# %%
import pandas as pd
import numpy as np
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fd4da9ed-65de-486b-af71-aeb0c0b60fca">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/LT-HT2.csv')

# %%
data['lt'] = 1
for index, row in data.iterrows():
    data['lt'][index] = row['job_id'][-6:-3].replace("-", "")
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['ht'] = 1
for index, row in data.iterrows():
    data['ht'][index] = row['job_id'][-3:]
data['ht'][data['ht']<0]=data['ht'][data['ht']<0]*-1
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][21:27]
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data = data[data['ht']!=0]

# %%
scat_ht_1 = Scatter(data, x='ht', y='mota', color='game')
scat_lt_1 = Scatter(data, x='lt', y='mota', color='game')
show(row(scat_ht_1,scat_lt_1))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="37d23ccf-cb2a-48af-ad53-a7175eb7c7af"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("37d23ccf-cb2a-48af-ad53-a7175eb7c7af");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("37d23ccf-cb2a-48af-ad53-a7175eb7c7af");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '37d23ccf-cb2a-48af-ad53-a7175eb7c7af' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"225ebd40-ae5b-4d5d-9501-08177884da80":{"roots":{"references":[{"attributes":{},"id":"1797308d-35a4-471e-815d-1183881b98a4","type":"BasicTickFormatter"},{"attributes":{},"id":"1b93fe20-083f-43db-86b8-ee7548d23d27","type":"BasicTickFormatter"},{"attributes":{},"id":"4c65c73f-a14c-4b65-990c-497d7ea7193f","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"80a24f17-49b1-4c1b-8138-ed476d5708f8","type":"Circle"},{"attributes":{"plot":{"id":"a7ab72d2-9271-4240-ae33-4638d47d147c","subtype":"Chart","type":"Plot"},"ticker":{"id":"c722887f-bdcb-464b-9ba1-5a07e0157714","type":"BasicTicker"}},"id":"eac82d5b-586b-446a-9c6a-1719a048f994","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"}],"game":["ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd"],"x_values":[29,39,24,24,29,39,29,34,34,29,39,34,24,39],"y_values":{"__ndarray__":"lwEKYHsr6T/XG2yMzi3pP+VpksdWLuk/D3IvVIIu6T8rIphcny7pP/gtJEe7Luk/5xCsVzgv6T8uXK/qVTHpP+vx3HXQMuk/OduDceMy6T/+q2CsrjPpP9f7BInMNOk/MIKq5v806T/NBSC3jTXpPw==","dtype":"float64","shape":[14]}}},"id":"33bb6fde-af0f-4ad8-97dd-78050fca5b4d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"}],"game":["PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214"],"x_values":[24,29,34,39,24,39,39,39,34,24,29,34],"y_values":{"__ndarray__":"NFKIxrDw6j92kw9wtPXqP55YLziU+Oo/i8Vwcn7/6j9fDpKMQQLrPzGfTuAUD+s/8p6+sD4R6z/LtBRcDxLrP4xyTfSyFes/coiOyBsW6z9m54eDQBfrP/31t3mdF+s/","dtype":"float64","shape":[12]}}},"id":"157ecce7-94b7-42fa-bd47-577baaea2735","type":"ColumnDataSource"},{"attributes":{},"id":"a210b423-2e83-4fe7-a818-62cc7e548466","type":"ToolEvents"},{"attributes":{"label":{"value":"PS0304"},"renderers":[{"id":"cbf8a4cb-c99f-4b0e-9c04-40b30b08949d","type":"GlyphRenderer"}]},"id":"e47fed88-8acb-4647-a9fd-57d264026029","type":"LegendItem"},{"attributes":{},"id":"c722887f-bdcb-464b-9ba1-5a07e0157714","type":"BasicTicker"},{"attributes":{"items":[{"id":"399e6c30-a730-4ff1-9f8b-532892a6fe7c","type":"LegendItem"},{"id":"e47fed88-8acb-4647-a9fd-57d264026029","type":"LegendItem"},{"id":"11124bae-89a3-4788-a1ab-51723e5d2e33","type":"LegendItem"},{"id":"a7ed5893-1bf5-4a4d-99c2-8cf4fefa5e48","type":"LegendItem"}],"location":"top_left","plot":{"id":"9a1d5721-5d60-41dd-8429-7f214cdecfb2","subtype":"Chart","type":"Plot"}},"id":"32cf564c-41ce-487e-ad3b-015ce67c6854","type":"Legend"},{"attributes":{"plot":null,"text":null},"id":"3fe380da-1c5d-464a-a52e-c0213696108d","type":"Title"},{"attributes":{},"id":"abb77f60-5fb1-453a-ba49-6eb71e1a3f38","type":"BasicTicker"},{"attributes":{"plot":{"id":"9a1d5721-5d60-41dd-8429-7f214cdecfb2","subtype":"Chart","type":"Plot"},"ticker":{"id":"9653ad13-2ddb-441d-bc1a-44072d65d96d","type":"BasicTicker"}},"id":"ed6f27f0-084d-43be-8d02-8cd86ee2482d","type":"Grid"},{"attributes":{"items":[{"id":"7df979db-4018-4caf-8fc9-0cd16b477e4f","type":"LegendItem"},{"id":"ebf3ee5a-6b0e-49f1-a9a6-a0d7da25468c","type":"LegendItem"},{"id":"6f48b7b9-f7d8-43f5-bfca-0b17cb9a3ab3","type":"LegendItem"},{"id":"47e8aaf6-2f90-46a3-86ad-3a57d030f32d","type":"LegendItem"}],"location":"top_left","plot":{"id":"a7ab72d2-9271-4240-ae33-4638 ...

# %%
data_ht = data.copy()
data_ht['hungarian'] = data_ht['ht']
data_ht = data_ht.groupby(['ht']).mean()
data_ht
# Out:
#         mota      motp      motr  mostly_tracked    mt_auc        lt  \
# ht
# 24  0.760174  0.640913  0.859903        0.759755  0.854329  8.307692
# 29  0.748220  0.621522  0.857700        0.758477  0.851527  8.500000
# 34  0.752222  0.638156  0.862898        0.769006  0.856515  8.500000
# 39  0.768028  0.632423  0.872772        0.792951  0.866555  8.571429
#
#     hungarian
# ht
# 24       24.0
# 29       29.0
# 34       34.0
# 39       39.0

# %%
data_lt = data.copy()
data_lt['lost'] = data_lt['lt']
data_lt = data_lt.groupby(['lt']).mean()
data_lt
# Out:
#         mota      motp      motr  mostly_tracked    mt_auc         ht  lost
# lt
# 7   0.758693  0.632948  0.853146        0.744516  0.847079  31.000000   7.0
# 8   0.748254  0.621722  0.856236        0.755224  0.849974  31.500000   8.0
# 9   0.763654  0.633049  0.873885        0.795004  0.868077  32.181818   9.0
# 10  0.758979  0.643961  0.872579        0.791798  0.866397  32.000000  10.0

# %%
scat_ht_2 = Scatter(data_ht, x = 'hungarian', y='mota')
scat_ht_3 = Scatter(data_ht, x = 'hungarian', y='motp')
scat_ht_4 = Scatter(data_ht, x = 'hungarian', y='mostly_tracked')
scat_ht_5 = Scatter(data_ht, x = 'hungarian', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat_ht_2, scat_ht_3), row(scat_ht_4, scat_ht_5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eaf7700e-6c01-4fc4-8a4d-6f0a53b84e1a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eaf7700e-6c01-4fc4-8a4d-6f0a53b84e1a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eaf7700e-6c01-4fc4-8a4d-6f0a53b84e1a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eaf7700e-6c01-4fc4-8a4d-6f0a53b84e1a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"18354f4d-f454-4ff4-a56f-940715584426":{"roots":{"references":[{"attributes":{},"id":"7079454d-fbd5-454b-b969-747052d62616","type":"BasicTicker"},{"attributes":{"plot":{"id":"b058b3e2-7bd9-478c-9281-db09993ff5e0","subtype":"Chart","type":"Plot"}},"id":"1a7542a1-5750-47d6-a2ca-a43ee62c2dba","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"056197d9-fdb1-4592-b844-f294c8dce43e","type":"BoxAnnotation"},"plot":{"id":"b058b3e2-7bd9-478c-9281-db09993ff5e0","subtype":"Chart","type":"Plot"}},"id":"f2395704-8ef6-45b3-808f-d0072071f1b8","type":"BoxZoomTool"},{"attributes":{"axis_label":"hungarian","formatter":{"id":"a4405ba8-aea1-49df-b177-b4356491030e","type":"BasicTickFormatter"},"plot":{"id":"b058b3e2-7bd9-478c-9281-db09993ff5e0","subtype":"Chart","type":"Plot"},"ticker":{"id":"eb679000-4cbd-43ca-acb6-26ebda06e42d","type":"BasicTicker"}},"id":"cfccf7c9-b2d2-4830-a097-549e7c5b3a24","type":"LinearAxis"},{"attributes":{"plot":{"id":"b058b3e2-7bd9-478c-9281-db09993ff5e0","subtype":"Chart","type":"Plot"}},"id":"a8e7a361-f6ba-4a54-8e60-7bc08643a6b8","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b986ee12-4f65-4c14-b0a0-e86a049e75a9","type":"PanTool"},{"id":"1a7542a1-5750-47d6-a2ca-a43ee62c2dba","type":"WheelZoomTool"},{"id":"f2395704-8ef6-45b3-808f-d0072071f1b8","type":"BoxZoomTool"},{"id":"6326006c-266c-4ec9-84a1-c24afbf7da84","type":"SaveTool"},{"id":"a8e7a361-f6ba-4a54-8e60-7bc08643a6b8","type":"ResetTool"},{"id":"cb767315-83c6-4774-b401-59b8fbc9b74b","type":"HelpTool"}]},"id":"645dbd45-1a11-49d9-b70d-500ca054900f","type":"Toolbar"},{"attributes":{"location":"top_left","plot":{"id":"5290c7b6-6c53-48cc-9eb4-02d170f5a5cb","subtype":"Chart","type":"Plot"}},"id":"3fdc7871-d8fa-4dfc-b1d6-c104ec0ddac6","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"6377641b-a934-46c4-98ea-9318f00775de","type":"Circle"},{"attributes":{"callback":null,"end":0.6428518902696059,"start":0.619583365526454},"id":"f5ca8887-0d09-466b-aec3-3596d845cf47","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"35ea117c-f868-490d-9835-b98f18395419","subtype":"Chart","type":"Plot"},"ticker":{"id":"fd13b8cd-c050-40cd-ae71-4cdef03b345b","type":"BasicTicker"}},"id":"3774f114-660e-4224-8b90-c8236aad3070","type":"Grid"},{"attributes":{"below":[{"id":"cfccf7c9-b2d2-4830-a097-549e7c5b3a24","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"5e484fce-e657-4529-8cf3-8ba475cd0d17","type":"LinearAxis"}],"renderers":[{"id":"056197d9-fdb1-4592-b844-f294c8dce43e","type":"BoxAnnotation"},{"id":"0841d3b1-27be-4100-9ae2-5bb89982545d","type":"GlyphRenderer"},{"id":"1b14e66c-c467-4ffa-9a99-d7406a89fc7f","type":"Legend"},{"id":"cfccf7c9-b2d2-4830-a097-549e7c5b3a24","type":"LinearAxis"},{"id":"5e484fce-e657-4529-8cf3-8ba475cd0d17","type":"LinearAxis"},{"id":"2fcaadb4-0d2b-404c-9ad8-5d6bff3c1096","type":"Grid"},{"id":"d8904556-da03-4fc8-af3c-a2d3e09dd89c","type":"Grid"}],"title":{"id":"892b8495-dc63-4847-9653-07c646abccf3","type":"Title"},"tool_events":{"id":"485aaa2e-a739-4542-97ae-3303f05ab525","type":"ToolEvents"},"toolbar":{"id":"645dbd45-1a11-49d9-b70d-500ca054900f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"2c6b8864-31d9-415d-b41e-d05e19e5f183","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"e18c0eb1-ce44-4405-9c8e-b3e968bca8e3","type":"Range1d"}},"id":"b058b3e2-7bd9-478c-9281-db09993ff5e0","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"278a3708-246e-4b8d-8f40-8606bad5ad5f","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"b058b3e2-7bd9-478c-9281-db09993ff5e0","subtype":"Chart","type":"Plot"},"ticker":{"id":"7079454d-fbd5-454b-b969-747052d62616","type":"BasicTicker"}},"id":"d8904556-da03-4fc8-af3c-a2d3e09dd89c","type":"Grid"},{"attributes":{"callback":null,"end":0 ...

# %%
scat_lt_2 = Scatter(data_lt, x = 'lost', y='mota')
scat_lt_3 = Scatter(data_lt, x = 'lost', y='motp')
scat_lt_4 = Scatter(data_lt, x = 'lost', y='mostly_tracked')
scat_lt_5 = Scatter(data_lt, x = 'lost', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat_lt_2, scat_lt_3), row(scat_lt_4, scat_lt_5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c594550f-7786-4b94-ade3-8a351873ca51"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c594550f-7786-4b94-ade3-8a351873ca51");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c594550f-7786-4b94-ade3-8a351873ca51");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c594550f-7786-4b94-ade3-8a351873ca51' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"84dcc2b4-3801-407b-b285-bf4db72155a1":{"roots":{"references":[{"attributes":{"data_source":{"id":"87c7e548-3193-424c-be3f-3cdad81892dd","type":"ColumnDataSource"},"glyph":{"id":"08eba42c-bb34-4503-afc9-cf229c2481ee","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"bf663bf7-e7cf-4521-98d0-15a4a8c577fa","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"22e7fe47-f845-4bba-b7b4-ec993d464a5c","subtype":"Chart","type":"Plot"},"ticker":{"id":"894a5a03-91e0-4be1-8607-9f45f46b9709","type":"BasicTicker"}},"id":"5f397faf-45a5-4044-be59-f369f54e2e55","type":"Grid"},{"attributes":{"callback":null,"end":10.3,"start":6.7},"id":"c1ad1399-4c4e-4cbe-bb1d-a400d89574ee","type":"Range1d"},{"attributes":{"plot":{"id":"0dd1f1ab-ce4f-4cc3-9a65-7ce2abd3093b","subtype":"Chart","type":"Plot"}},"id":"7dcec1f9-d4f0-42d9-9ceb-81a8d518e10a","type":"HelpTool"},{"attributes":{"plot":{"id":"22e7fe47-f845-4bba-b7b4-ec993d464a5c","subtype":"Chart","type":"Plot"}},"id":"c646bdca-5c0d-4f40-9d9b-1116647e0998","type":"PanTool"},{"attributes":{},"id":"894a5a03-91e0-4be1-8607-9f45f46b9709","type":"BasicTicker"},{"attributes":{"plot":null,"text":null},"id":"b5811566-bb6e-40df-b500-5fd18697a0c1","type":"Title"},{"attributes":{"below":[{"id":"c50e481e-af98-45cb-b750-3bfe966d281d","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"979a4b2e-3657-4139-844f-50f7fda105e1","type":"LinearAxis"}],"renderers":[{"id":"17ec8169-d498-4a13-98a7-f854687d7d33","type":"BoxAnnotation"},{"id":"bf663bf7-e7cf-4521-98d0-15a4a8c577fa","type":"GlyphRenderer"},{"id":"63e21f81-a399-448c-8038-5c282ab42c75","type":"Legend"},{"id":"c50e481e-af98-45cb-b750-3bfe966d281d","type":"LinearAxis"},{"id":"979a4b2e-3657-4139-844f-50f7fda105e1","type":"LinearAxis"},{"id":"a4bdb70c-864c-4c23-b6e0-606721160b80","type":"Grid"},{"id":"5f397faf-45a5-4044-be59-f369f54e2e55","type":"Grid"}],"title":{"id":"b5811566-bb6e-40df-b500-5fd18697a0c1","type":"Title"},"tool_events":{"id":"71053538-b5ba-4b9a-bd59-bf8b75ef600d","type":"ToolEvents"},"toolbar":{"id":"1f3bdf9e-e9f3-4ea6-bfaf-5d86b97bc377","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"76114303-5cbc-4d0c-bcb5-2fa27a470f6a","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"39d1a1a0-134c-4c3f-8c33-f523a474e617","type":"Range1d"}},"id":"22e7fe47-f845-4bba-b7b4-ec993d464a5c","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"0dd1f1ab-ce4f-4cc3-9a65-7ce2abd3093b","subtype":"Chart","type":"Plot"}},"id":"17148fab-e81e-45c7-9ddf-1023ecca8c1b","type":"ResetTool"},{"attributes":{"callback":null,"end":10.3,"start":6.7},"id":"76114303-5cbc-4d0c-bcb5-2fa27a470f6a","type":"Range1d"},{"attributes":{"plot":{"id":"0dd1f1ab-ce4f-4cc3-9a65-7ce2abd3093b","subtype":"Chart","type":"Plot"}},"id":"357818fa-d255-4f70-b0a5-990207078737","type":"SaveTool"},{"attributes":{"plot":{"id":"22e7fe47-f845-4bba-b7b4-ec993d464a5c","subtype":"Chart","type":"Plot"}},"id":"baa99a33-b51c-4cee-ae67-901e265bdae2","type":"HelpTool"},{"attributes":{},"id":"abcac03a-1c60-42b4-b75f-ef810ad49a83","type":"BasicTicker"},{"attributes":{},"id":"e95d9c04-996a-43ba-88a1-ff7aa19accf1","type":"ToolEvents"},{"attributes":{"below":[{"id":"dc317f4e-3393-4b4d-aef6-f96ee2a350ca","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"367c9d40-6a42-4684-afeb-63636b113927","type":"LinearAxis"}],"renderers":[{"id":"90e5d0af-f2e4-4d79-bfad-eb853fd0274d","type":"BoxAnnotation"},{"id":"5e2bc2bc-d71a-4e37-ad8d-6da738534386","type":"GlyphRenderer"},{"id":"911369a6-7d83-4b6e-961a-7fe60fc26fbb","type":"Legend"},{"id":"dc317f4e-3393-4b4d-aef6-f96ee2a350ca","type":"LinearAxis"},{"id":"367c9d40-6a42-4684-afeb-63636b113927","type":"LinearAxis"},{"id":"1b866c75-03bf-4d91-b515-0f64b7ad5578","type":"Grid"},{"id":"92cb7b8b-f450-49f4-9f4c-25bf2aa07079","type":"Grid"}],"title":{"id":"7819367c-3415-4e5d-921f-77750eb432ed","type":"Title"},"tool_events":{"id":"e95d9c04-996a-43ba-88a1-ff7aa19accf1","type":"ToolEvents"},"toolbar":{"id":"56fcb20f-b68f-49ab ...

# %%
data['mota'].groupby(data['ht']).describe()
# Out:
#     count      mean       std       min       25%       50%       75%  \
# ht
# 24   13.0  0.760174  0.070214  0.649901  0.755330  0.761317  0.787720
# 29   14.0  0.748220  0.070475  0.648157  0.676855  0.762013  0.786996
# 34   14.0  0.752222  0.075927  0.644341  0.675185  0.763873  0.787635
# 39   14.0  0.768028  0.073966  0.642696  0.761783  0.786898  0.829713
#
#          max
# ht
# 24  0.846449
# 29  0.846588
# 34  0.846633
# 39  0.845955

# %%
data['mota'].groupby(data['lt']).describe()
# Out:
#     count      mean       std       min       25%       50%       75%  \
# lt
# 7    15.0  0.758693  0.075944  0.645334  0.702616  0.786558  0.814577
# 8    14.0  0.748254  0.070701  0.645884  0.678921  0.761234  0.787325
# 9    11.0  0.763654  0.064779  0.646666  0.760625  0.763859  0.787753
# 10   15.0  0.758979  0.077310  0.642696  0.706033  0.763887  0.816775
#
#          max
# lt
# 7   0.843688
# 8   0.845591
# 9   0.846399
# 10  0.846633

# %%
data[data['lt']==9 data['ht']==39]['game']
# Out:
# ---------------------------------------------------
# ValueError        Traceback (most recent call last)
# <ipython-input-35-a8f67a59bc82> in <module>()
# ----> 1 data[data['lt']==9 and data['ht']==39]['game']
#
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     951         raise ValueError("The truth value of a {0} is ambiguous. "
#     952                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 953                          .format(self.__class__.__name__))
#     954
#     955     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data['mota'].groupby(data['game']).describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# game
# ChvUtd   14.0  0.787221  0.000391  0.786558  0.786931  0.787143  0.787535
# ER0429   14.0  0.647733  0.002634  0.642696  0.646080  0.647785  0.649768
# PP0214   12.0  0.844867  0.001767  0.841881  0.843477  0.845723  0.846411
# PS0304   15.0  0.760872  0.002516  0.755330  0.759429  0.761317  0.762796
#
#              max
# game
# ChvUtd  0.787787
# ER0429  0.652194
# PP0214  0.846633
# PS0304  0.763887

# %%
data_lt_ht = data.copy()
data_lt_ht['lost'] = data_lt_ht['lt']
data_lt_ht['hungarian'] = data_lt_ht['ht']
data_lt_ht = data_lt_ht.loc[:,['mota','ht', 'lt', 'lost', 'hungarian']].groupby(['ht','lt']).mean()
data_lt_ht
# Out:
#            mota  lost  hungarian
# ht lt
# 24 7   0.758510     7         24
#    8   0.760557     8         24
#    9   0.773737     9         24
#    10  0.752838    10         24
# 29 7   0.758709     7         29
#    8   0.732319     8         29
#    9   0.732999     9         29
#    10  0.761073    10         29
# 34 7   0.758913     7         34
#    8   0.731992     8         34
#    9   0.752308     9         34
#    10  0.760639    10         34
# 39 7   0.758621     7         39
#    8   0.760098     8         39
#    9   0.798934     9         39
#    10  0.759832    10         39

# %%
scat_ht_lt_1 = Scatter(data_lt_ht, x='hungarian', y='mota', color='lost')
show(scat_ht_lt_1)
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/bokeh/core/json_encoder.py:73: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   if pd and isinstance(obj, pd.tslib.Timestamp):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dc1e7c08-37aa-4160-bfbd-a7ab0bb8a66f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dc1e7c08-37aa-4160-bfbd-a7ab0bb8a66f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dc1e7c08-37aa-4160-bfbd-a7ab0bb8a66f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dc1e7c08-37aa-4160-bfbd-a7ab0bb8a66f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b000ad63-8dde-4b9c-bc7f-ee2eac43ec88":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d0e0339e-b490-4642-bc4f-0e9c02545e56","type":"Circle"},{"attributes":{"label":{"value":"10"},"renderers":[{"id":"8985a691-3606-4ebe-a402-d747e5cc6631","type":"GlyphRenderer"}]},"id":"d03433cd-5de2-4a98-970b-61e9774fc746","type":"LegendItem"},{"attributes":{"label":{"value":"7"},"renderers":[{"id":"317bdc0b-c3ff-492d-bd07-924007a78cd5","type":"GlyphRenderer"}]},"id":"ac9db07f-7fd8-4eca-a218-ffe48f71dc2c","type":"LegendItem"},{"attributes":{"plot":{"id":"091efc3f-74b9-4fc6-b92f-793e9b94ce5c","subtype":"Chart","type":"Plot"}},"id":"fc58082b-5447-4693-a0e6-c86a100bae2b","type":"HelpTool"},{"attributes":{},"id":"766a5002-a092-434c-af70-1ad6212bb000","type":"BasicTickFormatter"},{"attributes":{},"id":"9aacc4b1-47f6-4da3-8535-c65229d0a663","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c4908b20-0be4-4230-a005-bac74ac7e879","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":null},"id":"d80481bb-73e1-49d1-ab26-80fb78a0a03a","type":"Title"},{"attributes":{},"id":"7dc30c89-4ce7-4142-943e-49b1c1a3c31e","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"52798e28-b691-457f-b3cf-7333bd6e1c54","type":"Circle"},{"attributes":{"data_source":{"id":"777e448e-7806-4b3a-b100-23468ba39e99","type":"ColumnDataSource"},"glyph":{"id":"d0e0339e-b490-4642-bc4f-0e9c02545e56","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"049dc7d3-9a0f-47db-8607-3d56d776316c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"lost":9},{"lost":9},{"lost":9},{"lost":9}],"lost":[9,9,9,9],"x_values":[24,29,34,39],"y_values":{"__ndarray__":"Yl074XPC6D+ghm6wuXTnPxu4emPoEug/Y82h+t6Q6T8=","dtype":"float64","shape":[4]}}},"id":"986043cc-8b2c-4b7f-aea2-be514dc527a7","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5d59ece5-f3c4-4600-b6c5-839ca98faec7","type":"PanTool"},{"id":"87a71b64-c005-4d1f-a9d9-fd4d7b9eff28","type":"WheelZoomTool"},{"id":"ab7fdbc9-c998-4bac-a722-1037c73a0fcf","type":"BoxZoomTool"},{"id":"5a04a2df-8604-4270-b054-fc3d2ae98a1e","type":"SaveTool"},{"id":"29a4303f-deeb-4449-baaf-b26ae3f96654","type":"ResetTool"},{"id":"fc58082b-5447-4693-a0e6-c86a100bae2b","type":"HelpTool"}]},"id":"47d1c846-a5bd-459f-811d-1ac192449810","type":"Toolbar"},{"attributes":{"plot":{"id":"091efc3f-74b9-4fc6-b92f-793e9b94ce5c","subtype":"Chart","type":"Plot"}},"id":"5d59ece5-f3c4-4600-b6c5-839ca98faec7","type":"PanTool"},{"attributes":{"axis_label":"hungarian","formatter":{"id":"2ce4aa0b-d61b-4bdd-b36b-8bd20b3e870e","type":"BasicTickFormatter"},"plot":{"id":"091efc3f-74b9-4fc6-b92f-793e9b94ce5c","subtype":"Chart","type":"Plot"},"ticker":{"id":"d5cf1340-7f45-4cbc-82e8-51daa79edeac","type":"BasicTicker"}},"id":"5fff4b71-6ffc-486c-acf5-536ad25be0aa","type":"LinearAxis"},{"attributes":{"label":{"value":"8"},"renderers":[{"id":"049dc7d3-9a0f-47db-8607-3d56d776316c","type":"GlyphRenderer"}]},"id":"60c80575-2deb-48c5-a405-be0dd36f8862","type":"LegendItem"},{"attributes":{"axis_label":"mota","formatter":{"id":"766a5002-a092-434c-af70-1ad6212bb000","type":"BasicTickFormatter"},"plot":{"id":"091efc3f-74b9-4fc6-b92f-793e9b94ce5c","subtype":"Chart","type":"Plot"},"ticker":{"id":"9aacc4b1-47f6- ...

# %%
scat_ht_6 = Scatter(data_ht, x = 'hungarian', y='mota');scat_ht_6.y_range.start,scat_ht_6.y_range.end = (0,1)
scat_ht_7 = Scatter(data_ht, x = 'hungarian', y='motp');scat_ht_7.y_range.start,scat_ht_7.y_range.end = (0,1)
scat_ht_8 = Scatter(data_ht, x = 'hungarian', y='mostly_tracked');scat_ht_8.y_range.start,scat_ht_8.y_range.end = (0,1)
scat_ht_9 = Scatter(data_ht, x = 'hungarian', y='mt_auc');scat_ht_9.y_range.start,scat_ht_9.y_range.end = (0,1)
show(column(row(scat_ht_6, scat_ht_7), row(scat_ht_8, scat_ht_9)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aca99ad6-a15f-4cee-9207-f2d4f12ab165"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("aca99ad6-a15f-4cee-9207-f2d4f12ab165");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aca99ad6-a15f-4cee-9207-f2d4f12ab165");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aca99ad6-a15f-4cee-9207-f2d4f12ab165' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a8529bd4-6b0f-4396-a022-d87f4f8d521b":{"roots":{"references":[{"attributes":{},"id":"1cf14007-d4cd-4483-9c1e-99af3b6c7a9c","type":"BasicTickFormatter"},{"attributes":{},"id":"abe37140-676a-4806-9ac6-e53151f2d9bb","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"ce82d474-7e54-48e5-b510-4e3ed7a6a01a","subtype":"Chart","type":"Plot"},"ticker":{"id":"8286100c-f5a9-4db2-ae0e-101975abcc3f","type":"BasicTicker"}},"id":"bff73914-8170-49e8-abdf-25384d214bc8","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":{"__ndarray__":"AAAAAAAAJEAAAAAAAAA0QAAAAAAAAD5AAAAAAAAAREAAAAAAAABJQAAAAAAAAE5AAAAAAACAUUAAAAAAAABUQAAAAAAAgFZAAAAAAAAAWUAAAAAAAEBfQAAAAAAAwGJAAAAAAADgZUAAAAAAAABpQAAAAAAAQG9AAAAAAADgdUAAAAAAAEB/QA==","dtype":"float64","shape":[17]},"y_values":{"__ndarray__":"58oVVagY6D+fh462+MDpP+jEJAf1Euo/bX1vH1I/6j/r0ZhoVGXqP8mYr9q1heo/1PIgHZyh6j8hQV/CI7rqPzXwgF21z+o/dpjt6Mni6j8xrpf6JQ3rP4RmSD0FLus/tcfQOY9J6z9gQaCb8V7rP54OQG7gfus/HgF3L9+l6z8CTUSE98LrPw==","dtype":"float64","shape":[17]}}},"id":"9433e5c0-2793-45f0-a7a5-05d1cb4bad4e","type":"ColumnDataSource"},{"attributes":{},"id":"4dafb5a6-dd02-412e-ae53-3c04660aaf6e","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cccebea9-8fb1-473d-b67b-d4bd5fa47501","type":"PanTool"},{"id":"6be6ddd1-4602-437b-a942-27b26ef4d949","type":"WheelZoomTool"},{"id":"955d74dc-73d8-4275-a231-c87fb580e264","type":"BoxZoomTool"},{"id":"5320a350-1fa5-4887-ae74-92090079d65a","type":"SaveTool"},{"id":"dbe4b573-f60f-4693-9ca1-6aeb8ff2164c","type":"ResetTool"},{"id":"299b4575-e502-4a67-a83d-ba7a93e21d05","type":"HelpTool"}]},"id":"a9536199-05d9-4516-9f4e-0b770524b068","type":"Toolbar"},{"attributes":{},"id":"4e158e93-3101-4239-9b19-3e96b568f0ae","type":"BasicTicker"},{"attributes":{},"id":"216cc8cc-1d9c-4b61-b780-a93d9035102e","type":"ToolEvents"},{"attributes":{"location":"top_left","plot":{"id":"454063e2-256e-48fb-9d7e-088c41d7262c","subtype":"Chart","type":"Plot"}},"id":"7e369383-aa2f-4d2d-aaf3-b6ba0285ce99","type":"Legend"},{"attributes":{"plot":{"id":"b56f98a3-0847-4de2-937f-cfa0e8df4bd2","subtype":"Chart","type":"Plot"}},"id":"6be6ddd1-4602-437b-a942-27b26ef4d949","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dc41ac07-8f5d-4845-9db6-5f877957a40e","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"c92b8b3f-768f-4a7a-a55d-102f3e57f757","type":"BoxAnnotation"},"plot":{"id":"454063e2-256e-48fb-9d7e-088c41d7262c","subtype":"Chart","type":"Plot"}},"id":"7d6ca30e-c125-4421-a0fd-0186dd699cdb","type":"BoxZoomTool"},{"attributes":{},"id":"f82cb6f4-7ca6-45d7-af44-c57ad398739d","type":"ToolEvents"},{"attributes":{"plot":{"id":"b56f98a3-0847-4de2-937f-cfa0e8df4bd2","subtype":"Chart","type":"Plot"}},"id":"cccebea9-8fb1-473d-b67b-d4bd5fa47501","type":"PanTool"},{"attributes":{},"id":"1dfa4adb-6724-4465-9271-9b6aea98762a","type":"ToolEvents"},{"attributes":{},"id":"c30ffa39-9575-4423-afbc-34f0a698ad29","type":"ToolEvents"},{"attributes":{"axis_label":"hungarian","formatter":{"id":"c8dfdd26-a2a2-476d-b489-65868eb17d81","type":"BasicTickFormatter"},"plot":{"id":"ce82d474-7e54-48e5-b510-4e3ed7a6a01a","subtype":"Chart","type":"Plot"},"ticker":{"id":"4dafb5a6-dd02-412e-ae53-3c04660aaf6e","type":"BasicTicker"}},"id":"0b2c59c7-de84-4a29-b35a-fd54d96246fb","type":"LinearAxis"},{"attributes":{"plot":{"id":"48bedabf-abd7-47dd-95ff-1919575d52ab","subtype":"Chart","type":"Plot"}},"id":"8a3e6ecb-cc7d-4b41-a70f-5c4ff86bf894","type":"ResetTool"},{"attributes":{"data_source":{" ...

# %%
scat_lt_6 = Scatter(data_lt, x = 'lost', y='mota');scat_lt_6.y_range.start,scat_lt_6.y_range.end = (0,1)
scat_lt_7 = Scatter(data_lt, x = 'lost', y='motp');scat_lt_7.y_range.start,scat_lt_7.y_range.end = (0,1)
scat_lt_8 = Scatter(data_lt, x = 'lost', y='mostly_tracked');scat_lt_8.y_range.start,scat_lt_8.y_range.end = (0,1)
scat_lt_9 = Scatter(data_lt, x = 'lost', y='mt_auc');scat_lt_9.y_range.start,scat_lt_9.y_range.end = (0,1)
show(column(row(scat_lt_6, scat_lt_7), row(scat_lt_8, scat_lt_9)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="09f8c595-e1dd-4958-9e0f-406a174fcd55"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("09f8c595-e1dd-4958-9e0f-406a174fcd55");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("09f8c595-e1dd-4958-9e0f-406a174fcd55");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '09f8c595-e1dd-4958-9e0f-406a174fcd55' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b4b27a68-b971-4d8d-8836-a3e1c6723d35":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ab0d30f0-20a9-4eb9-a0bb-4a4aee6e55bc","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"}},"id":"8dbec301-e747-4941-9b14-9ea314715dc4","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"}},"id":"f1f4428e-23a8-4435-b419-1bdaef647b16","type":"HelpTool"},{"attributes":{"location":"top_left","plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"}},"id":"e21a6811-4d58-423b-846e-35605ea41c56","type":"Legend"},{"attributes":{},"id":"1626c20e-e80b-47d4-a71d-0eaee2a54495","type":"BasicTicker"},{"attributes":{"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"}},"id":"c266efe3-f523-416d-a091-78db36dc7908","type":"PanTool"},{"attributes":{"axis_label":"lost","formatter":{"id":"0de9ead1-c319-4741-b6cb-c5c1fb55d98c","type":"BasicTickFormatter"},"plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"},"ticker":{"id":"f15db48f-e5e3-4d92-987b-8c1a1d3ac054","type":"BasicTicker"}},"id":"dfecfd0f-10db-4fbb-acf6-f196180f1a46","type":"LinearAxis"},{"attributes":{},"id":"0de9ead1-c319-4741-b6cb-c5c1fb55d98c","type":"BasicTickFormatter"},{"attributes":{},"id":"f15db48f-e5e3-4d92-987b-8c1a1d3ac054","type":"BasicTicker"},{"attributes":{"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"}},"id":"70c1b89b-e7cc-42cc-8b45-92e6f58592b1","type":"HelpTool"},{"attributes":{"data_source":{"id":"78285ca3-c5c0-4094-b593-f116fd2d3cb8","type":"ColumnDataSource"},"glyph":{"id":"37396e15-6092-4c14-af82-1d0e587db3d2","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"cca08c7e-ed40-4698-a24b-7be031e7dd8a","type":"GlyphRenderer"},{"attributes":{},"id":"77b8ea0c-8728-4d30-9c2d-2706d0085364","type":"BasicTicker"},{"attributes":{"axis_label":"mt_auc","formatter":{"id":"06da90f1-e884-4a09-8888-cf8561ad6023","type":"BasicTickFormatter"},"plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"},"ticker":{"id":"77b8ea0c-8728-4d30-9c2d-2706d0085364","type":"BasicTicker"}},"id":"07cd424d-4b3d-43ec-8f23-2a7e71563e0b","type":"LinearAxis"},{"attributes":{"axis_label":"lost","formatter":{"id":"bc4e95cc-571e-40a1-8aa9-6c6151b3e95e","type":"BasicTickFormatter"},"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"},"ticker":{"id":"1626c20e-e80b-47d4-a71d-0eaee2a54495","type":"BasicTicker"}},"id":"d024be3e-413f-4ab6-8d48-88d24e0364ad","type":"LinearAxis"},{"attributes":{"children":[{"id":"11482419-79ce-4bef-9e77-da96c0f0e4ef","type":"Row"},{"id":"c5c9bc5b-c3d0-471f-b115-81408d06eb2d","type":"Row"}]},"id":"6295a5e5-4764-44c9-8fa5-92662feba106","type":"Column"},{"attributes":{"children":[{"id":"eb81cae9-1073-46e8-baf2-02256f6ac130","subtype":"Chart","type":"Plot"},{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"}]},"id":"c5c9bc5b-c3d0-471f-b115-81408d06eb2d","type":"Row"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null],"x_values":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAABhAAAAAAAAAHEAAAAAAAAAgQA==","dtype":"float64","shape":[8]},"y_values":{"__ndarray__":"8OTY/4QD6T83Bx/iHMbpP1gs7g1cWOo/ae5QQWDB6j/JkMCxiRXrPx/qijjLWes/nH5gaiSQ6z+ZZEidjLvrPw==","dtype":"float64","shape":[8]}}},"id":"e4486230-5169-4848-9e68-5f230b73b7b7","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"f1bf9304-7561-4d0 ...

# %%
scat_ht_10 = Scatter(data, x='ht', y='mota', color='game');scat_ht_10.y_range.start,scat_ht_10.y_range.end = (0,1)
show(scat_ht_10)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="75112888-b9e2-4817-a815-035e133e1aa9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("75112888-b9e2-4817-a815-035e133e1aa9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75112888-b9e2-4817-a815-035e133e1aa9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '75112888-b9e2-4817-a815-035e133e1aa9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a49b8214-1c8f-4f2a-96ad-741f060efb95":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"}],"game":["PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214"],"x_values":[500,500,500,350,350,500,350,250,250,500,250,200,350,200,175,250,175,350,250,200,500,200,350,150,175,175,125,70,150,125,17 ...

# %%
scat_lt_10 = Scatter(data, x='lt', y='mota', color='game');scat_lt_10.y_range.start,scat_lt_10.y_range.end = (0,1)
show(scat_lt_10)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e16fdd17-23fc-4d9c-95f5-5925253d2bbc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e16fdd17-23fc-4d9c-95f5-5925253d2bbc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e16fdd17-23fc-4d9c-95f5-5925253d2bbc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e16fdd17-23fc-4d9c-95f5-5925253d2bbc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f19e4c2f-dbad-476e-b4c2-1f7b16530a21":{"roots":{"references":[{"attributes":{"label":{"value":"PP0214"},"renderers":[{"id":"4b92634f-087c-4451-ac0e-bdcfbc25ac73","type":"GlyphRenderer"}]},"id":"fe4a5c1c-917b-40a7-8907-9bf60eb51efd","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c990ca31-bbb3-40af-aef0-d85227e9a1ff","type":"Circle"},{"attributes":{"data_source":{"id":"6fd4c1c0-056a-4175-bb1d-2b92311e6364","type":"ColumnDataSource"},"glyph":{"id":"49031655-7c44-4028-878a-3cb5e65ce607","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"3bb9a10b-aa80-4f7f-b175-8681083ae631","type":"GlyphRenderer"},{"attributes":{},"id":"6ee6f2f3-0f59-4ce7-809d-21edf3b36b4e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":8.7,"start":0.29999999999999993},"id":"1bec8485-71ac-492f-abf7-85eaab359b19","type":"Range1d"},{"attributes":{"axis_label":"lt","formatter":{"id":"5aca91ba-03d0-48a5-b073-d4e5f2a53ba1","type":"BasicTickFormatter"},"plot":{"id":"9d97ea9e-8100-4c6d-9e03-89eb0932a855","subtype":"Chart","type":"Plot"},"ticker":{"id":"bb768bc6-2ccf-4cd4-b480-f3a2069cfa2d","type":"BasicTicker"}},"id":"92b2b022-c38e-4f18-896d-037d6c57459a","type":"LinearAxis"},{"attributes":{"plot":{"id":"9d97ea9e-8100-4c6d-9e03-89eb0932a855","subtype":"Chart","type":"Plot"}},"id":"fb466228-b28c-4885-a8e1-17936b6079a6","type":"SaveTool"},{"attributes":{"label":{"value":"ChvUtd"},"renderers":[{"id":"58350d29-64b6-4dc8-b6c9-53c75c086ea5","type":"GlyphRenderer"}]},"id":"6bb64ada-1abf-4e07-afd9-bb9293c3b0f9","type":"LegendItem"},{"attributes":{},"id":"c2ef1b0a-ce66-47f3-9dd4-d6e183b6f54a","type":"ToolEvents"},{"attributes":{"below":[{"id":"92b2b022-c38e-4f18-896d-037d6c57459a","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"af549a0f-480d-4825-ba47-9e74369c551a","type":"LinearAxis"}],"renderers":[{"id":"a2cbce62-63eb-4eef-acba-bd5ed18d3a81","type":"BoxAnnotation"},{"id":"4b92634f-087c-4451-ac0e-bdcfbc25ac73","type":"GlyphRenderer"},{"id":"58350d29-64b6-4dc8-b6c9-53c75c086ea5","type":"GlyphRenderer"},{"id":"87e71c7b-c60c-4ea8-b55a-138cecc3698f","type":"GlyphRenderer"},{"id":"3bb9a10b-aa80-4f7f-b175-8681083ae631","type":"GlyphRenderer"},{"id":"1a48a948-ede5-4fee-9f24-c24aba46c301","type":"Legend"},{"id":"92b2b022-c38e-4f18-896d-037d6c57459a","type":"LinearAxis"},{"id":"af549a0f-480d-4825-ba47-9e74369c551a","type":"LinearAxis"},{"id":"e8f9a358-bae0-4eac-a266-327ed326b70a","type":"Grid"},{"id":"1293b0c1-abaf-433e-9b79-57d5087276bc","type":"Grid"}],"title":{"id":"68a28bc6-84d7-44e1-a3b0-2ec5967a6c0f","type":"Title"},"tool_events":{"id":"c2ef1b0a-ce66-47f3-9dd4-d6e183b6f54a","type":"ToolEvents"},"toolbar":{"id":"14a9598e-fccd-4cc4-92dd-62ef794997dd","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"1bec8485-71ac-492f-abf7-85eaab359b19","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"1ccdda8d-a070-41d6-a437-117a1c584613","type":"Range1d"}},"id":"9d97ea9e-8100-4c6d-9e03-89eb0932a855","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429 ...

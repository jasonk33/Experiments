# %%
import holmes.experiment as Ex
import tempfile
import pprint
import json
import os
from terrarium.flatten import flatten_dict, expand_dict
import tempfile

# %%
temp_dir_obj = tempfile.TemporaryDirectory()
temp_dir = temp_dir_obj.name
package_location = Ex.staging.prep_holmes_package(
    staging_path=temp_dir, 
    commit_hash='ca6ccd63f270d603ffa9bdf5a7ced184d6339796'
)

detects_dict={}
for video_data in Ex.val_data:
    detects_dict[video_data['video_id']] = video_data['video_path'].replace('processed','detections')

def_conf_path = Ex.staging.extract_default_config(package_location, temp_dir)

with open(def_conf_path, 'r') as fp:
    def_conf_dict = json.load(fp)

new_def_conf_dicts={}
list_dicts=[]
for video_data in Ex.val_data:
    new_def_conf_dict = def_conf_dict.copy()
    detects_path = video_data['video_path'].replace('processed','detections').replace('.mp4', '.json')
    new_def_conf_dict['detector_config'] = {"source_path": detects_path,"_class_name": "PassThroughDetectorConfig","batch_size": 1}
    new_def_conf_dict['video_config'] = video_data
    new_def_conf_dict['video_config']['_class_name'] = 'RawVideoConfig'
    list_dicts.append(new_def_conf_dict)

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
lost_thresholds = [8]
hungarian_thresholds = [15,25,35,45]
minimum_detections = [25,35]

# %%
list_configs=[]
for lt in lost_thresholds:
    for ht in hungarian_thresholds:
        for min_det in minimum_detections:
            for config in list_dicts:
                current_config_dict = config.copy()
                parameter_map = {"tracker_config.tracklet_config.lost_threshold": lt,"tracker_config.associator_config._class_name": 'SpatialAssociatorConfig', "tracker_config.associator_config.threshold": ht}
                flat_dict = flatten_dict(current_config_dict)
                flat_dict.update(parameter_map)
                updated_config_dict = expand_dict(flat_dict)
                updated_config_dict["filter_configs"] = [{"_class_name": 'BbAreaFilterConfig', 'min_detections': min_det, "max_pixel_area": 5000, "min_pixel_area": 100}]
                file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}-{:02d}-{:02d}.json".format(len(list_configs), 
                                                    current_config_dict['video_config']['video_id'], lt, ht, min_det))
                list_configs.append(file_name)
                with open(file_name, 'w') as f:
                    json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])
# Out:
# 32 /var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M00-ChvUtd-000-08-15-25.json

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-LT-HT-DET-1-1", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-LT-HT-DET-1-1",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )
# Out:
# 2017-06-16 11:51:02,439 [INFO] [holmes.experiment.base] Verifying AWS staging area: s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()
# Out:
# 2017-06-16 11:51:20,985 [INFO] [holmes.experiment.base] staging measurement M00-ChvUtd-000-08-15-25
# 2017-06-16 11:51:21,412 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M00-ChvUtd-000-08-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M00-ChvUtd-000-08-15-25.json
# 2017-06-16 11:51:21,767 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz
# 2017-06-16 11:51:22,770 [INFO] [holmes.experiment.base] staging measurement M01-PS0304-001-08-15-25
# 2017-06-16 11:51:23,269 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M01-PS0304-001-08-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M01-PS0304-001-08-15-25.json
# 2017-06-16 11:51:23,601 [INFO] [holmes.experiment.base] staging measurement M02-PP0214-000-08-15-25
# 2017-06-16 11:51:24,042 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M02-PP0214-000-08-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M02-PP0214-000-08-15-25.json
# 2017-06-16 11:51:24,421 [INFO] [holmes.experiment.base] staging measurement M03-ER0429-001-08-15-25
# 2017-06-16 11:51:24,838 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M03-ER0429-001-08-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M03-ER0429-001-08-15-25.json
# 2017-06-16 11:51:25,198 [INFO] [holmes.experiment.base] staging measurement M04-ChvUtd-000-08-15-35
# 2017-06-16 11:51:25,610 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M04-ChvUtd-000-08-15-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M04-ChvUtd-000-08-15-35.json
# 2017-06-16 11:51:26,029 [INFO] [holmes.experiment.base] staging measurement M05-PS0304-001-08-15-35
# 2017-06-16 11:51:26,482 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M05-PS0304-001-08-15-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M05-PS0304-001-08-15-35.json
# 2017-06-16 11:51:26,856 [INFO] [holmes.experiment.base] staging measurement M06-PP0214-000-08-15-35
# 2017-06-16 11:51:27,275 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M06-PP0214-000-08-15-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M06-PP0214-000-08-15-35.json
# 2017-06-16 11:51:27,653 [INFO] [holmes.experiment.base] staging measurement M07-ER0429-001-08-15-35
# 2017-06-16 11:51:29,686 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M07-ER0429-001-08-15-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M07-ER0429-001-08-15-35.json
# 2017-06-16 11:51:30,040 [INFO] [holmes.experiment.base] staging measurement M08-ChvUtd-000-08-25-25
# 2017-06-16 11:51:30,453 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M08-ChvUtd-000-08-25-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M08-ChvUtd-000-08-25-25.json
# 2017-06-16 11:51:30,805 [INFO] [holmes.experiment.base] staging measurement M09-PS0304-001-08-25-25
# 2017-06-16 11:51:31,223 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M09-PS0304-001-08-25-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M09-PS0304-001-08-25-25.json
# 2017-06-16 11:51:31,585 [INFO] [holmes.experiment.base] staging measurement M10-PP0214-000-08-25-25
# 2017-06-16 11:51:31,980 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M10-PP0214-000-08-25-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M10-PP0214-000-08-25-25.json
# 2017-06-16 11:51:32,413 [INFO] [holmes.experiment.base] staging measurement M11-ER0429-001-08-25-25
# 2017-06-16 11:51:32,821 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M11-ER0429-001-08-25-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M11-ER0429-001-08-25-25.json
# 2017-06-16 11:51:33,168 [INFO] [holmes.experiment.base] staging measurement M12-ChvUtd-000-08-25-35
# 2017-06-16 11:51:33,574 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M12-ChvUtd-000-08-25-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M12-ChvUtd-000-08-25-35.json
# 2017-06-16 11:51:33,931 [INFO] [holmes.experiment.base] staging measurement M13-PS0304-001-08-25-35
# 2017-06-16 11:51:34,333 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M13-PS0304-001-08-25-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M13-PS0304-001-08-25-35.json
# 2017-06-16 11:51:34,678 [INFO] [holmes.experiment.base] staging measurement M14-PP0214-000-08-25-35
# 2017-06-16 11:51:35,096 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M14-PP0214-000-08-25-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M14-PP0214-000-08-25-35.json
# 2017-06-16 11:51:35,428 [INFO] [holmes.experiment.base] staging measurement M15-ER0429-001-08-25-35
# 2017-06-16 11:51:35,817 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M15-ER0429-001-08-25-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M15-ER0429-001-08-25-35.json
# 2017-06-16 11:51:36,188 [INFO] [holmes.experiment.base] staging measurement M16-ChvUtd-000-08-35-25
# 2017-06-16 11:51:36,601 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M16-ChvUtd-000-08-35-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M16-ChvUtd-000-08-35-25.json
# 2017-06-16 11:51:36,941 [INFO] [holmes.experiment.base] staging measurement M17-PS0304-001-08-35-25
# 2017-06-16 11:51:37,375 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M17-PS0304-001-08-35-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M17-PS0304-001-08-35-25.json
# 2017-06-16 11:51:37,704 [INFO] [holmes.experiment.base] staging measurement M18-PP0214-000-08-35-25
# 2017-06-16 11:51:38,177 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M18-PP0214-000-08-35-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M18-PP0214-000-08-35-25.json
# 2017-06-16 11:51:38,509 [INFO] [holmes.experiment.base] staging measurement M19-ER0429-001-08-35-25
# 2017-06-16 11:51:38,920 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M19-ER0429-001-08-35-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M19-ER0429-001-08-35-25.json
# 2017-06-16 11:51:39,337 [INFO] [holmes.experiment.base] staging measurement M20-ChvUtd-000-08-35-35
# 2017-06-16 11:51:39,728 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M20-ChvUtd-000-08-35-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M20-ChvUtd-000-08-35-35.json
# 2017-06-16 11:51:40,060 [INFO] [holmes.experiment.base] staging measurement M21-PS0304-001-08-35-35
# 2017-06-16 11:51:40,465 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M21-PS0304-001-08-35-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M21-PS0304-001-08-35-35.json
# 2017-06-16 11:51:40,804 [INFO] [holmes.experiment.base] staging measurement M22-PP0214-000-08-35-35
# 2017-06-16 11:51:41,261 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M22-PP0214-000-08-35-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M22-PP0214-000-08-35-35.json
# 2017-06-16 11:51:41,709 [INFO] [holmes.experiment.base] staging measurement M23-ER0429-001-08-35-35
# 2017-06-16 11:51:42,125 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M23-ER0429-001-08-35-35.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M23-ER0429-001-08-35-35.json
# 2017-06-16 11:51:42,548 [INFO] [holmes.experiment.base] staging measurement M24-ChvUtd-000-08-45-25
# 2017-06-16 11:51:43,042 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M24-ChvUtd-000-08-45-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M24-ChvUtd-000-08-45-25.json
# 2017-06-16 11:51:43,435 [INFO] [holmes.experiment.base] staging measurement M25-PS0304-001-08-45-25
# 2017-06-16 11:51:43,909 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M25-PS0304-001-08-45-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M25-PS0304-001-08-45-25.json
# 2017-06-16 11:51:44,296 [INFO] [holmes.experiment.base] staging measurement M26-PP0214-000-08-45-25
# 2017-06-16 11:51:44,706 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M26-PP0214-000-08-45-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M26-PP0214-000-08-45-25.json
# 2017-06-16 11:51:45,044 [INFO] [holmes.experiment.base] staging measurement M27-ER0429-001-08-45-25
# 2017-06-16 11:51:45,443 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/M27-ER0429-001-08-45-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M27-ER0429-001-08-45-25.json
# 2017-06-16 11:51:45,804 [INFO] [holmes.experiment.base] staging measurement M28-ChvUtd-000-08-45-35
# 2017-06-16 11:51:46,201 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmp06jyo0u5/

#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'ceee32e6-52b3-11e7-af5a-6bb627506715',
#      'RetryAttempts': 0},
#     'jobId': '85de04e0-9a43-4224-bbec-013ef105e33c',
#     'jobName': 'PTA-95-LT-HT-DET-1-1-M28-ChvUtd-000-08-45-35'},
#    'measurement_id': 'M28-ChvUtd-000-08-45-35',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M29-PS0304-001-08-45-35.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-1-1',
#    'job_id': 'PTA-95-LT-HT-DET-1-1-M29-PS0304-001-08-45-35',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Fri, 16 Jun 2017 16:49:48 GMT',
#       'via': '1.1 e14228d1c5c45bb6d7b2b04dc268fae1.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': '0X8z0pnp9YgtS4Wqe8kZE0GuGa0tgjWlZn7dIRaHpkjSGHOo1uding==',
#       'x-amzn-requestid': 'cf125c98-52b3-11e7-aa81-eb9cacde3aab',
#       'x-amzn-trace-id': 'sampled=0;root=1-59440c2c-c780d8d9e6a8662b03923e9d',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'cf125c98-52b3-11e7-aa81-eb9cacde3aab',
#      'RetryAttempts': 0},
#     'jobId': 'b24cc950-a5ce-4e52-ab68-1e68c99d4147',
#     'jobName': 'PTA-95-LT-HT-DET-1-1-M29-PS0304-001-08-45-35'},
#    'measurement_id': 'M29-PS0304-001-08-45-35',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M30-PP0214-000-08-45-35.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-1-1',
#    'job_id': 'PTA-95-LT-HT-DET-1-1-M30-PP0214-000-08-45-35',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Fri, 16 Jun 2017 16:49:48 GMT',
#       'via': '1.1 32f7e69ff9adb3ec91a09cd1d395b768.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'eCJAtbXFg6HLDJXRJxBPUGLfGTtSrlWszYxYgx5J-tD-TtjiasLZ5w==',
#       'x-amzn-requestid': 'cf312f12-52b3-11e7-a4fd-85d084aa9131',
#       'x-amzn-trace-id': 'sampled=0;root=1-59440c2c-1c97a217972abc2ec7c30d6a',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'cf312f12-52b3-11e7-a4fd-85d084aa9131',
#      'RetryAttempts': 0},
#     'jobId': 'a51d4067-5f52-4e86-a15f-03cb74506471',
#     'jobName': 'PTA-95-LT-HT-DET-1-1-M30-PP0214-000-08-45-35'},
#    'measurement_id': 'M30-PP0214-000-08-45-35',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/M31-ER0429-001-08-45-35.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-1-1',
#    'job_id': 'PTA-95-LT-HT-DET-1-1-M31-ER0429-001-08-45-35',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Fri, 16 Jun 2017 16:49:48 GMT',
#       'via': '1.1 056e8663365bf1daf840591db57b77b6.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'tMvy1lx6zQTSzRA8L1EcM6Ja8A2-MjmFxrjjXggaBdT1hw71Sfaq-w==',
#       'x-amzn-requestid': 'cf4d90f4-52b3-11e7-a2f6-1d1cdc7036bf',
#       'x-amzn-trace-id': 'sampled=0;root=1-59440c2c-3efaa9b1a87f01b14c7e0497',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'cf4d90f4-52b3-11e7-a2f6-1d1cdc7036bf',
#      'RetryAttempts': 0},
#     'jobId': 'ab1c3aaa-5cbe-42ef-9aa2-de9d053b6663',
#     'jobName': 'PTA-95-LT-HT-DET-1-1-M31-ER0429-001-08-45-35'},
#    'measurement_id': 'M31-ER0429-001-08-45-35',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-1/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'}]}

# %%
import pandas as pd

# %%
data = pd.DataFrame({'mota':[.641,.645,.645,.649,.625,.656,.66,.663,.855,.858,.859,.859,.862,.857,.857,.855,.791,.793
                             ,.792,.792,.791,.792,.791,.791,.768,.767,.769,.766,.766,.770,.768,.767],
              'lt':[8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8],
              'ht':[45,45,35,35,25,25,15,15,45,25,25,15,15,35,35,45,45,25,25,15,45,35,35,15,45,35,25,15,45,35,25,15],
              'det':[25,35,25,35,25,35,25,35,25,35,25,35,25,35,25,35,25,35,25,25,35,35,25,35,35,25,35,35,25,35,25,25],
             'game':['ER0429','ER0429','ER0429','ER0429','ER0429','ER0429','ER0429','ER0429','PP0214','PP0214',
                     'PP0214','PP0214','PP0214','PP0214','PP0214','PP0214','ChvUtd','ChvUtd','ChvUtd','ChvUtd',
                    'ChvUtd','ChvUtd','ChvUtd','ChvUtd','PS0304','PS0304','PS0304','PS0304','PS0304','PS0304'
                    ,'PS0304','PS0304']})

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8407f968-b1e2-4907-bed6-99d84f79f95e">Loading BokehJS ...</span>
#     </div>

# %%
data_lt_ht_det = data.copy()
data_lt_ht_det['lost'] = data_lt_ht_det['lt']
data_lt_ht_det['hungarian'] = data_lt_ht_det['ht']
data_lt_ht_det['detections'] = data_lt_ht_det['det']
data_lt_ht_det = data_lt_ht_det.loc[:,['mota','ht', 'lt', 'det', 'lost', 'hungarian', 'detections']].groupby(['ht','lt','det']).mean()
data_lt_ht_det
# Out:
#               mota  lost  hungarian  detections
# ht lt det
# 15 8  25   0.77025     8         15          25
#       35   0.76975     8         15          35
# 25 8  25   0.76100     8         25          25
#       35   0.76900     8         25          35
# 35 8  25   0.76500     8         35          25
#       35   0.76700     8         35          35
# 45 8  25   0.76325     8         45          25
#       35   0.76475     8         45          35

# %%
scat_lt_ht_det_1 = Scatter(data_lt_ht_det, x='hungarian', y='mota', color='detections', marker='lost')
show(scat_lt_ht_det_1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff2156c2-d06a-4514-874d-a8aea2d69798"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ff2156c2-d06a-4514-874d-a8aea2d69798");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ff2156c2-d06a-4514-874d-a8aea2d69798");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ff2156c2-d06a-4514-874d-a8aea2d69798' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9a6d3091-87ac-4e0c-b591-c113dba60813":{"roots":{"references":[{"attributes":{},"id":"6a7e08d0-c078-4cca-b815-cea5dd1e46ef","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d05a14fc-0274-41f5-9f9f-65e85501bc80","type":"Circle"},{"attributes":{"plot":{"id":"9bb30954-73c0-4d0a-9277-ae721666f481","subtype":"Chart","type":"Plot"}},"id":"658ba553-7487-48ad-a558-225896470bb7","type":"PanTool"},{"attributes":{"overlay":{"id":"6325a8b2-4739-44e9-a56c-730bf87139ee","type":"BoxAnnotation"},"plot":{"id":"9bb30954-73c0-4d0a-9277-ae721666f481","subtype":"Chart","type":"Plot"}},"id":"f58721ef-4724-4ac7-bfc1-cd09217adec1","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"1ee6b0e3-28f1-46aa-a4f6-075c024f48e5","type":"ColumnDataSource"},"glyph":{"id":"7eff79b5-d90f-40ce-b573-247fe3c9743e","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"df2a0fae-8f7a-4690-b40e-393780f064da","type":"GlyphRenderer"},{"attributes":{},"id":"e906d980-9dbb-4755-bc27-be3b1851676f","type":"ToolEvents"},{"attributes":{"plot":{"id":"9bb30954-73c0-4d0a-9277-ae721666f481","subtype":"Chart","type":"Plot"}},"id":"1521a94f-25cf-4616-888e-3676472cdaef","type":"ResetTool"},{"attributes":{"plot":{"id":"9bb30954-73c0-4d0a-9277-ae721666f481","subtype":"Chart","type":"Plot"}},"id":"5efeadc6-3657-4319-bf43-12fa65d83aff","type":"HelpTool"},{"attributes":{},"id":"48011600-b68e-4167-93fa-8dba9c932a94","type":"BasicTicker"},{"attributes":{"below":[{"id":"d756e516-2983-4803-9333-7ddf88fb46fc","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"87ead8fb-3392-4405-a723-6120d79f2564","type":"LinearAxis"}],"renderers":[{"id":"6325a8b2-4739-44e9-a56c-730bf87139ee","type":"BoxAnnotation"},{"id":"739f6c0f-09a5-4dee-bd05-1521848a5386","type":"GlyphRenderer"},{"id":"df2a0fae-8f7a-4690-b40e-393780f064da","type":"GlyphRenderer"},{"id":"cb61e3ef-ef1d-44b4-bea8-8f4002d96d06","type":"Legend"},{"id":"d756e516-2983-4803-9333-7ddf88fb46fc","type":"LinearAxis"},{"id":"87ead8fb-3392-4405-a723-6120d79f2564","type":"LinearAxis"},{"id":"5f43b948-a3a9-45bb-aced-33c7927670a1","type":"Grid"},{"id":"09eb03f4-5fe2-420c-ba91-53f0aea4fec0","type":"Grid"}],"title":{"id":"93051a4a-582b-4165-8127-14a9ebb88e72","type":"Title"},"tool_events":{"id":"e906d980-9dbb-4755-bc27-be3b1851676f","type":"ToolEvents"},"toolbar":{"id":"8876083c-6fae-4f9f-9583-7c76426834ca","type":"Toolbar"},"x_range":{"id":"8b13489d-15ac-43f0-ae30-ea232128fdea","type":"Range1d"},"x_scale":{"id":"c358b62d-931d-4798-a973-579895ea8b78","type":"LinearScale"},"y_range":{"id":"71185ca5-8f60-4690-8f1d-3f9fce2de184","type":"Range1d"},"y_scale":{"id":"a20827f4-732d-46b5-a2fb-86a7773ed5b3","type":"LinearScale"}},"id":"9bb30954-73c0-4d0a-9277-ae721666f481","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":"hungarian","formatter":{"id":"6a7e08d0-c078-4cca-b815-cea5dd1e46ef","type":"BasicTickFormatter"},"plot":{"id":"9bb30954-73c0-4d0a-9277-ae721666f481","subtype":"Chart","type":"Plot"},"ticker":{"id":"48011600-b68e-4167-93fa-8dba9c932a94","type":"BasicTicker"}},"id":"d756e516-2983-4803-9333-7ddf88fb46fc","type":"LinearAxis"},{"attributes":{},"id":"a20827f4-732d-46b5-a2fb-86a7773ed5b3","type":"LinearScale"},{"attributes":{"plot":{"id":"9bb30954-73c0-4d0a-9277-ae721666f481","subtype":"Chart","type":"Plot"}},"id":"4fe0f1eb-1915-43d8-83d7-65df7d528cd3","type":"WheelZoomTool"},{"attributes":{"label":{"value":"(8, 35)"},"renderers":[{"id":"df2a0fae-8f7a-4690-b40e-393780f064da","type":"GlyphRenderer"}]},"id":"030053f2-cb5a-414a-a309-4a7a86f42678","type":"LegendItem"},{"attributes":{},"id":"45e4662f-ec92-408f-9e40-b03f6016b38f","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"detections":25,"lost":8},{"detections":25,"lost":8},{"detections":25,"lost":8}, ...

# %%
data[data['ht']==15][data[data['ht']==15]['det']==25]
# Out:
#     det    game  ht  lt   mota
# 6    25  ER0429  15   8  0.660
# 12   25  PP0214  15   8  0.862
# 19   25  ChvUtd  15   8  0.792
# 31   25  PS0304  15   8  0.767

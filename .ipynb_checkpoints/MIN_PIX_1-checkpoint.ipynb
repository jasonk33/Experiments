# %%
import holmes.experiment as Ex
import tempfile
import pprint
import json
import os
from terrarium.flatten import flatten_dict, expand_dict
import tempfile

# %%
temp_dir_obj = tempfile.TemporaryDirectory()
temp_dir = temp_dir_obj.name
package_location = Ex.staging.prep_holmes_package(
    staging_path=temp_dir, 
    commit_hash='ca6ccd63f270d603ffa9bdf5a7ced184d6339796'
)

detects_dict={}
for video_data in Ex.val_data:
    detects_dict[video_data['video_id']] = video_data['video_path'].replace('processed','detections')

def_conf_path = Ex.staging.extract_default_config(package_location, temp_dir)

with open(def_conf_path, 'r') as fp:
    def_conf_dict = json.load(fp)

new_def_conf_dicts={}
list_dicts=[]
for video_data in Ex.val_data:
    new_def_conf_dict = def_conf_dict.copy()
    detects_path = video_data['video_path'].replace('processed','detections').replace('.mp4', '.json')
    new_def_conf_dict['detector_config'] = {"source_path": detects_path,"_class_name": "PassThroughDetectorConfig","batch_size": 1}
    new_def_conf_dict['video_config'] = video_data
    new_def_conf_dict['video_config']['_class_name'] = 'RawVideoConfig'
    list_dicts.append(new_def_conf_dict)

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
minimum_pixels = [25,50,75,100,125,150,175,200]

# %%
list_configs=[]
for min_pix in minimum_pixels:
    for config in list_dicts:
        current_config_dict = config.copy()
        flat_dict = flatten_dict(current_config_dict)
        updated_config_dict = expand_dict(flat_dict)
        updated_config_dict["filter_configs"] = [{"_class_name": 'BbAreaFilterConfig', 'min_detections': 60, "max_pixel_area": 5000, "min_pixel_area": min_pix}]
        file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}.json".format(len(list_configs), 
                                            current_config_dict['video_config']['video_id'], min_pix))
        list_configs.append(file_name)
        with open(file_name, 'w') as f:
            json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-MIN-PIX-1-1", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-MIN-PIX-1-1",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()

# %%
experiment.launch_experiment()

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/min_pix1.csv')

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="165aaab8-8ecb-4633-af17-6f2e5b41810b">Loading BokehJS ...</span>
#     </div>

# %%
data['min_pix'] = 1
for index, row in data.iterrows():
    data['min_pix'][index] = row['job_id'][-3:]
data['min_pix'][data['min_pix']<0]=data['min_pix'][data['min_pix']<0]*-1

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][19:25]

# %%
scat1 = Scatter(data, x='min_pix', y='mota', color='game')
show(scat1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9ef24137-0790-447c-a3ab-7913c82b4f7e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9ef24137-0790-447c-a3ab-7913c82b4f7e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9ef24137-0790-447c-a3ab-7913c82b4f7e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9ef24137-0790-447c-a3ab-7913c82b4f7e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"311a576e-ac82-4e6d-8243-b5b541c131ce":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"fb4926fb-f489-4ff2-8f7b-78ce3e8b3b83","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"6adc54bd-fb09-491c-a7b0-71d9283eaadf","type":"Circle"},{"attributes":{"data_source":{"id":"2bea8115-e5e1-4122-8c43-9ff5c5559123","type":"ColumnDataSource"},"glyph":{"id":"6adc54bd-fb09-491c-a7b0-71d9283eaadf","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"70d72a85-25f9-41f7-a50d-1b2fd4f4f57e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"}],"game":["ER0429","ER0429","ER0429","ER0429","ER0429","ER0429","ER0429","ER0429"],"x_values":[25,200,125,50,150,75,175,100],"y_values":{"__ndarray__":"GPPBmMjJ5D+eroE5WMvkP8K2RN2sy+Q/JGpB2ufM5D9ueschkc3kPwgxz+qczeQ/kA1BxQPO5D/U+3kyN87kPw==","dtype":"float64","shape":[8]}}},"id":"ab4b9e79-5305-4e21-8587-08979e73c4ec","type":"ColumnDataSource"},{"attributes":{"label":{"value":"PS0304"},"renderers":[{"id":"70d72a85-25f9-41f7-a50d-1b2fd4f4f57e","type":"GlyphRenderer"}]},"id":"da7ae338-e3c2-43bf-8446-892232f3da0d","type":"LegendItem"},{"attributes":{},"id":"f6e46106-5c2f-476e-9fe0-12cbc01bef67","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a9b3c359-ac71-4f9c-b451-f54a3b40cc1a","type":"BoxAnnotation"},{"attributes":{"axis_label":"mota","formatter":{"id":"bee8f46a-3ac9-4ff5-a426-d5a50bb3e30d","type":"BasicTickFormatter"},"plot":{"id":"4b9f3292-20c7-47a7-bb7d-904aa8da00c9","subtype":"Chart","type":"Plot"},"ticker":{"id":"78167586-4e15-4187-9ea2-7c2314fd16ed","type":"BasicTicker"}},"id":"b8992af1-b67c-4920-ad7e-652fbc51f435","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"}],"game":["PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304"],"x_values":[200,150,25,125,100,75,50,175],"y_values":{"__ndarray__":"GvZgrt136D8eAMMUB3joP1z40QEFeug/vKm3Wyl66D9C0Z6wS3roPx1eic8sfeg/DOnJXTV+6D8kgPBkdIHoPw==","dtype":"float64","shape":[8]}}},"id":"2bea8115-e5e1-4122-8c43-9ff5c5559123","type":"ColumnDataSource"},{"attributes":{},"id":"bee8f46a-3ac9-4ff5-a426-d5a50bb3e30d","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"a9b3c359-ac71-4f9c-b451-f54a3b40cc1a","type":"BoxAnnotation"},"plot":{"id":"4b9f3292-20c7-47a7-bb7d-904aa8da00c9","subtype":"Chart","type":"Plot"}},"id":"d375bc9a-1ce5-42c7-9a79-b63c0b26aac3","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"}],"game":["ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd"],"x_values":[150,175,50,200,75,125,25,100],"y_values":{"__ndarray__":"L+Wen6Qz6T/oIovB1TPpPweOKezgM+k/UryaxQU06T8iKnZi8TTpP2G76Nn1NOk/u0GONyk16T9cMWEDDTbpPw==","dtype":"float64","shape":[8]}}},"id":"6a57a0f2-036f-40e5-a583-98260206f03b","type":"ColumnDataSource"},{"attributes":{"callback":n ...

# %%
data_min_pix = data.copy()
data_min_pix['minimum_pixels'] = data_min_pix['min_pix']
data_min_pix = data_min_pix.groupby(['min_pix']).mean()
data_min_pix
# Out:
#              mota      motp      motr  mostly_tracked    mt_auc  \
# min_pix
# 25       0.764141  0.638127  0.867665        0.769920  0.856285
# 50       0.764273  0.638060  0.867677        0.767969  0.856297
# 75       0.764320  0.638023  0.867739        0.769672  0.856358
# 100      0.764258  0.638083  0.867802        0.768264  0.856421
# 125      0.764150  0.638124  0.867510        0.767273  0.856157
# 150      0.764204  0.638064  0.867643        0.766991  0.856263
# 175      0.764387  0.638026  0.867841        0.770254  0.856477
# 200      0.764009  0.638084  0.867497        0.766895  0.856116
#
#          minimum_pixels
# min_pix
# 25                   25
# 50                   50
# 75                   75
# 100                 100
# 125                 125
# 150                 150
# 175                 175
# 200                 200

# %%
scat2 = Scatter(data_min_pix, x = 'minimum_pixels', y='mota')
scat3 = Scatter(data_min_pix, x = 'minimum_pixels', y='motp')
scat4 = Scatter(data_min_pix, x = 'minimum_pixels', y='mostly_tracked')
scat5 = Scatter(data_min_pix, x = 'minimum_pixels', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat2, scat3), row(scat4, scat5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="40d0c98e-3ebd-4417-a572-8ca3df6ff81f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("40d0c98e-3ebd-4417-a572-8ca3df6ff81f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("40d0c98e-3ebd-4417-a572-8ca3df6ff81f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '40d0c98e-3ebd-4417-a572-8ca3df6ff81f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7a7fe6c0-b13d-4e67-b893-3a401f40bee9":{"roots":{"references":[{"attributes":{"axis_label":"minimum_pixels","formatter":{"id":"e3e63c3b-e789-4614-b2f4-bcc5cf365b60","type":"BasicTickFormatter"},"plot":{"id":"62e7001e-7091-4fda-8804-700c9eeb8b13","subtype":"Chart","type":"Plot"},"ticker":{"id":"841ff77d-369b-451f-96f7-f84532a222e4","type":"BasicTicker"}},"id":"934fd079-ed7e-499f-a86e-ff613ea8dfd5","type":"LinearAxis"},{"attributes":{},"id":"4ca21264-f819-4435-8775-042f9fc549d1","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"72a9d73e-6239-4219-ac7d-642d633e5814","type":"BoxAnnotation"},"plot":{"id":"dd6c024d-6366-4e85-948c-ebfc41027223","subtype":"Chart","type":"Plot"}},"id":"38d07175-6a2a-4934-91e5-690054ad3ee1","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"dd6c024d-6366-4e85-948c-ebfc41027223","subtype":"Chart","type":"Plot"}},"id":"05fde97f-7d0b-4c3c-a967-51b4d215f42b","type":"ResetTool"},{"attributes":{"plot":null,"text":null},"id":"66b5fcbe-e078-4f85-bea9-52d9a257b74c","type":"Title"},{"attributes":{"overlay":{"id":"bee34397-e5c1-47c4-8ece-9dc8af52df76","type":"BoxAnnotation"},"plot":{"id":"62e7001e-7091-4fda-8804-700c9eeb8b13","subtype":"Chart","type":"Plot"}},"id":"75cf6884-dac0-4c1a-b1ac-36e1d9d399e0","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"76160f8f-1303-44ec-a725-55e9e7fa0512","subtype":"Chart","type":"Plot"}},"id":"6b29ca1d-31f5-4a5f-822e-7ffd4061adfd","type":"HelpTool"},{"attributes":{"below":[{"id":"b6fcf81f-e16f-4e38-af8a-66df6366adef","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"bf2bcc03-cbf5-45be-a67c-51240d047bce","type":"LinearAxis"}],"renderers":[{"id":"88481ce7-56d5-4bc4-bb8a-48470d6cc9bc","type":"BoxAnnotation"},{"id":"3bd89e50-7c9c-41ca-8b60-2bb193c7c890","type":"GlyphRenderer"},{"id":"28b583d1-2186-435a-8f69-9d82ffa8edec","type":"Legend"},{"id":"b6fcf81f-e16f-4e38-af8a-66df6366adef","type":"LinearAxis"},{"id":"bf2bcc03-cbf5-45be-a67c-51240d047bce","type":"LinearAxis"},{"id":"c17b09ba-a3b9-4087-acca-646579c94df3","type":"Grid"},{"id":"9da0ceaa-9d22-4b14-a30d-f3d0849176dd","type":"Grid"}],"title":{"id":"03b8afd8-75c8-4978-94ea-84b6bfd12cbe","type":"Title"},"tool_events":{"id":"215bfb09-c092-4edd-9e3a-7e57ab26895a","type":"ToolEvents"},"toolbar":{"id":"8b2278be-6637-46a3-9505-92cbd8518637","type":"Toolbar"},"x_range":{"id":"f8442b30-b999-43de-9b7f-e4adce1f2012","type":"Range1d"},"x_scale":{"id":"cb70f1fd-06fc-4b6f-ab98-694f8372538b","type":"LinearScale"},"y_range":{"id":"e11c09bf-f365-4266-92db-231fa173a350","type":"Range1d"},"y_scale":{"id":"026756e0-1058-4cc8-851d-7109a79b1eb0","type":"LinearScale"}},"id":"92b8edfd-b368-4e0e-9ad4-7bb922ec8afc","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"c73834bf-ca8b-40bd-aba6-520b8b80b852","type":"LinearScale"},{"attributes":{},"id":"cafbd634-0364-4317-99f3-d4b88473df12","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"62e7001e-7091-4fda-8804-700c9eeb8b13","subtype":"Chart","type":"Plot"}},"id":"17e38f53-679f-43e8-b300-bebe64784b72","type":"HelpTool"},{"attributes":{"axis_label":"mota","formatter":{"id":"381772af-07f1-41f5-a285-2b5e8771d616","type":"BasicTickFormatter"},"plot":{"id":"62e7001e-7091-4fda-8804-700c9eeb8b13","subtype":"Chart","type":"Plot"},"ticker":{"id":"3d693fb3-8d57-4bf5-a28e-eb46ff9cd540","type":"BasicTicker"}},"id":"d9d3879c-426d-4fc6-aa31-3917f4badfa3","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"62e7001e-7091-4fda-8804-700c9eeb8b13","subtype":"Chart","type":"Plot"}},"id":"487da39c-de61-4d9d-ba93-bcbecb07ace9","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"bd6a34a4-0ab7-4730-9769-b08ca708cc91","type":"Circle"},{"attributes":{"plot":{"id":"92b8edfd-b368-4e0e-9ad4-7bb922ec8afc","subtype":"Chart","type":"Plot"}},"id":"e7267c04-35dc-4207-bfbc-0c499123d54d","type":"ResetTool" ...

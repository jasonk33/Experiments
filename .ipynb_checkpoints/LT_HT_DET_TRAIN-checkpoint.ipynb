# %%
import holmes.experiment as Ex
import tempfile
import pprint
import json
import os
from terrarium.flatten import flatten_dict, expand_dict
import tempfile

# %%
temp_dir_obj = tempfile.TemporaryDirectory()
temp_dir = temp_dir_obj.name
package_location = Ex.staging.prep_holmes_package(
    staging_path=temp_dir, 
    commit_hash='2addf6c84ba0ca6544946a602bf943553d36b693'
)

detects_dict={}
for video_data in Ex.train_data:
    detects_dict[video_data['video_id']] = video_data['video_path'].replace('processed','detections')

def_conf_path = Ex.staging.extract_default_config(package_location, temp_dir)

with open(def_conf_path, 'r') as fp:
    def_conf_dict = json.load(fp)

new_def_conf_dicts={}
list_dicts=[]
for video_data in Ex.train_data:
    new_def_conf_dict = def_conf_dict.copy()
    detects_path = video_data['video_path'].replace('processed','detections').replace('.mp4', '.json')
    new_def_conf_dict['detector_config'] = {"source_path": detects_path,"_class_name": "PassThroughDetectorConfig","batch_size": 1}
    new_def_conf_dict['video_config'] = video_data
    new_def_conf_dict['video_config']['_class_name'] = 'RawVideoConfig'
    list_dicts.append(new_def_conf_dict)
# Out:
# 2017-06-19 17:43:45,827 [INFO] [holmes.experiment.staging] Preparing holmes payload
# 2017-06-19 17:43:45,828 [INFO] [holmes.experiment.staging] Cloning git:hudl/holmes
# 2017-06-19 17:43:48,474 [INFO] [holmes.experiment.staging] Checking out git:hudl/holmes:2addf6c84ba0ca6544946a602bf943553d36b693
# 2017-06-19 17:43:48,841 [INFO] [holmes.experiment.staging] Preparing distribution package
# 2017-06-19 17:43:51,482 [INFO] [holmes.experiment.staging] Staging distribution package
# 2017-06-19 17:43:51,483 [INFO] [holmes.experiment.staging] Commit staged
# 2017-06-19 17:43:51,484 [INFO] [holmes.experiment.staging] Removing Holmes Directory
# 2017-06-19 17:43:51,542 [INFO] [holmes.experiment.staging] Extracting default config from package

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
lost_thresholds = [2]
hungarian_thresholds = [10000]
minimum_detections = [60]

# %%
configs1 = []
list_configs=[]
for lt in lost_thresholds:
    for ht in hungarian_thresholds:
        for min_det in minimum_detections:
            for config in list_dicts:
                current_config_dict = config.copy()
                parameter_map = {"tracker_config.tracklet_config.lost_threshold": lt,"tracker_config.associator_config._class_name": 'SpatialAssociatorConfig', "tracker_config.associator_config.threshold": ht}
                flat_dict = flatten_dict(current_config_dict)
                flat_dict.update(parameter_map)
                updated_config_dict = expand_dict(flat_dict)
                updated_config_dict["filter_configs"] = [{"_class_name": 'BbAreaFilterConfig', 'min_detections': min_det, "max_pixel_area": 5000, "min_pixel_area": 100}]
                configs1.append(updated_config_dict)
                file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}-{:02d}-{:02d}.json".format(len(list_configs), 
                                                    current_config_dict['video_config']['video_id'], lt, ht, min_det))
                list_configs.append(file_name)
                with open(file_name, 'w') as f:
                    json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])
# Out:
# 20 /var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M00-CMPK1019-000-02-10000-60.json

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-LT-HT-DET-2-8", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-LT-HT-DET-2-8",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )
# Out:
# 2017-06-19 17:56:09,267 [INFO] [holmes.experiment.base] Verifying AWS staging area: s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()
# Out:
# 2017-06-19 17:56:21,493 [INFO] [holmes.experiment.base] staging measurement M00-CMPK1019-000-02-10000-60
# 2017-06-19 17:56:21,861 [WARNING] [holmes.experiment.base] S3 File expected but does not exist! This measurement may fail! s3_path=s3://hudl-holmes/recordings/childrens_mercy_park_kc/2016-10-19/detections_000.json
# 2017-06-19 17:56:22,360 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M00-CMPK1019-000-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M00-CMPK1019-000-02-10000-60.json
# 2017-06-19 17:56:22,715 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz
# 2017-06-19 17:56:23,820 [INFO] [holmes.experiment.base] staging measurement M01-LUS0114-000-02-10000-60
# 2017-06-19 17:56:24,233 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M01-LUS0114-000-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M01-LUS0114-000-02-10000-60.json
# 2017-06-19 17:56:24,615 [INFO] [holmes.experiment.base] staging measurement M02-LS0325-000-02-10000-60
# 2017-06-19 17:56:25,017 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M02-LS0325-000-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M02-LS0325-000-02-10000-60.json
# 2017-06-19 17:56:25,372 [INFO] [holmes.experiment.base] staging measurement M03-LS0325-001-02-10000-60
# 2017-06-19 17:56:25,781 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M03-LS0325-001-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M03-LS0325-001-02-10000-60.json
# 2017-06-19 17:56:26,209 [INFO] [holmes.experiment.base] staging measurement M04-SJP0201-000-02-10000-60
# 2017-06-19 17:56:26,660 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M04-SJP0201-000-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M04-SJP0201-000-02-10000-60.json
# 2017-06-19 17:56:27,104 [INFO] [holmes.experiment.base] staging measurement M05-SJP0201-001-02-10000-60
# 2017-06-19 17:56:27,573 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M05-SJP0201-001-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M05-SJP0201-001-02-10000-60.json
# 2017-06-19 17:56:27,924 [INFO] [holmes.experiment.base] staging measurement M06-PPS0221-000-02-10000-60
# 2017-06-19 17:56:28,326 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M06-PPS0221-000-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M06-PPS0221-000-02-10000-60.json
# 2017-06-19 17:56:28,687 [INFO] [holmes.experiment.base] staging measurement M07-PPS0221-001-02-10000-60
# 2017-06-19 17:56:29,096 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M07-PPS0221-001-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M07-PPS0221-001-02-10000-60.json
# 2017-06-19 17:56:29,434 [INFO] [holmes.experiment.base] staging measurement M08-CR0331-000-02-10000-60
# 2017-06-19 17:56:29,845 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M08-CR0331-000-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M08-CR0331-000-02-10000-60.json
# 2017-06-19 17:56:30,191 [INFO] [holmes.experiment.base] staging measurement M09-CR0331-001-02-10000-60
# 2017-06-19 17:56:30,489 [WARNING] [holmes.experiment.base] S3 File expected but does not exist! This measurement may fail! s3_path=s3://hudl-holmes/recordings/carrow_road/2017-03-31/detections_001.json
# 2017-06-19 17:56:30,782 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M09-CR0331-001-02-10000-60.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M09-CR0331-001-02-10000-60.json
# 2017-06-19 17:56:31,116 [INFO] [holmes.experiment.base] staging measurement M10-HS0401-000-02-10000-60
# 2017-06-19 17:56:31,393 [WARNING] [holmes.experiment.base] S3 File expected but does not exist! This measurement may fail! s3_path=s3://hudl-holmes/recordings/highbury_stadium/2017-04-01/detections_000.json
# 2017-06-19 17:56:31,672 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/

#       'x-amzn-trace-id': 'sampled=0;root=1-59485627-08b79ddd073ba12cebc954c9',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': '4153c23c-5542-11e7-b853-7d5f6d616178',
#      'RetryAttempts': 0},
#     'jobId': '7d67f43b-823b-4a33-b243-65aba6b645c4',
#     'jobName': 'PTA-95-LT-HT-DET-2-8-M17-SJP0401-001-02-10000-60'},
#    'measurement_id': 'M17-SJP0401-001-02-10000-60',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M18-MS0404-000-02-10000-60.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-2-8',
#    'job_id': 'PTA-95-LT-HT-DET-2-8-M18-MS0404-000-02-10000-60',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '108',
#       'content-type': 'application/json',
#       'date': 'Mon, 19 Jun 2017 22:54:31 GMT',
#       'via': '1.1 9438b4fa578cbce283b48cf092373802.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'N5rszPE2VM9DmWi0xS0MUHtfwPSzsASGuMWDwZTsrIMSh5rXq5ZRog==',
#       'x-amzn-requestid': '41721f1a-5542-11e7-a6a1-45649cf81419',
#       'x-amzn-trace-id': 'sampled=0;root=1-59485627-5248ef7a228b39a3f7d3977c',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': '41721f1a-5542-11e7-a6a1-45649cf81419',
#      'RetryAttempts': 0},
#     'jobId': '90ac99e8-5af7-4d92-a387-c6c2bb158561',
#     'jobName': 'PTA-95-LT-HT-DET-2-8-M18-MS0404-000-02-10000-60'},
#    'measurement_id': 'M18-MS0404-000-02-10000-60',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/M19-MS0404-001-02-10000-60.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-2-8',
#    'job_id': 'PTA-95-LT-HT-DET-2-8-M19-MS0404-001-02-10000-60',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '108',
#       'content-type': 'application/json',
#       'date': 'Mon, 19 Jun 2017 22:54:31 GMT',
#       'via': '1.1 1e3fbf61cd1af39f92484080b6bb8ef0.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'tzZuOyv8iZk8xu_ekA5t2YIYD8PIscT6jZCheadVNCFXeYwH-HSEXA==',
#       'x-amzn-requestid': '41929fb6-5542-11e7-a68c-916c425c66fb',
#       'x-amzn-trace-id': 'sampled=0;root=1-59485627-787ab46f1ba4e3bf8028d6a1',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': '41929fb6-5542-11e7-a68c-916c425c66fb',
#      'RetryAttempts': 0},
#     'jobId': '11ba4ea6-0b31-44bb-b566-b0df622f1b65',
#     'jobName': 'PTA-95-LT-HT-DET-2-8-M19-MS0404-001-02-10000-60'},
#    'measurement_id': 'M19-MS0404-001-02-10000-60',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-8/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz'}]}

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
lost_thresholds = [1]
hungarian_thresholds = [14]
minimum_detections = [9]

# %%
configs2 = []
list_configs=[]
for lt in lost_thresholds:
    for ht in hungarian_thresholds:
        for min_det in minimum_detections:
            for config in list_dicts:
                current_config_dict = config.copy()
                parameter_map = {"tracker_config.tracklet_config.lost_threshold": lt,"tracker_config.associator_config._class_name": 'SpatialAssociatorConfig', "tracker_config.associator_config.threshold": ht}
                flat_dict = flatten_dict(current_config_dict)
                flat_dict.update(parameter_map)
                updated_config_dict = expand_dict(flat_dict)
                updated_config_dict["filter_configs"] = [{"_class_name": 'BbAreaFilterConfig', 'min_detections': min_det, "max_pixel_area": 5000, "min_pixel_area": 100}]
                configs2.append(updated_config_dict)
                file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}-{:02d}-{:02d}.json".format(len(list_configs), 
                                                    current_config_dict['video_config']['video_id'], lt, ht, min_det))
                list_configs.append(file_name)
                with open(file_name, 'w') as f:
                    json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])
# Out:
# 20 /var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M00-CMPK1019-000-01-14-09.json

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-LT-HT-DET-2-9", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-LT-HT-DET-2-9",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )
# Out:
# 2017-06-19 17:57:24,355 [INFO] [holmes.experiment.base] Verifying AWS staging area: s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()
# Out:
# 2017-06-19 17:57:27,949 [INFO] [holmes.experiment.base] staging measurement M00-CMPK1019-000-01-14-09
# 2017-06-19 17:57:28,306 [WARNING] [holmes.experiment.base] S3 File expected but does not exist! This measurement may fail! s3_path=s3://hudl-holmes/recordings/childrens_mercy_park_kc/2016-10-19/detections_000.json
# 2017-06-19 17:57:28,590 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M00-CMPK1019-000-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M00-CMPK1019-000-01-14-09.json
# 2017-06-19 17:57:29,342 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz
# 2017-06-19 17:57:30,353 [INFO] [holmes.experiment.base] staging measurement M01-LUS0114-000-01-14-09
# 2017-06-19 17:57:30,797 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M01-LUS0114-000-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M01-LUS0114-000-01-14-09.json
# 2017-06-19 17:57:31,140 [INFO] [holmes.experiment.base] staging measurement M02-LS0325-000-01-14-09
# 2017-06-19 17:57:31,677 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M02-LS0325-000-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M02-LS0325-000-01-14-09.json
# 2017-06-19 17:57:32,027 [INFO] [holmes.experiment.base] staging measurement M03-LS0325-001-01-14-09
# 2017-06-19 17:57:33,276 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M03-LS0325-001-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M03-LS0325-001-01-14-09.json
# 2017-06-19 17:57:33,617 [INFO] [holmes.experiment.base] staging measurement M04-SJP0201-000-01-14-09
# 2017-06-19 17:57:34,053 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M04-SJP0201-000-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M04-SJP0201-000-01-14-09.json
# 2017-06-19 17:57:34,418 [INFO] [holmes.experiment.base] staging measurement M05-SJP0201-001-01-14-09
# 2017-06-19 17:57:34,858 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M05-SJP0201-001-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M05-SJP0201-001-01-14-09.json
# 2017-06-19 17:57:35,200 [INFO] [holmes.experiment.base] staging measurement M06-PPS0221-000-01-14-09
# 2017-06-19 17:57:35,683 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M06-PPS0221-000-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M06-PPS0221-000-01-14-09.json
# 2017-06-19 17:57:36,014 [INFO] [holmes.experiment.base] staging measurement M07-PPS0221-001-01-14-09
# 2017-06-19 17:57:36,471 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M07-PPS0221-001-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M07-PPS0221-001-01-14-09.json
# 2017-06-19 17:57:36,799 [INFO] [holmes.experiment.base] staging measurement M08-CR0331-000-01-14-09
# 2017-06-19 17:57:37,196 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M08-CR0331-000-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M08-CR0331-000-01-14-09.json
# 2017-06-19 17:57:37,533 [INFO] [holmes.experiment.base] staging measurement M09-CR0331-001-01-14-09
# 2017-06-19 17:57:37,808 [WARNING] [holmes.experiment.base] S3 File expected but does not exist! This measurement may fail! s3_path=s3://hudl-holmes/recordings/carrow_road/2017-03-31/detections_001.json
# 2017-06-19 17:57:38,095 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M09-CR0331-001-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M09-CR0331-001-01-14-09.json
# 2017-06-19 17:57:38,425 [INFO] [holmes.experiment.base] staging measurement M10-HS0401-000-01-14-09
# 2017-06-19 17:57:38,691 [WARNING] [holmes.experiment.base] S3 File expected but does not exist! This measurement may fail! s3_path=s3://hudl-holmes/recordings/highbury_stadium/2017-04-01/detections_000.json
# 2017-06-19 17:57:38,984 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpq1y_rad6/M10-HS0401-000-01-14-09.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M10-HS0401-000-01-14-09.json
# 2017-06-19 17:57:39,322 [INFO] [holmes.experiment.base] staging measurement M11-HS0401-001-01-14-09
# 2017-06-19 17:57:39,676 [WARNING] [holmes.experiment.base] S3 File expected but does not exist! This measurement may fail! s3_path=s3://hudl-holmes/recordings

#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': '6c3a455f-5542-11e7-99d2-b57db50dc317',
#      'RetryAttempts': 0},
#     'jobId': 'eb94a1f5-dc07-4071-8bd6-e1b51bffd412',
#     'jobName': 'PTA-95-LT-HT-DET-2-9-M17-SJP0401-001-01-14-09'},
#    'measurement_id': 'M17-SJP0401-001-01-14-09',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M18-MS0404-000-01-14-09.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-2-9',
#    'job_id': 'PTA-95-LT-HT-DET-2-9-M18-MS0404-000-01-14-09',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Mon, 19 Jun 2017 22:55:43 GMT',
#       'via': '1.1 8fb8ee88d9921a973386204b4edaab26.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'keB9NyOldyUJ8ycV5Dab6I_9yvSARFI7UJ5W26T4vy3LhdBsT3MWuw==',
#       'x-amzn-requestid': '6c57defd-5542-11e7-a44e-7f1592e19806',
#       'x-amzn-trace-id': 'sampled=0;root=1-5948566f-700c576f9ca36d64871c18f9',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': '6c57defd-5542-11e7-a44e-7f1592e19806',
#      'RetryAttempts': 0},
#     'jobId': '5d19b1cb-ed0e-4d45-886b-d488e3d8db7d',
#     'jobName': 'PTA-95-LT-HT-DET-2-9-M18-MS0404-000-01-14-09'},
#    'measurement_id': 'M18-MS0404-000-01-14-09',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/M19-MS0404-001-01-14-09.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-2-9',
#    'job_id': 'PTA-95-LT-HT-DET-2-9-M19-MS0404-001-01-14-09',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Mon, 19 Jun 2017 22:55:43 GMT',
#       'via': '1.1 9438b4fa578cbce283b48cf092373802.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'qDV7DdSvK14FyTJVnwm7jcg3YlmlYIUaDZUvzwcogAU2Kco13VTulw==',
#       'x-amzn-requestid': '6c75eeb8-5542-11e7-bdc1-8933d23942e0',
#       'x-amzn-trace-id': 'sampled=0;root=1-5948566f-5a9b5cc47bb8b3c8b2c807ca',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': '6c75eeb8-5542-11e7-bdc1-8933d23942e0',
#      'RetryAttempts': 0},
#     'jobId': '5d97b617-662b-460a-babe-1e402be07def',
#     'jobName': 'PTA-95-LT-HT-DET-2-9-M19-MS0404-001-01-14-09'},
#    'measurement_id': 'M19-MS0404-001-01-14-09',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-9/deps/2addf6c84ba0ca6544946a602bf943553d36b693.tar.gz'}]}

# %%
from holmes.io import Retrieve
import re

# %%
paths1=[]
for m in experiment.measurements:
    measurement_path = m.__dict__['_s3_measurement_path']
    video_id = ''.join(re.match(r'.*/M\d{2}-(\w+)(-{1})(\d+)-.*', measurement_path).groups())
    path = m.__dict__['_s3_measurement_path']+'/trajectory_results_{}.json'.format(video_id)
    paths1.append(path)

# %%
paths2=[]
for m in experiment.measurements:
    measurement_path = m.__dict__['_s3_measurement_path']
    video_id = ''.join(re.match(r'.*/M\d{2}-(\w+)(-{1})(\d+)-.*', measurement_path).groups())
    path = m.__dict__['_s3_measurement_path']+'/trajectory_results_{}.json'.format(video_id)
    paths2.append(path)

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.DataFrame({'game':[],'mota':[],'fnr':[],'fpr':[],'mr':[],'lt':[],'ht':[],'det':[],'job_id':[],'params':[]})
for i,j in enumerate([Retrieve(j) for j in paths1[1:9]]):
    with open(j.local_path, 'r') as fp:
        results = json.load(fp)
        game = results['video_id'][0:11]
        mota = results['MOTA']
        fnr = results['False negative rate']
        fpr = results['False positive rate']
        mr = results['Mismatch rate']
        lt = configs1[i]["tracker_config"]["tracklet_config"]["lost_threshold"]
        ht = configs1[i]['tracker_config']['associator_config']['threshold']
        det = configs1[i]['filter_configs'][0]['min_detections']
        job_id = paths1[i][29:78].replace('/','-')
        params = 'before'
        row = pd.DataFrame({'game':[game],'mota':[mota],'fnr':[fnr],'fpr':[fpr],'mr':[mr],'lt':[lt],'ht':[ht],
                            'det':[det],'job_id':[job_id],'params':[params]})
        data1 = data1.append(row)
data1[['lt','ht','det']] = data1[['lt','ht','det']].applymap(np.int64)

# %%
data1
# Out:
#    det       fnr       fpr         game     ht  \
# 0   60  0.283666  0.092815  LUS0114-000  10000
# 0   60  0.051093  0.076236   LS0325-000  10000
# 0   60  0.067952  0.095373   LS0325-001  10000
# 0   60  0.103661  0.054203  SJP0201-000  10000
# 0   60  0.109491  0.066118  SJP0201-001  10000
# 0   60  0.064064  0.103553  PPS0221-000  10000
# 0   60  0.074196  0.106353  PPS0221-001  10000
# 0   60  0.085254  0.082948   CR0331-000  10000
#
#                                               job_id  lt      mota        mr  \
# 0  PTA-95-LT-HT-DET-2-8-M00-CMPK1019-000-02-10000-60   2  0.558060  0.026185
# 0  PTA-95-LT-HT-DET-2-8-M01-LUS0114-000-02-10000-60-   2  0.797505  0.017072
# 0  PTA-95-LT-HT-DET-2-8-M02-LS0325-000-02-10000-60-t   2  0.759737  0.019034
# 0  PTA-95-LT-HT-DET-2-8-M03-LS0325-001-02-10000-60-t   2  0.772542  0.015066
# 0  PTA-95-LT-HT-DET-2-8-M04-SJP0201-000-02-10000-60-   2  0.751382  0.016019
# 0  PTA-95-LT-HT-DET-2-8-M05-SJP0201-001-02-10000-60-   2  0.751159  0.016419
# 0  PTA-95-LT-HT-DET-2-8-M06-PPS0221-000-02-10000-60-   2  0.729521  0.017877
# 0  PTA-95-LT-HT-DET-2-8-M07-PPS0221-001-02-10000-60-   2  0.721691  0.021709
#
#    params
# 0  before
# 0  before
# 0  before
# 0  before
# 0  before
# 0  before
# 0  before
# 0  before

# %%
data2 = pd.DataFrame({'game':[],'mota':[],'fnr':[],'fpr':[],'mr':[],'lt':[],'ht':[],'det':[],'job_id':[],'params':[]})
for i,j in enumerate([Retrieve(j) for j in paths2[1:9]]):
    with open(j.local_path, 'r') as fp:
        results = json.load(fp)
        game = results['video_id'][0:11]
        mota = results['MOTA']
        fnr = results['False negative rate']
        fpr = results['False positive rate']
        mr = results['Mismatch rate']
        lt = configs2[i]["tracker_config"]["tracklet_config"]["lost_threshold"]
        ht = configs2[i]['tracker_config']['associator_config']['threshold']
        det = configs2[i]['filter_configs'][0]['min_detections']
        job_id = paths2[i][29:73].replace('/','-')
        params = 'after'
        row = pd.DataFrame({'game':[game],'mota':[mota],'fnr':[fnr],'fpr':[fpr],'mr':[mr],'lt':[lt],'ht':[ht],
                            'det':[det],'job_id':[job_id],'params':[params]})
        data2 = data2.append(row)
data2[['lt','ht','det']] = data2[['lt','ht','det']].applymap(np.int64)

# %%
data2
# Out:
#    det       fnr       fpr         game  ht  \
# 0    9  0.271386  0.088304  LUS0114-000  14
# 0    9  0.039579  0.072273   LS0325-000  14
# 0    9  0.057727  0.089081   LS0325-001  14
# 0    9  0.091837  0.048305  SJP0201-000  14
# 0    9  0.102305  0.059866  SJP0201-001  14
# 0    9  0.048859  0.103597  PPS0221-000  14
# 0    9  0.061363  0.106967  PPS0221-001  14
# 0    9  0.078154  0.074011   CR0331-000  14
#
#                                          job_id  lt      mota        mr params
# 0  PTA-95-LT-HT-DET-2-9-M00-CMPK1019-000-01-14-   1  0.592827  0.018308  after
# 0  PTA-95-LT-HT-DET-2-9-M01-LUS0114-000-01-14-0   1  0.827124  0.014058  after
# 0  PTA-95-LT-HT-DET-2-9-M02-LS0325-000-01-14-09   1  0.791897  0.015096  after
# 0  PTA-95-LT-HT-DET-2-9-M03-LS0325-001-01-14-09   1  0.796607  0.014079  after
# 0  PTA-95-LT-HT-DET-2-9-M04-SJP0201-000-01-14-0   1  0.776823  0.013939  after
# 0  PTA-95-LT-HT-DET-2-9-M05-SJP0201-001-01-14-0   1  0.775192  0.014358  after
# 0  PTA-95-LT-HT-DET-2-9-M06-PPS0221-000-01-14-0   1  0.752030  0.014984  after
# 0  PTA-95-LT-HT-DET-2-9-M07-PPS0221-001-01-14-0   1  0.758993  0.017121  after

# %%
data = data1.append(data2)

# %%
from bokeh.charts import Scatter, Line
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="13961ddb-787e-4bd4-be78-69d90be9763c">Loading BokehJS ...</span>
#     </div>

# %%
df = data.loc[:,['game','params','mota']]
df
# Out:
#           game  params      mota
# 0  LUS0114-000  before  0.558060
# 0   LS0325-000  before  0.797505
# 0   LS0325-001  before  0.759737
# 0  SJP0201-000  before  0.772542
# 0  SJP0201-001  before  0.751382
# 0  PPS0221-000  before  0.751159
# 0  PPS0221-001  before  0.729521
# 0   CR0331-000  before  0.721691
# 0  LUS0114-000   after  0.592827
# 0   LS0325-000   after  0.827124
# 0   LS0325-001   after  0.791897
# 0  SJP0201-000   after  0.796607
# 0  SJP0201-001   after  0.776823
# 0  PPS0221-000   after  0.775192
# 0  PPS0221-001   after  0.752030
# 0   CR0331-000   after  0.758993

# %%
plot1 = Scatter(df, x='game', y='mota', color='params')
show(plot1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="40b866b5-fe2b-4cf2-849a-f60d53be7d70"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("40b866b5-fe2b-4cf2-849a-f60d53be7d70");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("40b866b5-fe2b-4cf2-849a-f60d53be7d70");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '40b866b5-fe2b-4cf2-849a-f60d53be7d70' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ba3d31b0-6243-4acc-8f15-330814788cc8":{"roots":{"references":[{"attributes":{"label":{"value":"after"},"renderers":[{"id":"c06a3946-0cca-49b2-9de6-5971938494b1","type":"GlyphRenderer"}]},"id":"3b0525e7-a0a3-47cb-b08b-ac314c1ae32d","type":"LegendItem"},{"attributes":{"plot":{"id":"bd182afa-133d-4189-8307-d506a5ee3e55","subtype":"Chart","type":"Plot"}},"id":"ccebea9f-4016-42b2-96db-75c9e0b8ee60","type":"ResetTool"},{"attributes":{},"id":"536a713a-f028-4996-afe2-7a71b9c2cf85","type":"CategoricalTicker"},{"attributes":{"callback":null,"factors":["LUS0114-000","LS0325-000","LS0325-001","SJP0201-000","SJP0201-001","PPS0221-000","PPS0221-001","CR0331-000"]},"id":"2e4eaf18-079a-4c63-b514-b59e13316d79","type":"FactorRange"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"0ea9158f-f952-4f88-af0e-70ac54f1d9bc","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"bd182afa-133d-4189-8307-d506a5ee3e55","subtype":"Chart","type":"Plot"},"ticker":{"id":"7a1e6eba-d01f-4314-bad1-f5825b866f51","type":"BasicTicker"}},"id":"25d82009-3acc-4033-a822-3657458ff0bd","type":"Grid"},{"attributes":{"plot":{"id":"bd182afa-133d-4189-8307-d506a5ee3e55","subtype":"Chart","type":"Plot"}},"id":"6a931777-a88b-4741-b806-2a6dbc7883c5","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"a021e647-92ca-4f2c-b485-d29b576a8562","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"43369469-f911-49b2-b4a9-bca01eb97cac","type":"LinearAxis"}],"renderers":[{"id":"6819fdec-c29a-4311-b5b8-8bcc4f96471b","type":"BoxAnnotation"},{"id":"c2cb513a-8ab5-4441-96c0-5e93fd128306","type":"GlyphRenderer"},{"id":"c06a3946-0cca-49b2-9de6-5971938494b1","type":"GlyphRenderer"},{"id":"a96120cd-7db1-4c1c-bc5f-ab772a022ccc","type":"Legend"},{"id":"a021e647-92ca-4f2c-b485-d29b576a8562","type":"CategoricalAxis"},{"id":"43369469-f911-49b2-b4a9-bca01eb97cac","type":"LinearAxis"},{"id":"7a4ba3cc-3ba9-4008-8b6c-d55bff35b913","type":"Grid"},{"id":"25d82009-3acc-4033-a822-3657458ff0bd","type":"Grid"}],"title":{"id":"4d6c60fe-d0ba-4f21-ae4a-7a8eae218600","type":"Title"},"tool_events":{"id":"5ff5cbbb-1a59-4d28-8d0a-b07018ee583c","type":"ToolEvents"},"toolbar":{"id":"b45a1a24-3421-4805-b906-be1c3ea7640d","type":"Toolbar"},"x_range":{"id":"2e4eaf18-079a-4c63-b514-b59e13316d79","type":"FactorRange"},"x_scale":{"id":"5bccf440-6395-4051-99a9-83a6917c3e99","type":"CategoricalScale"},"y_range":{"id":"92357873-244e-4db5-b188-a96e2046a75b","type":"Range1d"},"y_scale":{"id":"2ddcf4fc-e1d2-4908-abb6-0b5b24c12eac","type":"LinearScale"}},"id":"bd182afa-133d-4189-8307-d506a5ee3e55","subtype":"Chart","type":"Plot"},{"attributes":{"label":{"value":"before"},"renderers":[{"id":"c2cb513a-8ab5-4441-96c0-5e93fd128306","type":"GlyphRenderer"}]},"id":"f53cac8b-cf0d-4b1d-b25e-c8abfbdb94c4","type":"LegendItem"},{"attributes":{"axis_label":"mota","formatter":{"id":"33c57520-4142-4298-b8c8-ef44883e0abc","type":"BasicTickFormatter"},"plot":{"id":"bd182afa-133d-4189-8307-d506a5ee3e55","subtype":"Chart","type":"Plot"},"ticker":{"id":"7a1e6eba-d01f-4314-bad1-f5825b866f51","type":"BasicTicker"}},"id":"43369469-f911-49b2-b4a9-bca01eb97cac","type":"LinearAxis"},{"attributes":{},"id":"5ff5cbbb-1a59-4d28-8d0a-b07018ee583c","type":"ToolEvents"},{"attributes":{"data_source":{"id":"f54a9786-3cd8-446f-918f-362b266a8646","type":"ColumnDataSource"},"glyph":{"id":"a1320542-e45b-47e4-9350-74edf46eefe8","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"c2cb513a-8ab5-4441-96c0-5e93fd128306","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"868c8466-a391-4ce7-9f14-ae350ec2cd85","type":"PanTool"},{"id":"6a931777-a88b-4741-b806-2a6dbc7883c5","type":"WheelZoomTool"},{"id":"5904ab17-210e-49ef-b1e8-072eee07eda1","type":"BoxZoomTool"},{"id":"4df6fb2d-4086- ...

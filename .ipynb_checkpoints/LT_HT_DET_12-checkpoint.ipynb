
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-2-3/deps/7e2a704c4b5954fe403efd4925e045c672af82b5.tar.gz'}]}

# %%
from holmes.io import Retrieve
import re

# %%
paths=[]
for m in experiment.measurements:
    measurement_path = m.__dict__['_s3_measurement_path']
    video_id = ''.join(re.match(r'.*/M\d{2}-(\w+)(-{1})(\d+)-.*', measurement_path).groups())
    path = m.__dict__['_s3_measurement_path']+'/trajectory_results_{}.json'.format(video_id)
    paths.append(path)

# %%
configs[0]
# Out:
# {'checkpoint_freq': 1500,
#  'detector_config': {'_class_name': 'PassThroughDetectorConfig',
#   'batch_size': 1,
#   'source_path': 's3://hudl-holmes/recordings/stamford_bridge/chelsea_v_utd_u21/detections_000.json'},
#  'filter_configs': [{'_class_name': 'BbAreaFilterConfig',
#    'max_pixel_area': 5000,
#    'min_detections': 5,
#    'min_pixel_area': 100}],
#  'output_location': '/otp/output/',
#  'start_frame': 0,
#  'tracker_config': {'_class_name': 'OnlineTrackerConfig',
#   'associator_config': {'_class_name': 'SpatialAssociatorConfig',
#    'threshold': 10},
#   'tracklet_config': {'_class_name': 'SimpleTrackletConfig',
#    'lost_threshold': 1,
#    'motion_model_config': {'_class_name': 'DummyMotionModelConfig'}}},
#  'video_config': {'_class_name': 'RawVideoConfig',
#   'ground_truth_path': 's3://hudl-holmes/recordings/stamford_bridge/chelsea_v_utd_u21/truth_000.json',
#   'video_id': 'ChvUtd-000',
#   'video_path': 's3://hudl-holmes/recordings/stamford_bridge/chelsea_v_utd_u21/processed_000.mp4'}}

# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame({'game':[],'mota':[],'fnr':[],'fpr':[],'mr':[],'lt':[],'ht':[],'det':[],'job_id':[]})
for i,j in enumerate([Retrieve(j) for j in paths]):
    with open(j.local_path, 'r') as fp:
        results = json.load(fp)
        game = results['video_id'][0:6]
        mota = results['MOTA']
        fnr = results['False negative rate']
        fpr = results['False positive rate']
        mr = results['Mismatch rate']
        lt = configs[i]["tracker_config"]["tracklet_config"]["lost_threshold"]
        ht = configs[i]['tracker_config']['associator_config']['threshold']
        det = configs[i]['filter_configs'][0]['min_detections']
        job_id = paths[i][29:73].replace('/','-')
        row = pd.DataFrame({'game':[game],'mota':[mota],'fnr':[fnr],'fpr':[fpr],'mr':[mr],'lt':[lt],'ht':[ht],
                            'det':[det],'job_id':[job_id]})
        data = data.append(row)
data[['lt','ht','det']] = data[['lt','ht','det']].applymap(np.int64)
data
# Out:
#    det       fnr       fpr    game  ht  \
# 0    5  0.117648  0.062582  ChvUtd  10
# 0    5  0.091453  0.096575  PS0304  10
# 0    5  0.064231  0.011991  PP0214  10
# 0    5  0.187523  0.047598  ER0429  10
# 0   10  0.137533  0.054737  ChvUtd  10
# 0   10  0.108998  0.090956  PS0304  10
# 0   10  0.075446  0.010330  PP0214  10
# 0   10  0.212131  0.038897  ER0429  10
# 0    5  0.110827  0.066717  ChvUtd  15
# 0    5  0.088305  0.096469  PS0304  15
# 0    5  0.062571  0.012266  PP0214  15
# 0    5  0.183699  0.050313  ER0429  15
# 0   10  0.117705  0.062615  ChvUtd  15
# 0   10  0.100893  0.091593  PS0304  15
# 0   10  0.069881  0.010724  PP0214  15
# 0   10  0.201792  0.042879  ER0429  15
#
#                                          job_id  lt      mota        mr
# 0  PTA-95-LT-HT-DET-2-3-M00-ChvUtd-000-01-10-05   1  0.788991  0.014075
# 0  PTA-95-LT-HT-DET-2-3-M01-PS0304-001-01-10-05   1  0.765545  0.015267
# 0  PTA-95-LT-HT-DET-2-3-M02-PP0214-000-01-10-05   1  0.868661  0.012821
# 0  PTA-95-LT-HT-DET-2-3-M03-ER0429-001-01-10-05   1  0.672556  0.024356
# 0  PTA-95-LT-HT-DET-2-3-M04-ChvUtd-000-01-10-10   1  0.786417  0.009778
# 0  PTA-95-LT-HT-DET-2-3-M05-PS0304-001-01-10-10   1  0.766169  0.012071
# 0  PTA-95-LT-HT-DET-2-3-M06-PP0214-000-01-10-10   1  0.871528  0.010600
# 0  PTA-95-LT-HT-DET-2-3-M07-ER0429-001-01-10-10   1  0.679268  0.019010
# 0  PTA-95-LT-HT-DET-2-3-M08-ChvUtd-000-01-15-05   1  0.794756  0.009100
# 0  PTA-95-LT-HT-DET-2-3-M09-PS0304-001-01-15-05   1  0.767768  0.013757
# 0  PTA-95-LT-HT-DET-2-3-M10-PP0214-000-01-15-05   1  0.869046  0.011687
# 0  PTA-95-LT-HT-DET-2-3-M11-ER0429-001-01-15-05   1  0.669711  0.024046
# 0  PTA-95-LT-HT-DET-2-3-M12-ChvUtd-000-01-15-10   1  0.797789  0.007484
# 0  PTA-95-LT-HT-DET-2-3-M13-PS0304-001-01-15-10   1  0.770373  0.011462
# 0  PTA-95-LT-HT-DET-2-3-M14-PP0214-000-01-15-10   1  0.873889  0.010191
# 0  PTA-95-LT-HT-DET-2-3-M15-ER0429-001-01-15-10   1  0.677562  0.020032

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2b5527f8-f99d-4681-8594-1cb890b48c34">Loading BokehJS ...</span>
#     </div>

# %%
data_lt_ht_det = data.copy()
data_lt_ht_det['lost'] = data_lt_ht_det['lt']
data_lt_ht_det['hungarian'] = data_lt_ht_det['ht']
data_lt_ht_det['detections'] = data_lt_ht_det['det']
data_lt_ht_det = data_lt_ht_det.loc[:,['mota','ht', 'lt', 'det', 'lost', 'hungarian', 'detections']].groupby(['ht','lt','det']).mean()
data_lt_ht_det
# Out:
#                mota  lost  hungarian  detections
# ht lt det
# 10 1  5    0.773938     1         10           5
#       10   0.775845     1         10          10
# 15 1  5    0.775320     1         15           5
#       10   0.779903     1         15          10

# %%
scat_lt_ht_det_1 = Scatter(data_lt_ht_det, x='hungarian', y='mota', color='detections', marker='lost')
show(scat_lt_ht_det_1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b00c07e6-3b00-4ad8-b51b-75c9b136549f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b00c07e6-3b00-4ad8-b51b-75c9b136549f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b00c07e6-3b00-4ad8-b51b-75c9b136549f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b00c07e6-3b00-4ad8-b51b-75c9b136549f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bfe9607e-ff73-4fc2-bd2e-6ae8c1f6b618":{"roots":{"references":[{"attributes":{},"id":"c7e53620-4263-4ca6-8e15-f184ffd4d78e","type":"BasicTicker"},{"attributes":{"plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"},"ticker":{"id":"2880b9e9-e95a-48ca-92a7-88221a4c9b6c","type":"BasicTicker"}},"id":"29783e2a-8dff-4f71-b249-525fe19f89a4","type":"Grid"},{"attributes":{},"id":"cf45af85-4f9a-4a80-810a-12098481bd03","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"(5, 1)"},"renderers":[{"id":"c3327235-16d8-4931-8e93-7b79db6ff609","type":"GlyphRenderer"}]},"id":"61a6cd9a-a1d9-4f09-85a0-94ed64fdedc4","type":"LegendItem"},{"attributes":{"data_source":{"id":"09e8d03d-77d8-4874-921d-843886c922f6","type":"ColumnDataSource"},"glyph":{"id":"c3b158e4-a29b-408f-97a2-03372da1ac1b","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"0142440d-56d8-4c27-b6cc-c027c5735b42","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"}},"id":"264e7b9c-8dda-4975-adc6-672d0bb38d3d","type":"SaveTool"},{"attributes":{"callback":null,"end":15.5,"start":9.5},"id":"0ec9b4fc-6c06-4798-9571-012879aa9b6c","type":"Range1d"},{"attributes":{"label":{"value":"(10, 1)"},"renderers":[{"id":"0142440d-56d8-4c27-b6cc-c027c5735b42","type":"GlyphRenderer"}]},"id":"16ff8ca3-4c4a-4054-b6e2-65e9370ece05","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a8f0a8c0-8355-4595-956e-a3f9418a5550","type":"PanTool"},{"id":"284d803d-257d-4c3e-baa3-73699e09f031","type":"WheelZoomTool"},{"id":"d705ee35-2286-445c-9cb4-535d48550cb3","type":"BoxZoomTool"},{"id":"264e7b9c-8dda-4975-adc6-672d0bb38d3d","type":"SaveTool"},{"id":"00f1e1fb-a50f-4fd0-a52c-63f4259cbfe3","type":"ResetTool"},{"id":"193ad2c6-f18b-41d1-8764-8296cc485c6e","type":"HelpTool"}]},"id":"2e92c079-62a7-4a80-b15a-64c20ec35950","type":"Toolbar"},{"attributes":{},"id":"c63719e5-6e85-4635-bd57-2859943a50b9","type":"LinearScale"},{"attributes":{"plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"}},"id":"a8f0a8c0-8355-4595-956e-a3f9418a5550","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"},"ticker":{"id":"c7e53620-4263-4ca6-8e15-f184ffd4d78e","type":"BasicTicker"}},"id":"5a86f17c-e30f-4efc-a304-bb07d0d375e9","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"detections":5,"lost":1},{"detections":5,"lost":1}],"detections":[5,5],"lost":[1,1],"x_values":[10,15],"y_values":{"__ndarray__":"bhZsARrE6D+8YugUbM/oPw==","dtype":"float64","shape":[2]}}},"id":"a47c4cb0-e25f-4057-9131-9d96c424572a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"}},"id":"284d803d-257d-4c3e-baa3-73699e09f031","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":0.7804998576507319,"start":0.7733416656665145},"id":"d6251632-cfa4-49f6-87c2-41e7ea94cd6e","type":"Range1d"},{"attributes":{"overlay":{"id":"7aca0a8e-209b-40d0-b7b9-1576e4efd3e7","type":"BoxAnnotation"},"plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"}},"id":"d705ee35-2286-445c-9cb4-535d48550cb3","type":"BoxZoomTool"},{"attributes":{"items":[{"id":"61a6cd9a-a1d9-4f09-85a0-94ed64fdedc4","type":"LegendItem"},{"id":"16ff8ca3-4c4a-4054-b6e2-65e9370ece05","type":"LegendItem"}],"location":"top_left","plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"}},"id":"070172b6-7969-456b-b570-fce8b365afac","type":"Legend"},{"attributes":{"plot":null,"text":null},"id":"f2b7fe7a-c45b-4f47-89a1-8b2ff75cf4a7","type":"Title"},{"attributes":{"plot":{"id":"107adf4d-089e-4ad6-a3ae-f8ef713620e7","subtype":"Chart","type":"Plot"}},"id":"00f1e1fb-a50f-4fd0-a52c-63f4259cbfe3","type": ...

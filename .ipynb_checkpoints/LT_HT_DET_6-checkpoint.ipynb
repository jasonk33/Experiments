# %%
import holmes.experiment as Ex
import tempfile
import pprint
import json
import os
from terrarium.flatten import flatten_dict, expand_dict
import tempfile

# %%
temp_dir_obj = tempfile.TemporaryDirectory()
temp_dir = temp_dir_obj.name
package_location = Ex.staging.prep_holmes_package(
    staging_path=temp_dir, 
    commit_hash='ca6ccd63f270d603ffa9bdf5a7ced184d6339796'
)

detects_dict={}
for video_data in Ex.val_data:
    detects_dict[video_data['video_id']] = video_data['video_path'].replace('processed','detections')

def_conf_path = Ex.staging.extract_default_config(package_location, temp_dir)

with open(def_conf_path, 'r') as fp:
    def_conf_dict = json.load(fp)

new_def_conf_dicts={}
list_dicts=[]
for video_data in Ex.val_data:
    new_def_conf_dict = def_conf_dict.copy()
    detects_path = video_data['video_path'].replace('processed','detections').replace('.mp4', '.json')
    new_def_conf_dict['detector_config'] = {"source_path": detects_path,"_class_name": "PassThroughDetectorConfig","batch_size": 1}
    new_def_conf_dict['video_config'] = video_data
    new_def_conf_dict['video_config']['_class_name'] = 'RawVideoConfig'
    list_dicts.append(new_def_conf_dict)
# Out:
# 2017-06-17 22:48:30,964 [INFO] [holmes.experiment.staging] Preparing holmes payload
# 2017-06-17 22:48:30,966 [INFO] [holmes.experiment.staging] Cloning git:hudl/holmes
# 2017-06-17 22:48:33,878 [INFO] [holmes.experiment.staging] Checking out git:hudl/holmes:ca6ccd63f270d603ffa9bdf5a7ced184d6339796
# 2017-06-17 22:48:34,221 [INFO] [holmes.experiment.staging] Preparing distribution package
# 2017-06-17 22:48:36,927 [INFO] [holmes.experiment.staging] Staging distribution package
# 2017-06-17 22:48:36,928 [INFO] [holmes.experiment.staging] Commit staged
# 2017-06-17 22:48:36,929 [INFO] [holmes.experiment.staging] Removing Holmes Directory
# 2017-06-17 22:48:36,982 [INFO] [holmes.experiment.staging] Extracting default config from package

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
lost_thresholds = [4,5]
hungarian_thresholds = [10,15,20]
minimum_detections = [25]

# %%
list_configs=[]
for lt in lost_thresholds:
    for ht in hungarian_thresholds:
        for min_det in minimum_detections:
            for config in list_dicts:
                current_config_dict = config.copy()
                parameter_map = {"tracker_config.tracklet_config.lost_threshold": lt,"tracker_config.associator_config._class_name": 'SpatialAssociatorConfig', "tracker_config.associator_config.threshold": ht}
                flat_dict = flatten_dict(current_config_dict)
                flat_dict.update(parameter_map)
                updated_config_dict = expand_dict(flat_dict)
                updated_config_dict["filter_configs"] = [{"_class_name": 'BbAreaFilterConfig', 'min_detections': min_det, "max_pixel_area": 5000, "min_pixel_area": 100}]
                file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}-{:02d}-{:02d}.json".format(len(list_configs), 
                                                    current_config_dict['video_config']['video_id'], lt, ht, min_det))
                list_configs.append(file_name)
                with open(file_name, 'w') as f:
                    json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])
# Out:
# 24 /var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M00-ChvUtd-000-04-10-25.json

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-LT-HT-DET-1-6", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-LT-HT-DET-1-6",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )
# Out:
# 2017-06-17 22:49:39,532 [INFO] [holmes.experiment.base] Verifying AWS staging area: s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()
# Out:
# 2017-06-17 22:49:42,223 [INFO] [holmes.experiment.base] staging measurement M00-ChvUtd-000-04-10-25
# 2017-06-17 22:49:42,707 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M00-ChvUtd-000-04-10-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M00-ChvUtd-000-04-10-25.json
# 2017-06-17 22:49:43,125 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz
# 2017-06-17 22:49:44,393 [INFO] [holmes.experiment.base] staging measurement M01-PS0304-001-04-10-25
# 2017-06-17 22:49:44,913 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M01-PS0304-001-04-10-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M01-PS0304-001-04-10-25.json
# 2017-06-17 22:49:45,307 [INFO] [holmes.experiment.base] staging measurement M02-PP0214-000-04-10-25
# 2017-06-17 22:49:45,798 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M02-PP0214-000-04-10-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M02-PP0214-000-04-10-25.json
# 2017-06-17 22:49:46,210 [INFO] [holmes.experiment.base] staging measurement M03-ER0429-001-04-10-25
# 2017-06-17 22:49:46,677 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M03-ER0429-001-04-10-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M03-ER0429-001-04-10-25.json
# 2017-06-17 22:49:47,134 [INFO] [holmes.experiment.base] staging measurement M04-ChvUtd-000-04-15-25
# 2017-06-17 22:49:47,604 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M04-ChvUtd-000-04-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M04-ChvUtd-000-04-15-25.json
# 2017-06-17 22:49:48,061 [INFO] [holmes.experiment.base] staging measurement M05-PS0304-001-04-15-25
# 2017-06-17 22:49:48,516 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M05-PS0304-001-04-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M05-PS0304-001-04-15-25.json
# 2017-06-17 22:49:49,091 [INFO] [holmes.experiment.base] staging measurement M06-PP0214-000-04-15-25
# 2017-06-17 22:49:50,251 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M06-PP0214-000-04-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M06-PP0214-000-04-15-25.json
# 2017-06-17 22:49:50,649 [INFO] [holmes.experiment.base] staging measurement M07-ER0429-001-04-15-25
# 2017-06-17 22:49:51,123 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M07-ER0429-001-04-15-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M07-ER0429-001-04-15-25.json
# 2017-06-17 22:49:51,513 [INFO] [holmes.experiment.base] staging measurement M08-ChvUtd-000-04-20-25
# 2017-06-17 22:49:51,978 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M08-ChvUtd-000-04-20-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M08-ChvUtd-000-04-20-25.json
# 2017-06-17 22:49:52,362 [INFO] [holmes.experiment.base] staging measurement M09-PS0304-001-04-20-25
# 2017-06-17 22:49:52,845 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M09-PS0304-001-04-20-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M09-PS0304-001-04-20-25.json
# 2017-06-17 22:49:53,294 [INFO] [holmes.experiment.base] staging measurement M10-PP0214-000-04-20-25
# 2017-06-17 22:49:53,793 [INFO] [holmes.experiment.base] staging file, source=/var/folders/57/58_nn3s94l9f_jsjrzsd2h6mmwn1_p/T/tmpcofbzlhs/M10-PP0214-000-04-20-25.json, destination=s3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/
15-25',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Sun, 18 Jun 2017 03:48:02 GMT',
#       'via': '1.1 c81fe539ce375c7107717ad63121197f.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'E_-5VS3O0eb95G0U5mhubM_79uMTVn1pojH8fyzhvynP3Tri4EzLPw==',
#       'x-amzn-requestid': 'edce9778-53d8-11e7-aa81-eb9cacde3aab',
#       'x-amzn-trace-id': 'sampled=0;root=1-5945f7f2-1a4613720e60d79c4c52e6e3',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'edce9778-53d8-11e7-aa81-eb9cacde3aab',
#      'RetryAttempts': 0},
#     'jobId': 'cdb539db-9641-4ce4-b12e-ff9e76160e55',
#     'jobName': 'PTA-95-LT-HT-DET-1-6-M19-ER0429-001-05-15-25'},
#    'measurement_id': 'M19-ER0429-001-05-15-25',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M20-ChvUtd-000-05-20-25.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-1-6',
#    'job_id': 'PTA-95-LT-HT-DET-1-6-M20-ChvUtd-000-05-20-25',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Sun, 18 Jun 2017 03:48:02 GMT',
#       'via': '1.1 df7ccadded048f1d65b25a48e8fd474b.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'KWJ04WeUwQTj3Uudy_rZwEVG39t15CGrwxF_BpVkapxfmC7H1We1fA==',
#       'x-amzn-requestid': 'ee00f183-53d8-11e7-86b0-b13a541f1a57',
#       'x-amzn-trace-id': 'sampled=0;root=1-5945f7f2-23c307e2ce6fbcbf7b4bdac8',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'ee00f183-53d8-11e7-86b0-b13a541f1a57',
#      'RetryAttempts': 0},
#     'jobId': 'edf0c578-2baa-49f6-8318-3f4ead60a5c4',
#     'jobName': 'PTA-95-LT-HT-DET-1-6-M20-ChvUtd-000-05-20-25'},
#    'measurement_id': 'M20-ChvUtd-000-05-20-25',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M21-PS0304-001-05-20-25.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-1-6',
#    'job_id': 'PTA-95-LT-HT-DET-1-6-M21-PS0304-001-05-20-25',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Sun, 18 Jun 2017 03:48:03 GMT',
#       'via': '1.1 df6ab1791427412a072a852eb0428888.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'X_KYK6JXEO3oGSMx2zfy2UMxqud0Szs9QwgzYSgKAfmG6sM_kYUOzg==',
#       'x-amzn-requestid': 'ee2ce3ac-53d8-11e7-9634-27c1a53f7fd6',
#       'x-amzn-trace-id': 'sampled=0;root=1-5945f7f3-8daf4c2ed1e6d074ac582afa',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'ee2ce3ac-53d8-11e7-9634-27c1a53f7fd6',
#      'RetryAttempts': 0},
#     'jobId': '38cb79cd-b578-4c14-bd88-5ed9ca7dffe3',
#     'jobName': 'PTA-95-LT-HT-DET-1-6-M21-PS0304-001-05-20-25'},
#    'measurement_id': 'M21-PS0304-001-05-20-25',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M22-PP0214-000-05-20-25.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-1-6',
#    'job_id': 'PTA-95-LT-HT-DET-1-6-M22-PP0214-000-05-20-25',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Sun, 18 Jun 2017 03:48:03 GMT',
#       'via': '1.1 3fed6f40ae58f485d8018b6d900fcc88.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'oT1Dqbd7OVaAL2X-veb8mNUTzKpHdqt08ZjwKT73usrbS7dpGNxUhg==',
#       'x-amzn-requestid': 'ee55ef33-53d8-11e7-ac4b-fb8693282112',
#       'x-amzn-trace-id': 'sampled=0;root=1-5945f7f3-567cd8f7d3e640dbb2b03f31',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'ee55ef33-53d8-11e7-ac4b-fb8693282112',
#      'RetryAttempts': 0},
#     'jobId': '44fc2792-4c09-4d43-8686-ee6dc01d7e0f',
#     'jobName': 'PTA-95-LT-HT-DET-1-6-M22-PP0214-000-05-20-25'},
#    'measurement_id': 'M22-PP0214-000-05-20-25',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'},
#   {'config_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/M23-ER0429-001-05-20-25.json',
#    'experiment_id': 'PTA-95-LT-HT-DET-1-6',
#    'job_id': 'PTA-95-LT-HT-DET-1-6-M23-ER0429-001-05-20-25',
#    'job_queue': 'holmes-research-queue-cpu',
#    'launch_telemetry': {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#       'content-length': '105',
#       'content-type': 'application/json',
#       'date': 'Sun, 18 Jun 2017 03:48:03 GMT',
#       'via': '1.1 02da7bd0c115d2e6bc41d44c868efd72.cloudfront.net (CloudFront)',
#       'x-amz-cf-id': 'QaTX9lNxozuGxnildcwLO8hFhg_aeEdvdpcFqctrN7aJIDsjUb_b8Q==',
#       'x-amzn-requestid': 'ee7f70a8-53d8-11e7-ad4f-c5a10a974346',
#       'x-amzn-trace-id': 'sampled=0;root=1-5945f7f3-fec0126a31d1b5eeeb2e762a',
#       'x-cache': 'Miss from cloudfront'},
#      'HTTPStatusCode': 200,
#      'RequestId': 'ee7f70a8-53d8-11e7-ad4f-c5a10a974346',
#      'RetryAttempts': 0},
#     'jobId': '14abb7f7-7025-404b-9150-23bae09f13f2',
#     'jobName': 'PTA-95-LT-HT-DET-1-6-M23-ER0429-001-05-20-25'},
#    'measurement_id': 'M23-ER0429-001-05-20-25',
#    'package_path': 's3://hudl-holmes/experiments/PTA-95-LT-HT-DET-1-6/deps/ca6ccd63f270d603ffa9bdf5a7ced184d6339796.tar.gz'}]}

# %%
import pandas as pd

# %%
data = pd.DataFrame({'mota':[.672,.672,.669,.670,.670,.667,.858,.865,.865,.859,.864,.864,.769,.794,.796,.769,.794,
                             .795],
              'lt':[4,4,4,5,5,5,4,4,4,5,5,5,4,4,4,5,5,5,4,4,4,5,5,5],
              'ht':[10,15,20,10,15,20,10,15,20,10,15,20,10,15,20,10,15,20,10,15,20,10,15,20],
              'det':[25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25,25],
             'game':['ER0429','ER0429','ER0429','ER0429','ER0429','ER0429','PP0214','PP0214','PP0214','PP0214',
                     'PP0214','PP0214','ChvUtd','ChvUtd','ChvUtd','ChvUtd','ChvUtd','ChvUtd','PS0304','PS0304',
                     'PS0304','PS0304','PS0304','PS0304']})

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cd38edcd-bc13-489d-a1f2-092746f7b664">Loading BokehJS ...</span>
#     </div>

# %%
data_lt_ht_det = data.copy()
data_lt_ht_det['lost'] = data_lt_ht_det['lt']
data_lt_ht_det['hungarian'] = data_lt_ht_det['ht']
data_lt_ht_det['detections'] = data_lt_ht_det['det']
data_lt_ht_det = data_lt_ht_det.loc[:,['mota','ht', 'lt', 'det', 'lost', 'hungarian', 'detections']].groupby(['ht','lt','det']).mean()
data_lt_ht_det
# Out:
#               mota  lost  hungarian  detections
# ht lt det
# 15 5  25   0.77425     5         15          25
#       35   0.76925     5         15          35
#    6  25   0.77325     6         15          25
#       35   0.77025     6         15          35

# %%
scat_lt_ht_det_1 = Scatter(data_lt_ht_det, x='lost', y='mota', color='detections', marker='hungarian')
show(scat_lt_ht_det_1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ee89f1e6-52b7-44ff-9974-dae812c63031"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ee89f1e6-52b7-44ff-9974-dae812c63031");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ee89f1e6-52b7-44ff-9974-dae812c63031");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ee89f1e6-52b7-44ff-9974-dae812c63031' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a7d5f16a-1923-4747-ae9c-97554b4f256c":{"roots":{"references":[{"attributes":{"items":[{"id":"8923f83c-6fb8-487d-8e67-11ac84246268","type":"LegendItem"},{"id":"6f6ebcd1-1db8-4a54-83e9-6e6d7a095bc6","type":"LegendItem"}],"location":"top_left","plot":{"id":"cdf8ff58-9c09-4263-a363-cf4619dabb2c","subtype":"Chart","type":"Plot"}},"id":"5e60a581-99cf-4316-bf7b-0e51d8d7bcdc","type":"Legend"},{"attributes":{"data_source":{"id":"0eb47c00-0fb0-4ed0-b87d-6dbc1484f1e0","type":"ColumnDataSource"},"glyph":{"id":"417d2a9d-406d-47bc-9b51-bee290bbdad4","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"d95f52cf-9921-4e56-9bd1-4609db8756c7","type":"GlyphRenderer"},{"attributes":{"axis_label":"mota","formatter":{"id":"2d1de91e-e7d7-497f-a506-f17cca7227d3","type":"BasicTickFormatter"},"plot":{"id":"cdf8ff58-9c09-4263-a363-cf4619dabb2c","subtype":"Chart","type":"Plot"},"ticker":{"id":"a4fabfb7-20ab-426f-af85-bd29610c26d0","type":"BasicTicker"}},"id":"65bceaf6-ac7b-4f24-988c-67991e647fad","type":"LinearAxis"},{"attributes":{"callback":null,"end":6.1,"start":4.9},"id":"c7cd0e4a-f170-42e1-bddd-b03a46433f13","type":"Range1d"},{"attributes":{},"id":"cd3b296a-7b2f-4fa3-b4d2-e8a31f20373f","type":"LinearScale"},{"attributes":{"plot":{"id":"cdf8ff58-9c09-4263-a363-cf4619dabb2c","subtype":"Chart","type":"Plot"}},"id":"a2f0714d-432d-4c6b-84e8-3fc43d0a9a9e","type":"HelpTool"},{"attributes":{},"id":"433fa720-e97b-429a-8e43-ff3aafcec101","type":"LinearScale"},{"attributes":{"data_source":{"id":"0fc6ca11-6f72-4a22-a50a-a265722b25e4","type":"ColumnDataSource"},"glyph":{"id":"0c093d44-1c92-444a-aacf-4aeb9d57c767","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"0b00e53c-8c63-457c-99d1-ddc6a123b7cb","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"cdf8ff58-9c09-4263-a363-cf4619dabb2c","subtype":"Chart","type":"Plot"},"ticker":{"id":"a4fabfb7-20ab-426f-af85-bd29610c26d0","type":"BasicTicker"}},"id":"ee1d1df6-ce0b-4840-8048-4679ace71da8","type":"Grid"},{"attributes":{},"id":"c8976f17-e2f0-4f4a-be69-61e4e5334c84","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"detections":25,"hungarian":15},{"detections":25,"hungarian":15}],"detections":[25,25],"hungarian":[15,15],"x_values":[5,6],"y_values":{"__ndarray__":"LrKd76fG6D9ZObTIdr7oPw==","dtype":"float64","shape":[2]}}},"id":"0eb47c00-0fb0-4ed0-b87d-6dbc1484f1e0","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"cdf8ff58-9c09-4263-a363-cf4619dabb2c","subtype":"Chart","type":"Plot"},"ticker":{"id":"a704a9e7-5e0b-49b5-8c05-8901aedd2b81","type":"BasicTicker"}},"id":"f44b69a3-5d46-481e-97c4-6e8bf023d21d","type":"Grid"},{"attributes":{"callback":null,"end":0.7747500000000002,"start":0.7687499999999999},"id":"b687dbeb-a6ac-4cfe-9af3-665c6711ac36","type":"Range1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c49be024-51ad-4902-8848-6433b2714b2a","type":"PanTool"},{"id":"d11d3854-8d49-4ef7-87fd-3d4af6062eab","type":"WheelZoomTool"},{"id":"a6d437a6-9102-4203-9dd9-a64310cd93b7","type":"BoxZoomTool"},{"id":"28f0e8db-e835-4c8c-8ee8-7599b7a8abd0","type":"SaveTool"},{"id":"5877f462-ad43-4f38-b219-4eda17e38a28","type":"ResetTool"},{"id":"a2f0714d-432d-4c6b-84e8-3fc43d0a9a9e","type":"HelpTool"}]},"id":"22546647-b2ba-45eb-88cb-6ee9ef8c173f","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"detections":35,"hungarian":15},{"detections":35,"hungarian":15}],"detections":[35,35],"hungarian":[15,15],"x_values":[5,6],"y_values":{"__ndarray__":"BFYOLbKd6D/ZzvdT46XoPw==","dtype":"float64","shape":[2]}}},"id":"0fc6ca11-6f72-4a22-a50a-a265722b25e4","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values" ...

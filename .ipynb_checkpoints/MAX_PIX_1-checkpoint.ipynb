# %%
import holmes.experiment as Ex
import tempfile
import pprint
import json
import os
from terrarium.flatten import flatten_dict, expand_dict
import tempfile

# %%
temp_dir_obj = tempfile.TemporaryDirectory()
temp_dir = temp_dir_obj.name
package_location = Ex.staging.prep_holmes_package(
    staging_path=temp_dir, 
    commit_hash='ca6ccd63f270d603ffa9bdf5a7ced184d6339796'
)

detects_dict={}
for video_data in Ex.val_data:
    detects_dict[video_data['video_id']] = video_data['video_path'].replace('processed','detections')

def_conf_path = Ex.staging.extract_default_config(package_location, temp_dir)

with open(def_conf_path, 'r') as fp:
    def_conf_dict = json.load(fp)

new_def_conf_dicts={}
list_dicts=[]
for video_data in Ex.val_data:
    new_def_conf_dict = def_conf_dict.copy()
    detects_path = video_data['video_path'].replace('processed','detections').replace('.mp4', '.json')
    new_def_conf_dict['detector_config'] = {"source_path": detects_path,"_class_name": "PassThroughDetectorConfig","batch_size": 1}
    new_def_conf_dict['video_config'] = video_data
    new_def_conf_dict['video_config']['_class_name'] = 'RawVideoConfig'
    list_dicts.append(new_def_conf_dict)

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
maximum_pixels = [4500,4750,5000,5250,5500,5750,6000,6250,6500]

# %%
list_configs=[]
for max_pix in maximum_pixels:
    for config in list_dicts:
        current_config_dict = config.copy()
        flat_dict = flatten_dict(current_config_dict)
        updated_config_dict = expand_dict(flat_dict)
        updated_config_dict["filter_configs"] = [{"_class_name": 'BbAreaFilterConfig', 'min_detections': 60, "max_pixel_area": max_pix, "min_pixel_area": 100}]
        file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}.json".format(len(list_configs), 
                                            current_config_dict['video_config']['video_id'], max_pix))
        list_configs.append(file_name)
        with open(file_name, 'w') as f:
            json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-MAX-PIX-1-1", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-MAX-PIX-1-1",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()

# %%
experiment.launch_experiment()

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/max_pix1.csv')

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="65364502-ffb4-4907-8730-1d79b6da353c">Loading BokehJS ...</span>
#     </div>

# %%
data['max_pix'] = 1
for index, row in data.iterrows():
    data['max_pix'][index] = row['job_id'][-4:]

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][19:25]

# %%
scat1 = Scatter(data, x='max_pix', y='mota', color='game')
show(scat1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d27a465b-ee7a-4a42-b414-e36e120740cb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d27a465b-ee7a-4a42-b414-e36e120740cb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d27a465b-ee7a-4a42-b414-e36e120740cb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd27a465b-ee7a-4a42-b414-e36e120740cb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b4139a32-4bb8-4337-be84-4f3a588ae5e6":{"roots":{"references":[{"attributes":{"axis_label":"mota","formatter":{"id":"081d9680-52d3-4054-8c8c-55b1df00e2b2","type":"BasicTickFormatter"},"plot":{"id":"a055afd3-2ab3-49c8-965d-a838407e4d29","subtype":"Chart","type":"Plot"},"ticker":{"id":"a19be1ae-3d60-427e-8c9f-724f64b91760","type":"BasicTicker"}},"id":"4242ea60-2855-450f-8478-ed322097b475","type":"LinearAxis"},{"attributes":{},"id":"bab11c5e-7eff-4107-83f2-b8627ec9150a","type":"LinearScale"},{"attributes":{"overlay":{"id":"e71a9117-cfad-4a5c-955d-d0d82f68379e","type":"BoxAnnotation"},"plot":{"id":"a055afd3-2ab3-49c8-965d-a838407e4d29","subtype":"Chart","type":"Plot"}},"id":"7463da1b-d5d7-44b8-96d9-37f69002864c","type":"BoxZoomTool"},{"attributes":{"axis_label":"max_pix","formatter":{"id":"32ea9ac8-c96b-4f2c-aee2-6572f8d38088","type":"BasicTickFormatter"},"plot":{"id":"a055afd3-2ab3-49c8-965d-a838407e4d29","subtype":"Chart","type":"Plot"},"ticker":{"id":"d7d651c4-dafe-4b4c-b0fe-eb3b55d8281a","type":"BasicTicker"}},"id":"91d4c90b-13be-49a5-9e37-ed92fb7bd239","type":"LinearAxis"},{"attributes":{},"id":"32ea9ac8-c96b-4f2c-aee2-6572f8d38088","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"612d9d82-6b96-48db-a377-d87bad5721df","type":"Circle"},{"attributes":{"label":{"value":"ER0429"},"renderers":[{"id":"9ff70d04-fd8b-47a0-9447-a984f72c16c1","type":"GlyphRenderer"}]},"id":"50e3e162-1366-4685-a742-cdf43b0bca79","type":"LegendItem"},{"attributes":{"callback":null,"end":0.6503926351846696,"start":0.6494957380013948},"id":"b0507bfc-3a81-4833-8cdb-256291a03410","type":"Range1d"},{"attributes":{"plot":null,"text":null},"id":"d675843c-125b-4b8e-9354-c09945d0e149","type":"Title"},{"attributes":{"data_source":{"id":"92c1cc55-2a92-4ddf-b84f-38463aec4ab5","type":"ColumnDataSource"},"glyph":{"id":"612d9d82-6b96-48db-a377-d87bad5721df","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"9ff70d04-fd8b-47a0-9447-a984f72c16c1","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a055afd3-2ab3-49c8-965d-a838407e4d29","subtype":"Chart","type":"Plot"}},"id":"a32d56d0-101f-4ac0-b6d8-f486b1d82283","type":"PanTool"},{"attributes":{"below":[{"id":"91d4c90b-13be-49a5-9e37-ed92fb7bd239","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"4242ea60-2855-450f-8478-ed322097b475","type":"LinearAxis"}],"renderers":[{"id":"e71a9117-cfad-4a5c-955d-d0d82f68379e","type":"BoxAnnotation"},{"id":"9ff70d04-fd8b-47a0-9447-a984f72c16c1","type":"GlyphRenderer"},{"id":"83f25450-ff91-4191-8222-a89a33a4d12a","type":"Legend"},{"id":"91d4c90b-13be-49a5-9e37-ed92fb7bd239","type":"LinearAxis"},{"id":"4242ea60-2855-450f-8478-ed322097b475","type":"LinearAxis"},{"id":"76b0a8b9-1b01-4de5-8cba-d469b8c45021","type":"Grid"},{"id":"06bb80af-9601-44f4-8781-89e155b71890","type":"Grid"}],"title":{"id":"d675843c-125b-4b8e-9354-c09945d0e149","type":"Title"},"tool_events":{"id":"1aaaf764-5af0-4608-aed3-c26f67180239","type":"ToolEvents"},"toolbar":{"id":"a2b8f240-5a87-4ceb-9661-fbeb05153918","type":"Toolbar"},"x_range":{"id":"5b377c4a-bed4-4b7f-99cc-1b45b9432f5b","type":"Range1d"},"x_scale":{"id":"46a638c6-c95a-42bc-94f8-637ad2f43d95","type":"LinearScale"},"y_range":{"id":"b0507bfc-3a81-4833-8cdb-256291a03410","type":"Range1d"},"y_scale":{"id":"bab11c5e-7eff-4107-83f2-b8627ec9150a","type":"LinearScale"}},"id":"a055afd3-2ab3-49c8-965d-a838407e4d29","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"d7d651c4-dafe-4b4c-b0fe-eb3b55d8281a","type":"BasicTicker"},{"attributes":{"plot":{"id":"a055afd3-2ab3-49c8-965d-a838407e4d29","subtype":"Chart","type":"Plot"}},"id":"385af249-31be-4460-863e-a0e342050a56","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"a055afd3-2ab3-49c8-965d-a838407e4d29","subtype":"Chart","type":"Plot"},"ticker":{"id":"a19be1ae-3d60-427e-8c9f-724f ...

# %%
data_max_pix = data.copy()
data_max_pix['maximum_pixels'] = data_max_pix['max_pix']
data_max_pix = data_max_pix.groupby(['max_pix']).mean()
data_max_pix
# Out:
#              mota      motp      motr  mostly_tracked    mt_auc  \
# max_pix
# 4500     0.649966  0.622596  0.790376        0.579347  0.770379
# 4750     0.650115  0.622713  0.791080        0.580106  0.771007
# 5000     0.649714  0.622731  0.790960        0.578588  0.770864
# 5250     0.650318  0.622611  0.791086        0.583144  0.771062
# 5500     0.649946  0.622645  0.790835        0.573273  0.770796
# 5750     0.649570  0.622713  0.790694        0.577069  0.770641
# 6000     0.649756  0.622698  0.790991        0.573273  0.770921
# 6250     0.650110  0.622686  0.791198        0.579347  0.771130
# 6500     0.649601  0.622621  0.790855        0.574791  0.770736
#
#          maximum_pixels
# max_pix
# 4500               4500
# 4750               4750
# 5000               5000
# 5250               5250
# 5500               5500
# 5750               5750
# 6000               6000
# 6250               6250
# 6500               6500

# %%
scat2 = Scatter(data_max_pix, x = 'maximum_pixels', y='mota')
scat3 = Scatter(data_max_pix, x = 'maximum_pixels', y='motp')
scat4 = Scatter(data_max_pix, x = 'maximum_pixels', y='mostly_tracked')
scat5 = Scatter(data_max_pix, x = 'maximum_pixels', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat2, scat3), row(scat4, scat5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0eb95419-525e-4a8e-804f-7067b59d8a91"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0eb95419-525e-4a8e-804f-7067b59d8a91");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0eb95419-525e-4a8e-804f-7067b59d8a91");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0eb95419-525e-4a8e-804f-7067b59d8a91' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"29a528be-7261-4903-92c6-69bc83f7ed6a":{"roots":{"references":[{"attributes":{"plot":{"id":"af6e4cae-e540-4a4c-914b-04204f379502","subtype":"Chart","type":"Plot"},"ticker":{"id":"3714ee1e-a4f1-4792-9d59-7a40ab59a163","type":"BasicTicker"}},"id":"3462851d-ae04-48f0-a8bb-1fdb61cf247f","type":"Grid"},{"attributes":{"plot":{"id":"44fda527-5a14-4f63-9a16-23b66f652bc6","subtype":"Chart","type":"Plot"}},"id":"816810eb-5d75-4c61-86f9-6263d18af40e","type":"HelpTool"},{"attributes":{"callback":null,"end":6700.0,"start":4300.0},"id":"8be1700f-bce2-43d2-8692-3a8abafdcce1","type":"Range1d"},{"attributes":{"children":[{"id":"44fda527-5a14-4f63-9a16-23b66f652bc6","subtype":"Chart","type":"Plot"},{"id":"af6e4cae-e540-4a4c-914b-04204f379502","subtype":"Chart","type":"Plot"}]},"id":"6839b701-548f-4ff6-add1-561120f5956c","type":"Row"},{"attributes":{"plot":{"id":"6991fc15-91a0-4c80-b4b3-2332a863cea1","subtype":"Chart","type":"Plot"},"ticker":{"id":"e9c453b3-e5ca-42c2-b79d-28b02b075a89","type":"BasicTicker"}},"id":"14f445fe-f22a-4762-8c4a-8fc42264231d","type":"Grid"},{"attributes":{"plot":{"id":"44fda527-5a14-4f63-9a16-23b66f652bc6","subtype":"Chart","type":"Plot"}},"id":"4c6dc8ee-ffd5-46df-b3f4-94e1dd4444f8","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"af6e4cae-e540-4a4c-914b-04204f379502","subtype":"Chart","type":"Plot"}},"id":"43e56ca2-c939-44a1-a166-55d23638519d","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"44fda527-5a14-4f63-9a16-23b66f652bc6","subtype":"Chart","type":"Plot"},"ticker":{"id":"b3b8156d-7b37-4649-a0af-b3a25db89397","type":"BasicTicker"}},"id":"ca848035-1d2c-4ca8-85a7-161bf9970c5e","type":"Grid"},{"attributes":{"plot":{"id":"6991fc15-91a0-4c80-b4b3-2332a863cea1","subtype":"Chart","type":"Plot"}},"id":"e45bd31e-8d5e-49a1-98c9-e43816f27e21","type":"SaveTool"},{"attributes":{"below":[{"id":"bf0deaed-3075-46f9-bf61-a46586f91283","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"6f2b8b6f-4c09-477a-8e40-f09eb7c27ae6","type":"LinearAxis"}],"renderers":[{"id":"c055a703-f74b-4009-bf6e-6460038302e6","type":"BoxAnnotation"},{"id":"375914bb-2881-4aa3-85c6-d3c036c99aa7","type":"GlyphRenderer"},{"id":"69c59ab8-0b72-4b1e-892e-dc6aee2cdedd","type":"Legend"},{"id":"bf0deaed-3075-46f9-bf61-a46586f91283","type":"LinearAxis"},{"id":"6f2b8b6f-4c09-477a-8e40-f09eb7c27ae6","type":"LinearAxis"},{"id":"ca848035-1d2c-4ca8-85a7-161bf9970c5e","type":"Grid"},{"id":"c2c5db67-26da-4dbb-bfee-e2f28ab2f98d","type":"Grid"}],"title":{"id":"a6493584-094d-4e63-a2db-ea17dfa61c95","type":"Title"},"tool_events":{"id":"eec5b8f9-fd46-4bdc-964a-eb8f3b6f7bda","type":"ToolEvents"},"toolbar":{"id":"9ca9ca9b-6565-48e9-a9d9-84426931f241","type":"Toolbar"},"x_range":{"id":"a1eaa507-f98a-41f6-9870-dfc27344de38","type":"Range1d"},"x_scale":{"id":"7d5e09b8-1f4e-401d-b758-219c9c2d283b","type":"LinearScale"},"y_range":{"id":"d4d1aec0-406f-4c7d-ac90-868e43f7bd3c","type":"Range1d"},"y_scale":{"id":"50c6569b-7dc4-4ee1-85c9-10b8b5b6eef2","type":"LinearScale"}},"id":"44fda527-5a14-4f63-9a16-23b66f652bc6","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"50c6569b-7dc4-4ee1-85c9-10b8b5b6eef2","type":"LinearScale"},{"attributes":{"plot":null,"text":null},"id":"99901d40-d9ba-4c4d-a08d-0b22230fb9a3","type":"Title"},{"attributes":{"overlay":{"id":"fc743e4f-46fd-473c-a635-2110a8f7da0d","type":"BoxAnnotation"},"plot":{"id":"39f4b12f-0b03-42d2-82fb-eb588a9a7845","subtype":"Chart","type":"Plot"}},"id":"30b261b7-7071-4371-ba19-167fb7cb64f8","type":"BoxZoomTool"},{"attributes":{},"id":"ac8b98de-e4eb-47f4-b1f7-4c55e86ae4d3","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"95877c15-15ee-4822-b953-e8ebb07d8504","type":"PanTool"},{"id":"4c6dc8ee-ffd5-46df-b3f4-94e1dd4444f8","type":"WheelZoomTool"},{"id":"240d85bc-a34e-4ea6-8318-a4dfa34618ee","type":"BoxZoomTool"},{"id":"eb46f3fd-ba99-42df-88c3-4babd4c87809","type":"SaveTool"},{"id":"179f3759-085f-4eb7-bf7b- ...

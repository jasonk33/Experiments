# %%
import holmes.experiment as Ex
import tempfile
import pprint
import json
import os
from terrarium.flatten import flatten_dict, expand_dict
import tempfile

# %%
temp_dir_obj = tempfile.TemporaryDirectory()
temp_dir = temp_dir_obj.name
package_location = Ex.staging.prep_holmes_package(
    staging_path=temp_dir, 
    commit_hash='ca6ccd63f270d603ffa9bdf5a7ced184d6339796'
)

detects_dict={}
for video_data in Ex.val_data:
    detects_dict[video_data['video_id']] = video_data['video_path'].replace('processed','detections')

def_conf_path = Ex.staging.extract_default_config(package_location, temp_dir)

with open(def_conf_path, 'r') as fp:
    def_conf_dict = json.load(fp)

new_def_conf_dicts={}
list_dicts=[]
for video_data in Ex.val_data:
    new_def_conf_dict = def_conf_dict.copy()
    detects_path = video_data['video_path'].replace('processed','detections').replace('.mp4', '.json')
    new_def_conf_dict['detector_config'] = {"source_path": detects_path,"_class_name": "PassThroughDetectorConfig","batch_size": 1}
    new_def_conf_dict['video_config'] = video_data
    new_def_conf_dict['video_config']['_class_name'] = 'RawVideoConfig'
    list_dicts.append(new_def_conf_dict)

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
minimum_detections = [23,26,29,32,35,38,41,44]

# %%
list_configs=[]
for min_det in minimum_detections:
    for config in list_dicts:
        current_config_dict = config.copy()
        flat_dict = flatten_dict(current_config_dict)
        updated_config_dict = expand_dict(flat_dict)
        updated_config_dict["filter_configs"] = [{"_class_name": 'BbAreaFilterConfig', 'min_detections': min_det, "max_pixel_area": 5000, "min_pixel_area": 100}]
        file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}.json".format(len(list_configs), 
                                            current_config_dict['video_config']['video_id'], min_det))
        list_configs.append(file_name)
        with open(file_name, 'w') as f:
            json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-DET-1-4", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-DET-1-4",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()

# %%
experiment.launch_experiment()

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/DET4.csv')

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="683207ee-cf13-4e3b-a39c-ae9850d7642a">Loading BokehJS ...</span>
#     </div>

# %%
data['min_det'] = 1
for index, row in data.iterrows():
    data['min_det'][index] = row['job_id'][-3:]
data['min_det'][data['min_det']<0]=data['min_det'][data['min_det']<0]*-1

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][19:25]

# %%
scat1 = Scatter(data, x='min_det', y='mota', color='game')
show(scat1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="af371f7b-5f51-436f-b510-30b20cd46041"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("af371f7b-5f51-436f-b510-30b20cd46041");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("af371f7b-5f51-436f-b510-30b20cd46041");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'af371f7b-5f51-436f-b510-30b20cd46041' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dc6b7c94-1e0b-43af-9408-39c2a1f8c1ff":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"4036f4ea-09b7-4dac-b0e7-b4903753d08b","type":"Circle"},{"attributes":{},"id":"c35cf4b2-961b-4eda-89f6-dbf121a696b1","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"326b2f5b-8a02-4926-b8b1-6b8ac1c75b5f","subtype":"Chart","type":"Plot"}},"id":"45df5b35-3bb9-4d03-bc99-730e2c78d12f","type":"PanTool"},{"attributes":{"axis_label":"min_det","formatter":{"id":"8fd9c907-7be0-4b7c-b962-8be8b778a0ca","type":"BasicTickFormatter"},"plot":{"id":"326b2f5b-8a02-4926-b8b1-6b8ac1c75b5f","subtype":"Chart","type":"Plot"},"ticker":{"id":"9f35cc03-ebd4-4d75-9ef5-11b325e3c3df","type":"BasicTicker"}},"id":"cbdea808-f83d-408b-83ee-a488b7ef9d93","type":"LinearAxis"},{"attributes":{"callback":null,"end":46.1,"start":20.9},"id":"0226ecf6-08b8-4584-af48-5aa664b71abc","type":"Range1d"},{"attributes":{},"id":"8fd9c907-7be0-4b7c-b962-8be8b778a0ca","type":"BasicTickFormatter"},{"attributes":{"axis_label":"mota","formatter":{"id":"c35cf4b2-961b-4eda-89f6-dbf121a696b1","type":"BasicTickFormatter"},"plot":{"id":"326b2f5b-8a02-4926-b8b1-6b8ac1c75b5f","subtype":"Chart","type":"Plot"},"ticker":{"id":"2b736427-8300-43c7-aa65-9fccd7d555b5","type":"BasicTicker"}},"id":"ad196901-0f27-4c0c-a985-58dcd8178d97","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"cb19b14f-a0e5-481b-bfdb-6902554d2440","type":"Circle"},{"attributes":{},"id":"9f35cc03-ebd4-4d75-9ef5-11b325e3c3df","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"},{"game":"ChvUtd"}],"game":["ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd","ChvUtd"],"x_values":[44,41,38,35,23,29,32,26],"y_values":{"__ndarray__":"9N41hbhL6T9YbZ8eyE/pP37rtNQKUek/8he18dRR6T9FFNN4H1PpPyr3Z27XVOk/KDIkA2NV6T8XFawT4FXpPw==","dtype":"float64","shape":[8]}}},"id":"828c601c-d610-40e4-ab32-46a389d3da7b","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"326b2f5b-8a02-4926-b8b1-6b8ac1c75b5f","subtype":"Chart","type":"Plot"}},"id":"9f996aa5-0282-4ab2-a5d7-f767bc9a6323","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"45df5b35-3bb9-4d03-bc99-730e2c78d12f","type":"PanTool"},{"id":"312c26fd-13a5-4242-983d-779321840bdf","type":"WheelZoomTool"},{"id":"c5435701-6d76-4be0-b1fe-649912797f16","type":"BoxZoomTool"},{"id":"49474c64-4c7a-4fe6-b4b5-a0ef3d06e573","type":"SaveTool"},{"id":"9f996aa5-0282-4ab2-a5d7-f767bc9a6323","type":"ResetTool"},{"id":"7a4daee3-e4b0-4abe-b0b0-e3d0bb4b0f5d","type":"HelpTool"}]},"id":"acb022a0-2a0e-4372-805d-8b99f3e5ba75","type":"Toolbar"},{"attributes":{},"id":"2b736427-8300-43c7-aa65-9fccd7d555b5","type":"BasicTicker"},{"attributes":{"plot":{"id":"326b2f5b-8a02-4926-b8b1-6b8ac1c75b5f","subtype":"Chart","type":"Plot"}},"id":"312c26fd-13a5-4242-983d-779321840bdf","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"cbdea808-f83d-408b-83ee-a488b7ef9d93","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"ad196901-0f27-4c0c-a985-58dcd8178d97","type":"LinearAxis"}],"renderers":[{"id":"c63ab343-7abf-4c7f-a36f-0bc2692a3502","type":"BoxAnnotation"},{"id":"3211298d-95aa-486b-82f1-2b99044569b7","type":"GlyphRenderer"},{"id":"48ed27b3-1583-4560-bc4f-f921fa0665f3","type":"GlyphRenderer"},{"id":"90b434a6-7fa4-4164-a5c3-42749998588e","type":"GlyphRenderer"},{"id":"8c039db2-dd58-40f9-b795-16856e3a1958","type":"GlyphRenderer"},{"id":"8256437c-f287-4db8-9a24-127d358fcd25","ty ...

# %%
data_min_det = data.copy()
data_min_det['minimum_detections'] = data_min_det['min_det']
data_min_det = data_min_det.groupby(['min_det']).mean()
data_min_det
# Out:
#              mota      motp      motr  mostly_tracked    mt_auc  \
# min_det
# 23       0.768034  0.636297  0.889955        0.808788  0.877075
# 26       0.768404  0.636432  0.888687        0.808449  0.875934
# 29       0.768634  0.636534  0.887212        0.806059  0.874579
# 32       0.768738  0.636723  0.885541        0.803976  0.873068
# 35       0.768593  0.636774  0.884096        0.798583  0.871726
# 38       0.768514  0.636904  0.882170        0.796493  0.869966
# 41       0.768271  0.637092  0.880319        0.794691  0.868268
# 44       0.767750  0.637239  0.878373        0.790854  0.866420
#
#          minimum_detections
# min_det
# 23                       23
# 26                       26
# 29                       29
# 32                       32
# 35                       35
# 38                       38
# 41                       41
# 44                       44

# %%
scat2 = Scatter(data_min_det, x = 'minimum_detections', y='mota')
scat3 = Scatter(data_min_det, x = 'minimum_detections', y='motp')
scat4 = Scatter(data_min_det, x = 'minimum_detections', y='mostly_tracked')
scat5 = Scatter(data_min_det, x = 'minimum_detections', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat2, scat3), row(scat4, scat5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b39a6211-3a37-451a-be25-fcb2f948c1fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b39a6211-3a37-451a-be25-fcb2f948c1fb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b39a6211-3a37-451a-be25-fcb2f948c1fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b39a6211-3a37-451a-be25-fcb2f948c1fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3ee1a717-2b71-466b-a619-f699faf26d62":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"80d1b2ca-374b-477b-b695-6d96a3c7a470","subtype":"Chart","type":"Plot"},"ticker":{"id":"a62f0a1a-faa2-4d14-93e6-022d26511829","type":"BasicTicker"}},"id":"ef8e7870-7229-438e-ba8c-50fb31a42173","type":"Grid"},{"attributes":{"children":[{"id":"ca811c25-0e8b-43bc-8b99-e53e40efa1e2","subtype":"Chart","type":"Plot"},{"id":"2711873b-843a-4f01-b950-9e70381e9928","subtype":"Chart","type":"Plot"}]},"id":"fb3f8cc1-85a3-4438-983b-1c0195a1fb9c","type":"Row"},{"attributes":{"plot":{"id":"80d1b2ca-374b-477b-b695-6d96a3c7a470","subtype":"Chart","type":"Plot"}},"id":"906fe711-09ce-4beb-b1a3-a00ed74aeb4a","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":
# %%
import pandas as pd
import numpy as np
import bokeh
import bokeh.io
import bokeh.charts
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="525276ad-5833-494f-8a58-867e5226be4c">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/search_results2.csv')

# %%
data['lt'] = 1
for index, row in data.iterrows():
    data['lt'][index] = row['job_id'][-2:]
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][16:22]
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data
# Out:
#                            job_id      mota      motp      motr  \
# 0   PTA-89-LT-2-M10-PP0214-000-03  0.854207  0.736993  0.923646
# 1   PTA-89-LT-2-M06-PP0214-000-02  0.853777  0.738426  0.912850
# 2   PTA-89-LT-2-M14-PP0214-000-04  0.852414  0.736220  0.930289
# 3   PTA-89-LT-2-M18-PP0214-000-05  0.850347  0.735444  0.935255
# 4   PTA-89-LT-2-M02-PP0214-000-01  0.849115  0.740737  0.895785
# 5   PTA-89-LT-2-M08-ChvUtd-000-03  0.788275  0.497346  0.883448
# 6   PTA-89-LT-2-M04-ChvUtd-000-02  0.787788  0.497793  0.876728
# 7   PTA-89-LT-2-M12-ChvUtd-000-04  0.787097  0.497067  0.886739
# 8   PTA-89-LT-2-M16-ChvUtd-000-05  0.786305  0.496785  0.889819
# 9   PTA-89-LT-2-M00-ChvUtd-000-01  0.785588  0.498367  0.867492
# 10  PTA-89-LT-2-M05-PS0304-001-02  0.765266  0.693293  0.889746
# 11  PTA-89-LT-2-M09-PS0304-001-03  0.762204  0.692325  0.902410
# 12  PTA-89-LT-2-M13-PS0304-001-04  0.759587  0.691528  0.909705
# 13  PTA-89-LT-2-M01-PS0304-001-01  0.759224  0.695451  0.868102
# ...

# %%
scat1 = bokeh.charts.Scatter(data, x='lt', y='mota', color='game')
bokeh.io.show(scat1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4fe52695-1feb-4ffa-8956-77f275011507"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
data_lt = data.copy()
data_lt['loss'] = data_lt['lt']
data_lt = data_lt.groupby(['lt']).mean()
data_lt
# Out:
#         mota      motp      motr  mostly_tracked    mt_auc  loss
# lt
# 1   0.735035  0.640477  0.819166        0.666049  0.809022     1
# 2   0.741263  0.638814  0.837608        0.709025  0.826910     2
# 3   0.743281  0.637822  0.850431        0.734457  0.839622     3
# 4   0.744797  0.636943  0.860527        0.750982  0.849614     4
# 5   0.744160  0.636579  0.866801        0.763067  0.855742     5

# %%
scat2 = bokeh.charts.Scatter(data_lt, x = 'loss', y='mota')
scat3 = bokeh.charts.Scatter(data_lt, x = 'loss', y='motp')
scat4 = bokeh.charts.Scatter(data_lt, x = 'loss', y='mostly_tracked')
scat5 = bokeh.charts.Scatter(data_lt, x = 'loss', y='mt_auc')
bokeh.io.show(bokeh.layouts.column(bokeh.layouts.row(scat2, scat3), bokeh.layouts.row(scat4, scat5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="37872af1-7c35-4b87-9642-2c5dedf02c0e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
data_lt = data['mota'].groupby(data['lt']).describe()
data_lt
# Out:
#     count      mean       std       min       25%       50%       75%  \
# lt
# 1     4.0  0.735035  0.131414  0.546212  0.705971  0.772406  0.801470
# 2     4.0  0.741263  0.127678  0.558220  0.713505  0.776527  0.804286
# 3     4.0  0.743281  0.122824  0.568438  0.713763  0.775239  0.804758
# 4     4.0  0.744797  0.116502  0.580090  0.714712  0.773342  0.803426
# 5     4.0  0.744160  0.114839  0.581928  0.714026  0.772182  0.802316
#
#          max
# lt
# 1   0.849115
# 2   0.853777
# 3   0.854207
# 4   0.852414
# 5   0.850347

# %%
data[data['lt']==4]
# Out:
#                            job_id      mota      motp      motr  \
# 2   PTA-89-LT-2-M14-PP0214-000-04  0.852414  0.736220  0.930289
# 7   PTA-89-LT-2-M12-ChvUtd-000-04  0.787097  0.497067  0.886739
# 12  PTA-89-LT-2-M13-PS0304-001-04  0.759587  0.691528  0.909705
# 16  PTA-89-LT-2-M15-ER0429-001-04  0.580090  0.622954  0.715374
#
#     mostly_tracked    mt_auc  lt    game
# 2         0.890526  0.921708   4  PP0214
# 7         0.839044  0.879377   4  ChvUtd
# 12        0.851429  0.898789   4  PS0304
# 16        0.422931  0.698585   4  ER0429

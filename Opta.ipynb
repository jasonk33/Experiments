# %%
import xmltodict
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import  train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import os, zipfile
import enum
# %matplotlib inline
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from bokeh.charts import Bar, Histogram
from bokeh.io import output_notebook, show
from bokeh.layouts import row
# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 9.18 ms

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7dd33714-8999-44cf-9e86-e992b07a9e46">Loading BokehJS ...</span>
#     </div>

# %%
class ImportOpta(object):
    def __init__(self, path, run=True):
        self.path = path
        self.file_paths = []
        self.instances = []
        
        if run:
            self.get_file_paths()
            self.create_instances()
            
    def get_file_paths(self):
        for folder_name in os.listdir(self.path)[1:]: # loop through items in dir
            folder_path = self.path + '/' + folder_name
            zip_file_name = os.listdir(folder_path)[-1]
            if zip_file_name.endswith(".zip"): # check for ".zip" extension
                zip_file_path = folder_path + '/' + zip_file_name # get full path of files
                zip_ref = zipfile.ZipFile(zip_file_path, 'r') # create zipfile object
                zip_ref.extractall(folder_path) # extract file to dir
                zip_ref.close() # close file
                os.remove(zip_file_path) # delete zipped file
            folder_items = os.listdir(folder_path)
            for file_name in folder_items:
                if 'f24' in file_name:
                    self.file_paths.append(folder_path + '/' + file_name)
                    break
                elif 'Opta' in file_name or 'opta_import' == file_name:
                    sub_folder_path = folder_path + '/' + file_name
                    sub_folder_items = os.listdir(sub_folder_path)
                    for file_name2 in sub_folder_items:
                        if 'f24' in file_name2:
                            self.file_paths.append(sub_folder_path + '/' + file_name2)
                            
    def create_instances(self):
        for file_path in self.file_paths:
            with open(file_path) as fd:
                [self.instances.append(Shot(item)) for item in xmltodict.parse(fd.read())['Games']['Game']['Event'] 
                 if item['@type_id'] in ['13', '14', '15', '16']];

# %%
class BodyPart(enum.Enum):
    head = 0
    left_foot = 1
    right_foot = 2
    other = 3
    none = 4

# %%
 class ShotPitchLocation(enum.Enum):
    small_box_center = 0
    box_center = 1
    out_of_box_center = 2
    center_35_plus = 3
    small_box_right = 4
    small_box_left = 5
    box_deep_right = 6
    box_right = 7
    box_left = 8
    box_deep_left = 9
    out_of_box_deep_right = 10
    out_of_box_right = 11
    out_of_box_left = 12
    out_of_box_deep_left = 13
    right_35_plus = 14
    left_35_plus = 15
    none = 16

# %%
class ShotGoalLocation(enum.Enum):
    left = 0
    high = 1
    right = 2
    low_left = 3
    high_left = 4
    low_center = 5
    high_center = 6
    low_right = 7
    high_right = 8
    blocked = 9
    close_left = 10
    close_right = 11
    close_high = 12
    close_left_and_high = 13
    close_right_and_high = 14
    none = 15

# %%
class PatternOfPlay(enum.Enum):
    regular_play = 0
    fast_break = 1
    set_piece = 2
    from_corner = 3
    from_kick = 4
    penalty_kick = 5
    throw_in = 6
    none = 7

# %%
class ShotResult(enum.Enum):
    miss = 0
    post = 1
    saved = 2
    goal = 3
    none = 4

# %%
class Assisted(enum.Enum):
    yes = 1
    no = 0
# Out:
# time: 1.44 ms

# %%
class IndividualPlay(enum.Enum):
    yes = 1
    no = 0
# Out:
# time: 1.28 ms

# %%
class Made(enum.Enum):
    yes = 1
    no = 0
# Out:
# time: 1.35 ms

# %%
class Shot(object):
    def __init__(self, item):
        self.item = item
        self.pitch_length = 105.0
        self.pitch_width = 68.0
        
    @property
    def x_raw(self):
        return float(self.item['@x'])
    
    @property
    def y_raw(self):
        return float(self.item['@y'])
    
    @property
    def x(self):
        return self.x_raw / 100.0 * self.pitch_length
    
    @property
    def y(self):
        return self.y_raw / 100.0 * self.pitch_width
    
    @property
    def minute(self):
        return self.item['@min']
    
    @property
    def second(self):
        return self.item['@sec']
    
    @property
    def team(self):
        return self.item['@team_id']
    
    @property
    def shot_result(self):
        if self.item['@type_id'] == '13':
            return ShotResult.miss
        elif self.item['@type_id'] == '14':
            return ShotResult.post
        elif self.item['@type_id'] == '15':
            return ShotResult.saved
        elif self.item['@type_id'] == '16':
            return ShotResult.goal
        else:
            return ShotResult.none
    
    @property
    def made(self):
        if self.item['@type_id'] == '16':
            return Made.yes
        else:
            return Made.no
    
    @property
    def distance_raw(self):
        return np.sqrt((abs(float(self.y_raw) - 50))**2 + ((100 - float(self.x_raw)))**2)
    
    @property
    def distance(self):
        return np.sqrt((abs(float(self.y) - self.pitch_width * .5))**2 + 
                       ((self.pitch_length - float(self.x)))**2)
    
    @property
    def qualifiers(self):
        return [qualifier['@qualifier_id'] for qualifier in self.item['Q']]
    
    @property
    def body_part(self):
        if '15' in self.qualifiers:
            return BodyPart.head
        elif '72' in self.qualifiers:
            return BodyPart.left_foot
        elif '20' in self.qualifiers:
            return BodyPart.right_foot
        elif '21' in self.qualifiers:
            return BodyPart.other
        else:
            return BodyPart.none
    
    @property
    def assisted(self):
        if '29' in self.qualifiers:
            return Assisted.yes
        else:
            return Assisted.no
    
    @property
    def individual_play(self):
        if '215' in self.qualifiers:
            return IndividualPlay.yes
        else:
            return IndividualPlay.no
    
    @property
    def shot_pitch_location(self):
        if '16' in self.qualifiers:
            return ShotPitchLocation.small_box_center
        elif '17' in self.qualifiers:
            return ShotPitchLocation.box_center
        elif '18' in self.qualifiers:
            return ShotPitchLocation.out_of_box_center
        elif '19' in self.qualifiers:
            return ShotPitchLocation.center_35_plus
        elif '60' in self.qualifiers:
            return ShotPitchLocation.small_box_right
        elif '61' in self.qualifiers:
            return ShotPitchLocation.small_box_left
        elif '62' in self.qualifiers:
            return ShotPitchLocation.box_deep_right
        elif '63' in self.qualifiers:
            return ShotPitchLocation.box_right
        elif '64' in self.qualifiers:
            return ShotPitchLocation.box_left
        elif '65' in self.qualifiers:
            return ShotPitchLocation.box_deep_left
        elif '66' in self.qualifiers:
            return ShotPitchLocation.out_of_box_deep_right
        elif '67' in self.qualifiers:
            return ShotPitchLocation.out_of_box_right
        elif '68' in self.qualifiers:
            return ShotPitchLocation.out_of_box_left
        elif '69' in self.qualifiers:
            return ShotPitchLocation.out_of_box_deep_left
        elif '70' in self.qualifiers:
            return ShotPitchLocation.right_35_plus
        elif '71' in self.qualifiers:
            return ShotPitchLocation.left_35_plus
        else:
            return ShotPitchLocation.none
        
    @property
    def shot_goal_location(self):
        if '73' in self.qualifiers:
            return ShotGoalLocation.left
        elif '74' in self.qualifiers:
            return ShotGoalLocation.high
        elif '75' in self.qualifiers:
            return ShotGoalLocation.right
        elif '76' in self.qualifiers:
            return ShotGoalLocation.low_left
        elif '77' in self.qualifiers:
            return ShotGoalLocation.high_left
        elif '78' in self.qualifiers:
            return ShotGoalLocation.low_center
        elif '79' in self.qualifiers:
            return ShotGoalLocation.high_center
        elif '80' in self.qualifiers:
            return ShotGoalLocation.low_right
        elif '81' in self.qualifiers:
            return ShotGoalLocation.high_right
        elif '82' in self.qualifiers:
            return ShotGoalLocation.blocked
        elif '83' in self.qualifiers:
            return ShotGoalLocation.close_left
        elif '84' in self.qualifiers:
            return ShotGoalLocation.close_right
        elif '85' in self.qualifiers:
            return ShotGoalLocation.close_high
        elif '86' in self.qualifiers:
            return ShotGoalLocation.close_left_and_high
        elif '87' in self.qualifiers:
            return ShotGoalLocation.close_right_and_high
        else:
            return ShotGoalLocation.none
    
    @property
    def pattern_of_play(self):
        if '22' in self.qualifiers:
            return PatternOfPlay.regular_play
        elif '23' in self.qualifiers:
            return PatternOfPlay.fast_break
        elif '24' in self.qualifiers:
            return PatternOfPlay.set_piece
        elif '25' in self.qualifiers:
            return PatternOfPlay.from_corner
        elif '26' in self.qualifiers:
            return PatternOfPlay.from_kick
        elif '9' in self.qualifiers:
            return PatternOfPlay.penalty_kick
        elif '160' in self.qualifiers:
            return PatternOfPlay.throw_in
        else:
            return PatternOfPlay.none
# Out:
# time: 229 ms

# %%
instances = ImportOpta('/Users/jason.katz/Downloads/AllOpta')
# Out:
# time: 1min 21s

# %%
def opta_hists(prop):
    enum = type(getattr(instances.instances[0],prop))
    members = '__members__'
    goal_percentage = [np.mean([result.made for result in instances.instances if getattr(result,prop) == option]) 
                       for option in enum.__members__.values()][:-1]
    categories = [option for option in enum.__members__.keys()][:-1]
    data1 = {'label': categories,'values': goal_percentage}
    plot1 = Bar(data = data1, values = 'values', label = 'label', title = prop + ' goal percentages', legend=False)
    data2 = pd.DataFrame.from_dict(Counter([getattr(result,prop).name for result in instances.instances]), 
                                  orient='index')
    data2['name'] = data2.index
    
    data2 = {'label': data2['name'], 'values': data2[0]}
    
    plot2 = Bar(data = data2, values = 'values', label = 'label', title = prop + ' counts', legend=False)
    try: 
        show(plot1)
    except AttributeError:
        pass
    try: 
        show(plot2)
    except AttributeError:
        pass
    show(plot1)
    show(plot2)
# Out:
# time: 17.2 ms

# %%
opta_hists('pattern_of_play')
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2a30ba06-168b-4ce6-bb17-a5232181ea25"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2a30ba06-168b-4ce6-bb17-a5232181ea25");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2a30ba06-168b-4ce6-bb17-a5232181ea25");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2a30ba06-168b-4ce6-bb17-a5232181ea25' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5995a891-0a3b-443c-ba8b-212edcd301b0":{"roots":{"references":[{"attributes":{"data_source":{"id":"59e00d89-a77c-4812-8db8-6053e25efc5b","type":"ColumnDataSource"},"glyph":{"id":"4d3bf255-c3b3-4ac0-bdca-400d5540ce36","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"414aec1c-19ec-4531-bef2-da8683af5ac7","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["fast_break","from_corner","from_kick","penalty_kick","regular_play","set_piece","throw_in"]},"id":"80f4dc96-d38b-49ea-b00c-8addc986895c","type":"FactorRange"},{"attributes":{},"id":"069af7b3-118d-4740-94ab-d648264a7463","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"pattern_of_play goal percentages"},"id":"7d9230f9-df14-4258-aac5-25722f2fa917","type":"Title"},{"attributes":{},"id":"389ae4a9-190a-457a-aaf1-b9b9ba96469a","type":"ToolEvents"},{"attributes":{"plot":{"id":"ab15460c-7e80-4b54-822c-56556402d774","subtype":"Chart","type":"Plot"}},"id":"66d3420d-9441-4b52-8172-2c4f7355e2af","type":"HelpTool"},{"attributes":{"data_source":{"id":"476c77a9-db8c-441e-a990-a90ac0c3efe8","type":"ColumnDataSource"},"glyph":{"id":"9cfc4c7b-54bb-49c5-b0e1-d3ab6ff112ff","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"08d9f9df-9103-4676-9830-9c349a12c4f0","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ece91c13-4e48-40ce-aca8-a0f1ce8eb69b","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"fast_break"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.30158730158730157],"label":["fast_break"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["fast_break"],"y":[0.15079365079365079]}},"id":"5d4bfc6d-ed18-49c0-ac92-c0b99f64e28c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"set_piece"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.11363636363636363],"label":["set_piece"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["set_piece"],"y":[0.056818181818181816]}},"id":"c343da7b-86aa-435a-a7df-04bde9a67fa4","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ab15460c-7e80-4b54-822c-56556402d774","subtype":"Chart","type":"Plot"}},"id":"d38a0651-170e-4140-81ce-42757169331c","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"from_kick"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.064],"label":["from_kick"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["from_kick"],"y":[0.032]}},"id":"476c77a9-db8c-441e-a990-a90ac0c3efe8","type":"ColumnDataSource"},{"attributes":{},"id":"c158e1be-ae5d-4dcb-891c-e4cfd09f7c95","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5f65d6d5-2b72-45e0-b26f-57c60b966ef5","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ed37a2cf-d1ce-42e0-a4d3-b26b4fe95d86","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"from_corner"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.09799554565701558],"la ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3e2c40fb-c642-4b32-82b1-6395c083997f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3e2c40fb-c642-4b32-82b1-6395c083997f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3e2c40fb-c642-4b32-82b1-6395c083997f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3e2c40fb-c642-4b32-82b1-6395c083997f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"22234086-941e-4204-ac54-f9d90297df30":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"penalty_kick"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[114.0],"label":["penalty_kick"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["penalty_kick"],"y":[57.0]}},"id":"b68ac363-a4ad-4475-9197-ff758882f8e2","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a1f15226-fc28-4bc9-823b-25b9e79b181e","type":"ColumnDataSource"},"glyph":{"id":"a75ac2ce-3aee-4cc3-bfaf-d91a3bf537e6","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"659fc4a7-fc6f-4274-8875-04e36347b052","type":"GlyphRenderer"},{"attributes":{"axis_label":"Label","formatter":{"id":"c0052a4e-130f-41d9-b4c0-4a3dde1c7b22","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"5d5ce9ae-2803-41e0-8c81-f4c115c5d1f1","subtype":"Chart","type":"Plot"},"ticker":{"id":"01af127a-40bb-4199-a62b-870db9a8406a","type":"CategoricalTicker"}},"id":"5fd13b35-3858-4975-8bf8-52efa2c2716c","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"5d5ce9ae-2803-41e0-8c81-f4c115c5d1f1","subtype":"Chart","type":"Plot"}},"id":"1f8ed4a8-a5c2-450a-abaa-8cd33d1a2fab","type":"ResetTool"},{"attributes":{"axis_label":"Sum( Values )","formatter":{"id":"650df15a-406c-46f1-8a88-b853c559b4c9","type":"BasicTickFormatter"},"plot":{"id":"5d5ce9ae-2803-41e0-8c81-f4c115c5d1f1","subtype":"Chart","type":"Plot"},"ticker":{"id":"5fc00794-b84d-4254-acbe-5d6b629d0c1e","type":"BasicTicker"}},"id":"09f6a497-9a33-4e59-ba63-2165fd8ee841","type":"LinearAxis"},{"attributes":{"data_source":{"id":"7cbad42f-18d6-485f-b405-219667da111f","type":"ColumnDataSource"},"glyph":{"id":"a5dbd4ba-0107-4f6a-8c19-04d87919a263","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"3d5d76f0-b394-4bbd-9146-4f832c127672","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5d5ce9ae-2803-41e0-8c81-f4c115c5d1f1","subtype":"Chart","type":"Plot"}},"id":"342ed6ed-ae63-4238-a78b-6414eae9bab8","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2220b3f3-e07a-4333-b409-0a9e9f748f5f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a75ac2ce-3aee-4cc3-bfaf-d91a3bf537e6","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f1e4cfba-11f9-4fb6-9f10-23188d17a8bd","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"d679c621-a21c-46c5-9234-9df7eda2e2cb","type":"ColumnDataSource"},"glyph":{"id":"5146aa3f-fd12-430c-8d53-0c465dbb0e17","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"902ca15b-6733-4f51-90b6-284df88814f8","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ffd22072-febb-4ca8-8f05-3b2be3c3aeed","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"set_piece"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[748.0],"label":["set_piece"],"line_alpha":[1.0],"line_color" ...
# time: 1.04 s

# %%
opta_hists('body_part')
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b5b0e46a-8dc3-403a-b1c6-84ed9b817807"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b5b0e46a-8dc3-403a-b1c6-84ed9b817807");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b5b0e46a-8dc3-403a-b1c6-84ed9b817807");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b5b0e46a-8dc3-403a-b1c6-84ed9b817807' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c109f831-0768-49c4-b35c-b802fcbcd583":{"roots":{"references":[{"attributes":{"below":[{"id":"26e826c2-209c-4591-9d13-25eba0eaff0e","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"14199a9d-9cdb-41dd-adf6-567c19282563","type":"LinearAxis"}],"renderers":[{"id":"71686aff-920d-4ea4-aca5-62a9252e59e7","type":"BoxAnnotation"},{"id":"8df0fa83-42bf-42c1-9053-e188e8682d90","type":"GlyphRenderer"},{"id":"684c3ea9-2f92-42ba-8656-38e295e6eafb","type":"GlyphRenderer"},{"id":"e64cbff2-c852-4933-8faf-96cf64673d0f","type":"GlyphRenderer"},{"id":"1dc41755-93ea-47c4-977e-e163282b55ed","type":"GlyphRenderer"},{"id":"26e826c2-209c-4591-9d13-25eba0eaff0e","type":"CategoricalAxis"},{"id":"14199a9d-9cdb-41dd-adf6-567c19282563","type":"LinearAxis"},{"id":"075305ee-88ad-458d-b169-90a9f770c3ac","type":"Grid"}],"title":{"id":"73775fbe-adc1-4941-9c77-9714982ef7b8","type":"Title"},"tool_events":{"id":"3de88146-fb36-4f23-a688-65273a4c12be","type":"ToolEvents"},"toolbar":{"id":"2ef273f9-8a63-4ffe-88cf-f28e4929074b","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"b7b5aa34-2a6b-4b93-8ff5-8fc9766401bf","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"167725f0-eecc-43e0-906c-7a1d657f5d18","type":"Range1d"}},"id":"92f84523-05ab-4087-84b9-4d3c6551495c","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"831b7acc-8354-48cb-8fc0-8d39d595614d","type":"Rect"},{"attributes":{"data_source":{"id":"3e45c878-4a4e-4e54-a952-140d0fafd800","type":"ColumnDataSource"},"glyph":{"id":"fa2c82d1-edaa-43a2-b48f-96014c12f5e9","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e64cbff2-c852-4933-8faf-96cf64673d0f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"head"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.1251342642320086],"label":["head"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["head"],"y":[0.0625671321160043]}},"id":"a696b640-912e-4686-88cd-40489799ad7f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a4e82773-e8d8-4bd2-88a2-d92e02ee9f7f","type":"ColumnDataSource"},"glyph":{"id":"0fe47a5d-dace-469b-a9cf-8586c4726aa6","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"1dc41755-93ea-47c4-977e-e163282b55ed","type":"GlyphRenderer"},{"attributes":{"axis_label":"Sum( Values )","formatter":{"id":"6fcef88b-fe09-4d69-8ab4-1243a6e8456e","type":"BasicTickFormatter"},"plot":{"id":"92f84523-05ab-4087-84b9-4d3c6551495c","subtype":"Chart","type":"Plot"},"ticker":{"id":"f2e965ef-0290-4698-be93-e24923135faf","type":"BasicTicker"}},"id":"14199a9d-9cdb-41dd-adf6-567c19282563","type":"LinearAxis"},{"attributes":{"callback":null,"factors":["head","left_foot","other","right_foot"]},"id":"b7b5aa34-2a6b-4b93-8ff5-8fc9766401bf","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"right_foot"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.10573678290213723],"label":["right_foot"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["right_foot"],"y":[0.052868391451068614]}},"id":"3e45c878-4a4e-4e54-a952-140d0fafd800","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"92f84523-05ab-4087-84b9-4d3c6551495c","subtype":"Chart","type":"Plot"}},"id":"aac2c481-00d1-47af-b722-8d81ba70ed52","type":"PanTool"},{"attributes":{},"id":"3de88146-fb36-4f23-a688-65273a4c12be","type":"ToolEvents"},{"attributes":{},"id":"6fcef88b-fe09-4d69-8ab4-1243a6e8456e","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height", ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9d83c469-e5a7-42b1-afa8-38ee0b21de8e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9d83c469-e5a7-42b1-afa8-38ee0b21de8e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d83c469-e5a7-42b1-afa8-38ee0b21de8e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d83c469-e5a7-42b1-afa8-38ee0b21de8e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c10af8d5-794f-4d51-af9b-9752f4612e94":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"head"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1862.0],"label":["head"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["head"],"y":[931.0]}},"id":"cab46fd5-8571-45be-a593-fbaa2afa6eb9","type":"ColumnDataSource"},{"attributes":{"axis_label":"Label","formatter":{"id":"efc96e2b-6667-4b60-a8ec-a0a7baa80594","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"35649491-24ff-48fb-91bf-80083bbf0c8f","subtype":"Chart","type":"Plot"},"ticker":{"id":"873e137f-68c7-45bd-afef-c8fa5ed5eae3","type":"CategoricalTicker"}},"id":"e85c9332-7498-44e9-a5ab-1f167052108d","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f62cc403-b42b-44a4-9a5a-45f0974569a9","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"35649491-24ff-48fb-91bf-80083bbf0c8f","subtype":"Chart","type":"Plot"},"ticker":{"id":"c9f0eee4-72f5-45f6-90dc-7d2e59011414","type":"BasicTicker"}},"id":"241b3602-c94a-4f0b-bde5-055bf5b04c0b","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3edf417e-9f02-49e0-815d-8862f23467b6","type":"Rect"},{"attributes":{"below":[{"id":"e85c9332-7498-44e9-a5ab-1f167052108d","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"d36f54d9-5157-47fd-bb9c-afdc7eccfbc2","type":"LinearAxis"}],"renderers":[{"id":"913e96b9-7214-4672-822b-649ede08fdbc","type":"BoxAnnotation"},{"id":"93ec00a6-a367-4f25-9e47-426c3e26b133","type":"GlyphRenderer"},{"id":"b727151d-be0d-4c41-a2af-6f4110790fe1","type":"GlyphRenderer"},{"id":"1697b8e4-072c-4498-ba67-cb7568e7d757","type":"GlyphRenderer"},{"id":"aee5ebc1-1e18-4eaa-82b8-89e0e0696b64","type":"GlyphRenderer"},{"id":"e85c9332-7498-44e9-a5ab-1f167052108d","type":"CategoricalAxis"},{"id":"d36f54d9-5157-47fd-bb9c-afdc7eccfbc2","type":"LinearAxis"},{"id":"241b3602-c94a-4f0b-bde5-055bf5b04c0b","type":"Grid"}],"title":{"id":"1ada6f13-b4ba-4ee3-a832-178009b2bfbd","type":"Title"},"tool_events":{"id":"54fa52bd-f138-4ded-9158-b8372eb49d6b","type":"ToolEvents"},"toolbar":{"id":"b7fc37cd-1b47-4b26-9e79-6c80fbed3efd","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"367a33c0-f23c-4ad8-a5e9-4c3ff6f0aaa0","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"98dcabea-0fe8-4565-90af-3922a878ff1b","type":"Range1d"}},"id":"35649491-24ff-48fb-91bf-80083bbf0c8f","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"c9f0eee4-72f5-45f6-90dc-7d2e59011414","type":"BasicTicker"},{"attributes":{"axis_label":"Sum( Values )","formatter":{"id":"15b7e286-a6bf-41ff-9cc9-e29eef329ca5","type":"BasicTickFormatter"},"plot":{"id":"35649491-24ff-48fb-91bf-80083bbf0c8f","subtype":"Chart","type":"Plot"},"ticker":{"id":"c9f0eee4-72f5-45f6-90dc-7d2e59011414","type":"BasicTicker"}},"id":"d36f54d9-5157-47fd-bb9c-afdc7eccfbc2","type":"LinearAxis"},{"attributes":{"overlay":{"id":"913e96b9-7214-4672-822b-649ede08fdbc","type":"BoxAnnotation"},"plot":{"id":"35649491-24ff-48fb-91bf-80083bbf0c8f","subtype":"Chart","type":"Plot"}},"id":"9f00c648-919c-4e49-b8ce-ba5e0059bcb6","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9 ...
# time: 756 ms

# %%
opta_hists('shot_pitch_location')
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="121167b4-af58-4154-8405-cfec776f608c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("121167b4-af58-4154-8405-cfec776f608c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("121167b4-af58-4154-8405-cfec776f608c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '121167b4-af58-4154-8405-cfec776f608c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"540817a7-c823-4f9e-8451-f605682c5afa":{"roots":{"references":[{"attributes":{"callback":null,"end":0.4990909090909091},"id":"3bc7a6d9-021d-4b74-9bde-8e00978d0860","type":"Range1d"},{"attributes":{"data_source":{"id":"fc0f33b5-13b9-4b0c-ba05-e9414ee37491","type":"ColumnDataSource"},"glyph":{"id":"2070cd76-66ef-4146-801f-49f557296e46","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"38658912-63a3-4d83-9949-7270acf9c610","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"510f47cb-9524-4037-90c5-0f59c0ad9c38","type":"ColumnDataSource"},"glyph":{"id":"113cbed6-2273-4d77-a0be-dd4371953709","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"16b1af07-8624-43ca-95ac-183ee76583c9","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2070cd76-66ef-4146-801f-49f557296e46","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"small_box_right"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.16062176165803108],"label":["small_box_right"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["small_box_right"],"y":[0.08031088082901554]}},"id":"510f47cb-9524-4037-90c5-0f59c0ad9c38","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b9ee76ac-4c9c-4766-b51e-c421aecb5db2","type":"ColumnDataSource"},"glyph":{"id":"00520185-49a6-4a8c-b180-3825527bc9af","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"962134e1-c2c5-43de-998a-c9fc3e0ce9ee","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a71586eb-a987-4dc9-8876-f36af3587fe8","type":"Rect"},{"attributes":{"below":[{"id":"95210cf0-e18a-4a43-9925-a9fabee9f312","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"c7a4c732-0d12-4ca3-a933-2a29917014ca","type":"LinearAxis"}],"renderers":[{"id":"bfcd3a28-f9b7-4555-8ec2-70e147d322b9","type":"BoxAnnotation"},{"id":"fadf58c6-7b0a-44c8-8c8e-abfcd43f150f","type":"GlyphRenderer"},{"id":"98bace1f-2e2b-4ff6-92dd-dafc8dc5aec6","type":"GlyphRenderer"},{"id":"bee29cf6-90f2-4730-aadf-573ef113fdcc","type":"GlyphRenderer"},{"id":"1d8d6e04-1615-412f-97a7-2701ac40ee65","type":"GlyphRenderer"},{"id":"16b1af07-8624-43ca-95ac-183ee76583c9","type":"GlyphRenderer"},{"id":"664212ba-ef04-462d-a787-08f5361a5abf","type":"GlyphRenderer"},{"id":"38658912-63a3-4d83-9949-7270acf9c610","type":"GlyphRenderer"},{"id":"5c639b14-9bed-4fe2-ac20-0507f042d523","type":"GlyphRenderer"},{"id":"d6a6ab42-8cdc-42df-836f-49e9f66f5eab","type":"GlyphRenderer"},{"id":"fefbf540-f79a-4608-9238-81ee9bc2410f","type":"GlyphRenderer"},{"id":"962134e1-c2c5-43de-998a-c9fc3e0ce9ee","type":"GlyphRenderer"},{"id":"4ea1ddfa-d436-45a7-be91-741f2a03cada","type":"GlyphRenderer"},{"id":"7d0c2e74-ac27-4684-bb78-5ae0aa286f1c","type":"GlyphRenderer"},{"id":"fa79db26-c286-42ed-9d67-61c31f82c311","type":"GlyphRenderer"},{"id":"4a77ccf8-eebb-4431-8ee2-5c8b30fa5455","type":"GlyphRenderer"},{"id":"7849086a-c67f-46a2-a8bc-3fd6687b4b85","type":"GlyphRenderer"},{"id":"95210cf0-e18a-4a43-9925-a9fabee9f312","type":"CategoricalAxis"},{"id":"c7a4c732-0d12-4ca3-a933-2a29917014ca","type":"LinearAxis"},{"id":"8a585c0f-3ee7-4960-b47c-32c2114659d1","type":"Grid"}],"title":{"id":"77201301-0bf5-4395-b4e9-84dbf521a2fb","type":"Title"},"tool_events":{"id":"15a132e5-13cd-4066-b1e0-3b5606e1588f","type":"ToolEvents"},"toolbar":{"id":"aa4feceb-4e25-444a-ae23-f8690c9b3819","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"f67c6bcb-b4a8-4cf5-9054-abdb4774ed14","type":"FactorRange"},"y_mapper_ty ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7f34cab9-e849-4ece-b7ea-87b886bf0123"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7f34cab9-e849-4ece-b7ea-87b886bf0123");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7f34cab9-e849-4ece-b7ea-87b886bf0123");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7f34cab9-e849-4ece-b7ea-87b886bf0123' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c60677d0-734a-4f51-992d-ee9e42a74a3f":{"roots":{"references":[{"attributes":{"data_source":{"id":"87b147b7-bfbb-498d-940b-55136d22df3c","type":"ColumnDataSource"},"glyph":{"id":"14e00f5f-add8-4ba4-941a-97bcd4c948f3","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"871ab72e-c393-48df-b3e3-24fa314d64da","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd9c3c6a-c47d-4c8a-80c0-1456f951ad46","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"box_right"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[936.0],"label":["box_right"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["box_right"],"y":[468.0]}},"id":"ac1965e0-ab80-49de-ad1d-672b7da894c6","type":"ColumnDataSource"},{"attributes":{},"id":"611ea137-81c6-47f6-9ca2-3db0e73b062f","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b54b7cab-083d-4468-9370-c929ee42a474","type":"Rect"},{"attributes":{"data_source":{"id":"4228349d-cffe-4ba3-a01d-bfafee3ea391","type":"ColumnDataSource"},"glyph":{"id":"b54b7cab-083d-4468-9370-c929ee42a474","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"d46b6615-fe70-4c9b-9dcd-4150b6020d44","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fee6465d-4d51-4931-9d04-0c3defca10f0","type":"Rect"},{"attributes":{"plot":null,"text":"shot_pitch_location counts"},"id":"c0d74109-a0c6-48f6-9f09-5f86c2018aab","type":"Title"},{"attributes":{"below":[{"id":"725472d5-04b2-4174-bb84-34c921404b43","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"196aa2d5-e7e0-4253-8dd0-1d9711d30e3c","type":"LinearAxis"}],"renderers":[{"id":"ffc4a606-3867-41be-8b90-0837acb744ee","type":"BoxAnnotation"},{"id":"d46b6615-fe70-4c9b-9dcd-4150b6020d44","type":"GlyphRenderer"},{"id":"2699738d-781e-4839-81d4-c61de81426de","type":"GlyphRenderer"},{"id":"701da2dd-3102-435a-947e-e77830f16729","type":"GlyphRenderer"},{"id":"293d729f-7213-4748-998a-5d566676b797","type":"GlyphRenderer"},{"id":"dde6f65a-5d9a-4dbe-84d5-5e8146ff3825","type":"GlyphRenderer"},{"id":"efecac4e-9317-4ad1-944c-4612baa4d462","type":"GlyphRenderer"},{"id":"5a1ff0ec-635e-43c0-a4a5-7edb9b7f211c","type":"GlyphRenderer"},{"id":"d7081655-b8f9-4cbe-a248-14d15b7cdc73","type":"GlyphRenderer"},{"id":"871ab72e-c393-48df-b3e3-24fa314d64da","type":"GlyphRenderer"},{"id":"45134409-af9d-4258-a1a5-191001b532de","type":"GlyphRenderer"},{"id":"bdb0588e-74cb-4630-8364-c685966372b8","type":"GlyphRenderer"},{"id":"d572509f-f5b2-4c59-805f-94933d94c4e3","type":"GlyphRenderer"},{"id":"db2d6e6e-3174-476f-8786-f04ee530c546","type":"GlyphRenderer"},{"id":"ce280832-6b8c-42c8-862d-01fe04b63b8d","type":"GlyphRenderer"},{"id":"fca23dc9-cdd5-4d19-9122-41f92f062823","type":"GlyphRenderer"},{"id":"725472d5-04b2-4174-bb84-34c921404b43","type":"CategoricalAxis"},{"id":"196aa2d5-e7e0-4253-8dd0-1d9711d30e3c","type":"LinearAxis"},{"id":"67956f23-7182-42aa-b871-a70442d94578","type":"Grid"}],"title":{"id":"c0d74109-a0c6-48f6-9f09-5f86c2018aab","type":"Title"},"tool_events":{"id":"611ea137-81c6-47f6-9ca2-3db0e73b062f","type":"ToolEvents"},"toolbar":{"id":"0f0a3c07-a8ad-47de-bd92-b69dd75ddb9d","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"c6f57757-9b76-4a92-a2f4-593fbe7879d9","type":"FactorRange"},"y_mapper_type":"a ...
# time: 2.57 s

# %%
opta_hists('assisted')
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="42bdaebb-dd5f-4965-a0dc-0d7f472c9b50"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("42bdaebb-dd5f-4965-a0dc-0d7f472c9b50");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("42bdaebb-dd5f-4965-a0dc-0d7f472c9b50");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '42bdaebb-dd5f-4965-a0dc-0d7f472c9b50' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"967cac4b-47df-4824-ac69-667659eabb88":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"no"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.13538149898717083],"label":["no"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["no"],"y":[0.06769074949358542]}},"id":"a1c509dd-c8de-4476-8c18-9e4bf4ddf455","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["no","yes"]},"id":"8cfcc040-6762-4bb6-94e7-848a7f2bad23","type":"FactorRange"},{"attributes":{"overlay":{"id":"9efb795e-2ed9-406a-9757-9cc8db916ec5","type":"BoxAnnotation"},"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"}},"id":"cfa79bf3-edd2-4837-89be-39453d0a8979","type":"BoxZoomTool"},{"attributes":{},"id":"2ed0d4f6-7a6a-4d03-9f22-6babed72caed","type":"ToolEvents"},{"attributes":{},"id":"879ff2c6-9575-412d-9f0a-09d1c343efe6","type":"BasicTicker"},{"attributes":{"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"}},"id":"35e3d54b-3827-4819-ba69-f20aa88b5f14","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":0.14215057393652938},"id":"de8fe202-b46b-4de2-9e45-6d5c8fc44daa","type":"Range1d"},{"attributes":{"axis_label":"Label","formatter":{"id":"a24bd718-aa28-44a2-b0ed-e1f15b5caa71","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"},"ticker":{"id":"c880ec5a-eb6a-46f3-89f7-8e374cdc6877","type":"CategoricalTicker"}},"id":"9ae4b043-7992-4739-9cc9-2cc39efbd089","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"}},"id":"ade3a1be-ac61-4341-9d92-d07c511f2da8","type":"ResetTool"},{"attributes":{"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"}},"id":"9ccea9a5-544b-4cf5-bc84-82624ec3058f","type":"HelpTool"},{"attributes":{},"id":"f8e102c7-4acf-4491-a8fa-eff016a1de3f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"}},"id":"5df6bb1f-05ef-46c9-ae3b-8b5e92c6bc60","type":"SaveTool"},{"attributes":{},"id":"a24bd718-aa28-44a2-b0ed-e1f15b5caa71","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"}},"id":"3b6d1776-1490-4794-ad8e-2840791fa7a7","type":"PanTool"},{"attributes":{"axis_label":"Sum( Values )","formatter":{"id":"f8e102c7-4acf-4491-a8fa-eff016a1de3f","type":"BasicTickFormatter"},"plot":{"id":"004cc7b7-a8fa-41cc-9aff-5b82ca68a934","subtype":"Chart","type":"Plot"},"ticker":{"id":"879ff2c6-9575-412d-9f0a-09d1c343efe6","type":"BasicTicker"}},"id":"cff41b14-b613-48b7-a0b0-6d92c4b91f2f","type":"LinearAxis"},{"attributes":{},"id":"c880ec5a-eb6a-46f3-89f7-8e374cdc6877","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e76c31c-7bf7-4ca8-8b65-6763c6aa06d0","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3b6d1776-1490-4794-ad8e-2840791fa7a7","type":"PanTool"},{"id":"35e3d54b-3827-4819-ba69-f20aa88b5f14","type":"WheelZoomTool"},{"id":"cfa79bf3-edd2-4837-89be-39453d0a8979","type":"BoxZoomTool"},{"id":"5df6bb1f-05ef-46c9-ae3b-8b5e92c6bc60","type":"SaveTool"},{"id":"ade3a1be-ac61-4341-9d92-d07c511f2da8","type":"ResetTool"},{"id":"9ccea9a5-544b-4cf5-bc84-82624ec3058f","type":"HelpTool"}]},"id":"55b5c205-be3c-4bea-9944-0db76c1909a6","type":"Toolbar"},{"attributes":{"data_source":{"id":"a1c509dd-c8de-4476-8c18-9e4bf4ddf455","type":"ColumnDataSource"},"glyph":{"id":"3e93d657-a01 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1f268229-4e51-42ff-b5f0-69ddaa1ec4f1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1f268229-4e51-42ff-b5f0-69ddaa1ec4f1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1f268229-4e51-42ff-b5f0-69ddaa1ec4f1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1f268229-4e51-42ff-b5f0-69ddaa1ec4f1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"01344fad-db94-449b-bd46-fdcddee8a672":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a492cc98-c642-40ef-825f-7aae59bd274c","type":"Rect"},{"attributes":{"overlay":{"id":"a9577737-e186-496c-b3e1-66d3459cf42f","type":"BoxAnnotation"},"plot":{"id":"8321cf23-d3b5-4649-9b3e-feb902ea27d9","subtype":"Chart","type":"Plot"}},"id":"39a133da-0ec3-46f7-b633-ee29f2ee356a","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"6e7cc30c-8767-448f-8291-5eb93baa4554","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"4a12b926-0766-44e8-8ad2-e473015d2829","type":"LinearAxis"}],"renderers":[{"id":"a9577737-e186-496c-b3e1-66d3459cf42f","type":"BoxAnnotation"},{"id":"63eb225a-10b5-408a-8f56-a2ae83cee78c","type":"GlyphRenderer"},{"id":"fb9ccd43-2369-4102-b178-bb26237571dd","type":"GlyphRenderer"},{"id":"6e7cc30c-8767-448f-8291-5eb93baa4554","type":"CategoricalAxis"},{"id":"4a12b926-0766-44e8-8ad2-e473015d2829","type":"LinearAxis"},{"id":"6592480d-be41-4de0-aec5-901786f71477","type":"Grid"}],"title":{"id":"ce285b6f-db01-4549-9350-93b00b95ae58","type":"Title"},"tool_events":{"id":"1c9a6491-88de-4c26-a509-f7760fd028a7","type":"ToolEvents"},"toolbar":{"id":"3718de7d-2be0-4214-897d-c4674c28940c","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"18bc1367-c567-45b0-8a16-a7db0a17a482","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"fd43b1ea-b659-4899-96f9-c91f2dcbd6c4","type":"Range1d"}},"id":"8321cf23-d3b5-4649-9b3e-feb902ea27d9","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"8321cf23-d3b5-4649-9b3e-feb902ea27d9","subtype":"Chart","type":"Plot"}},"id":"733a257c-d122-4877-ad96-b54853ff8662","type":"SaveTool"},{"attributes":{"plot":{"id":"8321cf23-d3b5-4649-9b3e-feb902ea27d9","subtype":"Chart","type":"Plot"}},"id":"f05dfaa9-41ec-4d8c-8a4d-be054eb919fc","type":"PanTool"},{"attributes":{"plot":{"id":"8321cf23-d3b5-4649-9b3e-feb902ea27d9","subtype":"Chart","type":"Plot"}},"id":"85a192a5-60f9-49fa-8198-857cf64bb5c0","type":"HelpTool"},{"attributes":{"callback":null,"end":9053.1},"id":"fd43b1ea-b659-4899-96f9-c91f2dcbd6c4","type":"Range1d"},{"attributes":{"axis_label":"Label","formatter":{"id":"98971847-b8e9-43cd-8853-237bfefa9b30","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"8321cf23-d3b5-4649-9b3e-feb902ea27d9","subtype":"Chart","type":"Plot"},"ticker":{"id":"66c1392c-64de-49cc-8a16-a8c33a2f1d3f","type":"CategoricalTicker"}},"id":"6e7cc30c-8767-448f-8291-5eb93baa4554","type":"CategoricalAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a9577737-e186-496c-b3e1-66d3459cf42f","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f05dfaa9-41ec-4d8c-8a4d-be054eb919fc","type":"PanTool"},{"id":"c471be5b-6bf4-485a-b17a-a5b33153ad8d","type":"WheelZoomTool"},{"id":"39a133da-0ec3-46f7-b633-ee29f2ee356a","type":"BoxZoomTool"},{"id":"733a257c-d122-4877-ad96-b54853ff8662","type":"SaveTool"},{"id":"445d764b-964e-4767-a62c-ddd6584bace2","type":"ResetTool"},{"id":"85a192a5-60f9-49fa-8198-857cf64bb5c0","type":"HelpTool"}]},"id":"3718de7d-2be0-4214-897d-c4674c28940c","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"no"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2962.0],"label":["no"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["no"],"y":[1481.0]}} ...
# time: 488 ms

# %%
opta_hists('individual_play')
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="739870f3-e306-4dd0-bbe7-c1089e6cfa2c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("739870f3-e306-4dd0-bbe7-c1089e6cfa2c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("739870f3-e306-4dd0-bbe7-c1089e6cfa2c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '739870f3-e306-4dd0-bbe7-c1089e6cfa2c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"62614a41-b25f-421c-9f81-b154878bf73a":{"roots":{"references":[{"attributes":{"axis_label":"Sum( Values )","formatter":{"id":"6b96a42d-0eb2-45d5-8c27-de7817612102","type":"BasicTickFormatter"},"plot":{"id":"8add529a-d98c-4868-b69b-d77444abf011","subtype":"Chart","type":"Plot"},"ticker":{"id":"6da3f51c-97a5-46c9-875e-73267cc7ca75","type":"BasicTicker"}},"id":"3c13b077-97b0-45ea-9b24-b24dfe4f3478","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"no"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.1557822010199046],"label":["no"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["no"],"y":[0.0778911005099523]}},"id":"7d1a9d5a-7bee-4103-9420-ce6a75ee5445","type":"ColumnDataSource"},{"attributes":{"axis_label":"Label","formatter":{"id":"fb097c59-8d8c-4710-8d17-b8f0f7640d14","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"8add529a-d98c-4868-b69b-d77444abf011","subtype":"Chart","type":"Plot"},"ticker":{"id":"4334720e-be1a-4576-9847-91701b78510c","type":"CategoricalTicker"}},"id":"1ad9ecf3-8cf3-4080-aff3-4a7f0767a737","type":"CategoricalAxis"},{"attributes":{},"id":"fb097c59-8d8c-4710-8d17-b8f0f7640d14","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"end":0.1635713110708998},"id":"b70c6dcc-e28d-4736-9d80-2f2864ab2d48","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"679f4e9e-13e5-46cb-a044-0dbf0c47843c","type":"Rect"},{"attributes":{"plot":{"id":"8add529a-d98c-4868-b69b-d77444abf011","subtype":"Chart","type":"Plot"}},"id":"227d1600-dc4b-42be-9b9f-eee8c991fb4f","type":"HelpTool"},{"attributes":{"plot":{"id":"8add529a-d98c-4868-b69b-d77444abf011","subtype":"Chart","type":"Plot"}},"id":"e8763b8d-afa0-417e-8970-276055545bed","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"8add529a-d98c-4868-b69b-d77444abf011","subtype":"Chart","type":"Plot"}},"id":"9b761aa6-23c4-4cdc-976c-bad9e745300c","type":"PanTool"},{"attributes":{"data_source":{"id":"7d1a9d5a-7bee-4103-9420-ce6a75ee5445","type":"ColumnDataSource"},"glyph":{"id":"b9ea1d75-8134-4ef1-971c-2485e9e79840","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"6b7a2aae-be6f-460f-85d3-a23e018a9326","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"27ffa573-c7c4-46c5-a075-feaa03527f97","type":"BoxAnnotation"},"plot":{"id":"8add529a-d98c-4868-b69b-d77444abf011","subtype":"Chart","type":"Plot"}},"id":"9537bcb3-7084-401d-9db4-eb79023aa5f0","type":"BoxZoomTool"},{"attributes":{},"id":"6da3f51c-97a5-46c9-875e-73267cc7ca75","type":"BasicTicker"},{"attributes":{"plot":null,"text":"individual_play goal percentages"},"id":"cf32024e-7632-49f6-82f0-d7e8dc1c7c8b","type":"Title"},{"attributes":{},"id":"6b96a42d-0eb2-45d5-8c27-de7817612102","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"8add529a-d98c-4868-b69b-d77444abf011","subtype":"Chart","type":"Plot"},"ticker":{"id":"6da3f51c-97a5-46c9-875e-73267cc7ca75","type":"BasicTicker"}},"id":"3f69794f-0e73-43ce-975e-612f76f24d8a","type":"Grid"},{"attributes":{"below":[{"id":"1ad9ecf3-8cf3-4080-aff3-4a7f0767a737","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"3c13b077-97b0-45ea-9b24-b24dfe4f3478","type":"LinearAxis"}],"renderers":[{"id":"27ffa573-c7c4-46c5-a075-feaa03527f97","type":"BoxAnnotation"},{"id":"db47de7c-8424-412d-b218-b11ed5939ea5","type":"GlyphRenderer"},{"id":"6b7a2aae-be6f-460f-85d3-a23e018a9326","type":"GlyphRenderer"},{"id":"1ad9ecf3-8cf3-4080-aff3-4a7f0767a737","type":"CategoricalAxis"},{"id":"3c13b077-97b0-45ea-9b24-b24dfe4f3478","type":"LinearAxis"},{"id":"3f69794f-0e73-43ce-975e-612f76f24d8a","type":"Grid"}],"title":{"id":"cf32024e-7632-49f ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0639f060-d7ca-4276-976b-15425b419966"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0639f060-d7ca-4276-976b-15425b419966");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0639f060-d7ca-4276-976b-15425b419966");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0639f060-d7ca-4276-976b-15425b419966' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"17564690-34a9-48b1-b506-b729f15ac184":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"40bd4bdb-5075-4688-8f02-ec5ae3d83644","type":"PanTool"},{"id":"7febe486-a506-42a1-b2ee-b90eef1ab747","type":"WheelZoomTool"},{"id":"ab44c3f8-49e5-4698-ab45-9a927bd5ea42","type":"BoxZoomTool"},{"id":"e30509eb-e743-4d21-804f-57d9d7778d32","type":"SaveTool"},{"id":"b8fbcc4c-a93c-421c-9f83-3cdeb6d06ca0","type":"ResetTool"},{"id":"7cf6a98b-add3-405c-8f9f-ec0241266309","type":"HelpTool"}]},"id":"607bade6-f617-4e1f-b7d2-aedd20bc50da","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1821d3d2-d5d0-4153-ac5c-bf618ca238a0","type":"BoxAnnotation"},{"attributes":{"callback":null,"factors":["no","yes"]},"id":"db425ed4-5239-43a8-a7ab-8a876eabfcb2","type":"FactorRange"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2889836e-39a0-4018-8470-8e31c3b23f0e","type":"Rect"},{"attributes":{"plot":{"id":"b20b8dbd-ab41-4d45-9cb7-7a1241eca5a5","subtype":"Chart","type":"Plot"}},"id":"40bd4bdb-5075-4688-8f02-ec5ae3d83644","type":"PanTool"},{"attributes":{"plot":{"id":"b20b8dbd-ab41-4d45-9cb7-7a1241eca5a5","subtype":"Chart","type":"Plot"}},"id":"7cf6a98b-add3-405c-8f9f-ec0241266309","type":"HelpTool"},{"attributes":{"plot":null,"text":"individual_play counts"},"id":"1ddd3c07-8ac4-4571-90c5-93d89b7c8ed0","type":"Title"},{"attributes":{"overlay":{"id":"1821d3d2-d5d0-4153-ac5c-bf618ca238a0","type":"BoxAnnotation"},"plot":{"id":"b20b8dbd-ab41-4d45-9cb7-7a1241eca5a5","subtype":"Chart","type":"Plot"}},"id":"ab44c3f8-49e5-4698-ab45-9a927bd5ea42","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b09ef025-ad04-4af8-a6c4-1d97a35ac644","type":"Rect"},{"attributes":{},"id":"de8cf7fc-1149-4e5b-9340-475fc40ef562","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"end":6382.95},"id":"bcbd3214-6b14-43e6-b528-5695ed8053da","type":"Range1d"},{"attributes":{"data_source":{"id":"459838bb-2540-4afe-bbaf-54d976fe67ac","type":"ColumnDataSource"},"glyph":{"id":"b09ef025-ad04-4af8-a6c4-1d97a35ac644","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4a5cbee6-f55c-4216-bb92-389931aae8a5","type":"GlyphRenderer"},{"attributes":{},"id":"72b9853e-5362-4372-9bc8-4d82603b6dc0","type":"ToolEvents"},{"attributes":{"data_source":{"id":"0c8817f9-3fc0-48ad-8ef3-0897c44cfa65","type":"ColumnDataSource"},"glyph":{"id":"2889836e-39a0-4018-8470-8e31c3b23f0e","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e65b69d6-9209-45d0-a684-1ec81bc690da","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"b20b8dbd-ab41-4d45-9cb7-7a1241eca5a5","subtype":"Chart","type":"Plot"}},"id":"7febe486-a506-42a1-b2ee-b90eef1ab747","type":"WheelZoomTool"},{"attributes":{},"id":"15567159-73a7-48fd-9135-346f69b9f6eb","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"yes"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5505.0],"label":["yes"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["yes"],"y":[2752.5]}},"id":"459838bb-2540-4afe-bbaf-54d976fe67ac","type":"ColumnDataSource"},{"attributes":{},"id":"20bb7efa-a5ab-4428-9ac6-d9ba9d7cae41","type":"BasicTi ...
# time: 482 ms

# %%
data = pd.DataFrame({'c1': [1,2,3]})
data['c1']
# Out:
# 0    1
# 1    2
# 2    3
# Name: c1, dtype: int64
# time: 9.16 ms

# %%
pd.DataFrame.from_dict(Counter([getattr(result,'pattern_of_play').name for result in instances.instances]), 
                                  orient='index')
# Out:
#                  0
# set_piece      748
# regular_play  8236
# from_corner   1796
# fast_break     126
# from_kick      500
# penalty_kick   114
# throw_in        64
# time: 624 ms

# %%
features = ['made', 'pattern_of_play', 'body_part', 'shot_pitch_location', 'assisted', 'individual_play']
data = pd.DataFrame()
for feature in features:
    data[feature] = [getattr(result,feature).value for result in instances.instances]
locations = ['x', 'y', 'distance']
for location in locations:
    data[location] = [getattr(result,location) for result in instances.instances]
data
# Out:
#        made  pattern_of_play  body_part  shot_pitch_location  assisted  \
# 0         0                2          0                    1         1
# 1         0                2          0                    1         0
# 2         0                0          2                    2         1
# 3         0                3          1                    2         0
# 4         0                3          1                    1         1
# 5         0                0          1                    5         1
# 6         0                2          2                    2         0
# 7         0                0          1                    2         1
# 8         0                0          2                    2         1
# 9         0                0          1                    2         0
# 10        0                0          0                    1         1
# 11        0                1          1                    8         1
# 12        1                0          1                    5         1
# 13        0                0          2                    7         1
# 14        1                0          2                    7         0
# 15        0                4          2                    2         1
# 16        0                0          1                    2         1
# 17        0                3          2                    1         1
# 18        0                0          2                    2         1
# 19        0                1          1                    8         1
# 20        0                0          0                    1         1
# 21        0                0          2                    2         1
# 22        0                0          2                    2         1
# 23        0                3          1                    2         0
# 24        1                3          1                    1         0
# 25        1                0          1                    2         1
# 26        0                0          2                    7         1
# 27        1                5          2                    1         0
# 28        0                3          0                    4         1
# 29        0                0          2                    2         1
# ...     ...              ...        ...                  ...       ...
# 11554     0                0          0                    1         1
# 11555     0                0          2                    2         1
# 11556     0                0          1                    2         1
# 11557     0                0          0                    1         1
# 11558     0                2          1                    8         1
# 11559     0                3          2                    2         1
# 11560     0                2          0                    1         1
# 11561     1                0          2                    6         1
# 11562     0                2          0                    1         1
# 11563     0                0          2                    2         1
# 11564     0                2          2                    1         1
# 11565     0                4          1                    2         0
# 11566     0                2          1                    8         1
# 11567     0                0          2                    2         0
# 11568     0                0          1                    2         1
# 11569     0                0          2                    2         1
# 11570     0                0          2                    7         0
# 11571     0                3          0                    1         1
# 11572     1                3          2                    0         1
# 11573     0                0          2                    2         1
# 11574     0                0          2                    2         1
# 11575     0                0          0                    1         1
# 11576     0                0          0                    1         1
# 11577     0                0          2                    2         0
# 11578     0                0          1                    2         1
# 11579     0                0          2                    2         1
# 11580     0                0          1                    2         0
# 11581     0                0          1                    2         1
# 11582     0                4          1                    2         0
# 11583     1                0          0                    1         1
#
#        individual_play        x       y   distance
# 0                    0   95.760  26.248  12.061140
# 1                    0   97.860  35.768   7.355639
# 2                    1   76.545  35.836  28.514171
# 3                    1   83.265  42.636  23.387833
# 4                    0   93.975  37.264  11.498014
# 5                    0   99.120  39.508   8.056827
# 6                    1   82.110  30.600  23.141134
# 7                    1   78.855  42.024  27.348594
# 8                    1   82.110  49.368  27.570410
# 9                    1   86.205  23.732  21.416906
# 10                   0   97.545  34.340   7.462749
# 11                   1   93.450  45.288  16.149967
# 12                   0  101.220  42.772   9.551774
# 13                   0   95.760  21.488  15.554027
# 14                   0   91.350  22.032  18.153664
# 15                   0   84.945  33.796  20.056038
# 16                   1   76.860  33.796  28.140739
# 17                   0   94.290  28.288  12.138000
# 18                   1   83.055  41.752  23.273945
# 19                   0   95.550  45.696  15.036586
# 20                   0   96.810  29.308   9.438801
# 21                   1   79.275  39.508  26.308054
# 22                   1   83.790  51.884  27.743496
# 23                   1   83.055  33.252  21.957744
# 24                   1   90.510  30.396  14.931474
# 25                   1   74.865  34.204  30.135690
# 26                   1   91.140  21.284  18.809473
# 27                   0   92.925  33.932  12.075191
# 28                   0   99.960  29.580   6.703581
# 29                   1   85.050  23.936  22.344722
# ...                ...      ...     ...        ...
# 11554                0   95.550  32.096   9.639902
# 11555                1   81.375  49.572  28.295367
# 11556                1   85.575  35.904  19.518090
# 11557                0   97.545  38.148   8.531291
# 11558                1   89.355  47.532  20.685286
# 11559                1   79.695  28.492  25.897511
# 11560                0   96.495  32.980   8.565946
# 11561                1  100.800  24.956   9.971657
# 11562                0   94.605  37.128  10.855432
# 11563                1   75.810  31.688  29.281418
# 11564                0   96.495  36.992   9.015935
# 11565                0   73.185  32.164  31.867932
# 11566                1   95.865  45.424  14.627235
# 11567                1   74.760  22.848  32.230804
# 11568                1   81.480  20.196  27.271612
# 11569                1   80.955  22.236  26.768521
# 11570                1   96.600  22.440  14.289633
# 11571                0   94.185  38.556  11.735474
# 11572                0  100.170  31.144   5.611206
# 11573                1   79.065  22.236  28.478341
# 11574                0   86.625  37.876  18.779350
# 11575                0   92.190  37.876  13.383552
# 11576                0   97.965  35.360   7.165251
# 11577                1   82.530  32.232  22.539448
# 11578                1   75.810  30.872  29.357120
# 11579                1   79.170  48.892  29.815442
# 11580                1   81.060  48.756  28.122289
# 11581                1   80.535  50.592  29.560627
# 11582                1   73.710  32.096  31.347876
# 11583                0   99.435  33.524   5.585320
#
# [11584 rows x 9 columns]
# time: 650 ms

# %%
enc = OneHotEncoder(categorical_features=[0,1,2,3,4,5,6])
x = enc.fit_transform(data[data.columns[1:]])
y = data['made']
xtrain,xtest,ytrain,ytest  = train_test_split(x,y,random_state=2)
ytrain=np.ravel(ytrain)
#modelling 
clf = LogisticRegression(penalty='l1')
clf.fit(xtrain,ytrain)
ypred_train = clf.predict(xtrain)
ypred_test = clf.predict(xtest)
accuracy_score(ytest,ypred_test)
# Out:
# 0.91160220994475138
# time: 353 ms

# %%
clf.coef_
# Out:
# array([[-0.59054066,  0.96639931, -0.93927628, -1.24563231, -0.23166984,
#          2.29858156, -0.81965108, -0.59526841, -0.17383815, -0.04493604,
#          0.25225328,  1.2090153 ,  0.50378674, -0.4666055 , -1.24819076,
#         -0.13850803,  0.27015704, -0.59328817, -0.15052683, -0.40372386,
#         -0.13017584, -0.42125937, -0.39690668, -0.29106396,  1.78741898,
#         -0.09191839, -0.10142453, -0.46036478, -0.24428102, -0.31750829,
#          0.53766441,  1.75581093,  1.6103759 ,  1.46772098,  0.84850292,
#          0.5365597 ,  1.24188835,  0.55330837,  0.26102671,  0.35620443,
#          0.00996503,  0.06887812, -0.45082261,  0.07303282, -0.25495171,
#         -0.63470562, -0.56385202, -0.53891611, -0.64481343, -0.38543881,
#         -0.5284883 , -0.79869518, -0.59605491, -1.02717677, -1.33013354,
#         -0.8330696 , -1.61337309, -1.49298819, -1.25005715, -1.57491011,
#         -1.13832942, -1.37167432, -1.49790447, -0.20410155, -0.92462389,
#         -0.69133405, -0.17144659, -0.19626233, -0.39883928, -0.21563224,
#          0.        , -0.10923868, -0.05123591, -0.08483984, -0.03682597,
#         -0.14125178, -0.03682597, -0.09191839, -0.04556809, -0.03265   ,
#         -0.03682597,  0.        ,  0.        , -0.07128994, -0.09807484,
#         -0.03265   , -0.04556809,  0.64459745,  1.21878953,  0.        ,
#          1.52177957,  1.03451278,  1.01306136,  1.03451278,  0.63084584,
#          0.476494  ,  1.40617936,  0.46634841,  0.91081635,  2.00269337,
#          0.        ]])
# time: 4.51 ms

# %%
accuracy_score(ytrain,ypred_train)
# Out:
# 0.90032228360957645
# time: 3.62 ms

# %%
1-np.mean(data['made'])
# Out:
# 0.8933011049723757
# time: 2.92 ms

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(ytest,ypred_test)
# Out:
# array([[2575,   25],
#        [ 252,   44]])
# time: 6.19 ms

# %%
import pandas as pd
import numpy as np
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0d4209e8-5d7b-4e0a-9a76-5341a821d2e5">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/LT-HT3.csv')

# %%
data['lt'] = 1
for index, row in data.iterrows():
    data['lt'][index] = row['job_id'][-6:-3].replace("-", "")
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['ht'] = 1
for index, row in data.iterrows():
    data['ht'][index] = row['job_id'][-3:]
data['ht'][data['ht']<0]=data['ht'][data['ht']<0]*-1
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][21:27]
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data = data[data['ht']!=0]

# %%
scat_ht_1 = Scatter(data, x='ht', y='mota', color='game')
scat_lt_1 = Scatter(data, x='lt', y='mota', color='game')
show(row(scat_ht_1,scat_lt_1))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08a955d2-97cf-43d1-a1af-45ed7293bdce"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("08a955d2-97cf-43d1-a1af-45ed7293bdce");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08a955d2-97cf-43d1-a1af-45ed7293bdce");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08a955d2-97cf-43d1-a1af-45ed7293bdce' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"89f6690c-883a-403a-85f4-3bf5ae199cda":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"0a64119b-c60c-47f8-a005-4c12dd984e33","subtype":"Chart","type":"Plot"},"ticker":{"id":"18c5ff62-ab69-4065-bdcf-a4793c88bf45","type":"BasicTicker"}},"id":"cb9511f8-9239-476d-8c62-40d5db322fa0","type":"Grid"},{"attributes":{},"id":"afd4e653-aeec-47a9-beab-a3e349a3b312","type":"BasicTicker"},{"attributes":{"data_source":{"id":"eba0be47-dc4c-42e3-844c-a1ec300705ac","type":"ColumnDataSource"},"glyph":{"id":"b4b82e3a-058d-463c-94dd-6af3f5a1ceb3","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"8c078f86-0375-4008-a703-f882ed0ae3d7","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"b5dc7807-ac76-4590-8076-23d779f4850f","type":"Circle"},{"attributes":{},"id":"18c5ff62-ab69-4065-bdcf-a4793c88bf45","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"},{"game":"PS0304"}],"game":["PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304","PS0304"],"x_values":[24,29,39,34,24,29,24,24,34,39,29,29,39,34,34,39],"y_values":{"__ndarray__":"iOK+5b0s6D/2yDGJ8DnoPyGOuF2TQ+g/cor17XZJ6D/4IdD4Hk3oP1w48lmzT+g/aFYYjS9Q6D8KHuo2LlzoP69kOUjTXeg/iNKo60tf6D+6xJbU62ToP7U/QTmHaeg/NwXYoBhq6D8KpUQDRmzoP0sCkPezcOg/+dMM2Htz6D8=","dtype":"float64","shape":[16]}}},"id":"6c5df299-e694-4fe4-b52d-87328e9267d7","type":"ColumnDataSource"},{"attributes":{"axis_label":"mota","formatter":{"id":"fc68f3b3-79fc-49d0-a660-79a0cad9acc4","type":"BasicTickFormatter"},"plot":{"id":"0a64119b-c60c-47f8-a005-4c12dd984e33","subtype":"Chart","type":"Plot"},"ticker":{"id":"18c5ff62-ab69-4065-bdcf-a4793c88bf45","type":"BasicTicker"}},"id":"9882bdc4-73eb-43cb-9e22-7cba7fdbcd40","type":"LinearAxis"},{"attributes":{"children":[{"id":"0a64119b-c60c-47f8-a005-4c12dd984e33","subtype":"Chart","type":"Plot"},{"id":"93f81f9c-61f7-4cda-881b-b5b84bfff960","subtype":"Chart","type":"Plot"}]},"id":"a04ab409-bf48-4db8-9808-3bddb8a45dab","type":"Row"},{"attributes":{"data_source":{"id":"6c5df299-e694-4fe4-b52d-87328e9267d7","type":"ColumnDataSource"},"glyph":{"id":"017960c1-998b-4dad-9024-01243050ff38","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"73fc77ba-6ef7-4e8f-86e5-410c133f0608","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"59f268d2-c903-464a-b9c2-8bbaec3ca233","type":"ColumnDataSource"},"glyph":{"id":"b5dc7807-ac76-4590-8076-23d779f4850f","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"0c0b5ea4-4f13-4447-abdc-610e3e87dce6","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"0a64119b-c60c-47f8-a005-4c12dd984e33","subtype":"Chart","type":"Plot"},"ticker":{"id":"afd4e653-aeec-47a9-beab-a3e349a3b312","type":"BasicTicker"}},"id":"edcd331a-33bf-4b97-80eb-b3cca06d2f43","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"017960c1-998b-4dad-9024-01243050ff38","type":"Circle"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"}],"game":["PP0214","PP0214","PP0214", ...

# %%
data_ht = data.copy()
data_ht['hungarian'] = data_ht['ht']
data_ht = data_ht.groupby(['ht']).mean()
data_ht
# Out:
#         mota      motp      motr  mostly_tracked    mt_auc   lt  hungarian
# ht
# 24  0.760242  0.636448  0.858721        0.756731  0.853087  8.5       24.0
# 29  0.760443  0.635811  0.863485        0.770156  0.857553  8.5       29.0
# 34  0.760291  0.635404  0.866504        0.778420  0.860282  8.5       34.0
# 39  0.759723  0.635154  0.868819        0.783157  0.862400  8.5       39.0

# %%
data_lt = data.copy()
data_lt['lost'] = data_lt['lt']
data_lt = data_lt.groupby(['lt']).mean()
data_lt
# Out:
#         mota      motp      motr  mostly_tracked    mt_auc    ht  lost
# lt
# 7   0.758698  0.636655  0.855030        0.747938  0.849022  31.5   7.0
# 8   0.760219  0.635980  0.862005        0.765955  0.855958  31.5   8.0
# 9   0.760953  0.635350  0.867865        0.780884  0.861813  31.5   9.0
# 10  0.760830  0.634832  0.872628        0.793687  0.866530  31.5  10.0

# %%
scat_ht_2 = Scatter(data_ht, x = 'hungarian', y='mota')
scat_ht_3 = Scatter(data_ht, x = 'hungarian', y='motp')
scat_ht_4 = Scatter(data_ht, x = 'hungarian', y='mostly_tracked')
scat_ht_5 = Scatter(data_ht, x = 'hungarian', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat_ht_2, scat_ht_3), row(scat_ht_4, scat_ht_5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1ced7b59-ffd9-45b0-94cb-51a5431571f0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1ced7b59-ffd9-45b0-94cb-51a5431571f0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1ced7b59-ffd9-45b0-94cb-51a5431571f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1ced7b59-ffd9-45b0-94cb-51a5431571f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d8c222b6-0d6f-4031-bc96-eccdde041194":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"37085e98-0f27-41dd-8437-3191848c9f4a","type":"PanTool"},{"id":"df9af6d1-ba9d-4736-8a0e-76894117e83c","type":"WheelZoomTool"},{"id":"b3d8aa58-840a-4f5a-a8df-fe2b6129ed06","type":"BoxZoomTool"},{"id":"8b159f80-6624-40af-885c-abf769a8fc23","type":"SaveTool"},{"id":"fd736c2e-7208-49ba-8414-66181e325ae9","type":"ResetTool"},{"id":"7a4b6baa-2fee-436f-a800-20d0f6379566","type":"HelpTool"}]},"id":"cc09b821-6bbc-4bfb-859a-6d07dfac5af6","type":"Toolbar"},{"attributes":{"plot":{"id":"55314379-2fb7-4915-bd55-b6f565f85f26","subtype":"Chart","type":"Plot"},"ticker":{"id":"5d28457c-9dfa-442d-98aa-9ae6dd5fea00","type":"BasicTicker"}},"id":"6cbbac3c-5699-4522-8988-d7b87ac8cd42","type":"Grid"},{"attributes":{"callback":null,"end":40.5,"start":22.5},"id":"db0552e7-9d18-4c1f-a099-081ba35540d2","type":"Range1d"},{"attributes":{},"id":"e3f681be-d1d4-4b61-bcf8-4ae48611efd4","type":"BasicTicker"},{"attributes":{"data_source":{"id":"3525cde4-5cff-4e74-9af1-9c1520203db0","type":"ColumnDataSource"},"glyph":{"id":"5514a132-c175-4adc-afe9-4f10f589ce68","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"7eded8ab-dff1-4b24-b60b-a06fc05ef42f","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"93fc6d5d-4086-48a8-9a24-0e9ccd299d77","type":"BoxAnnotation"},"plot":{"id":"d630e73b-cdc7-4793-a520-9d6a30fa6b88","subtype":"Chart","type":"Plot"}},"id":"b3d8aa58-840a-4f5a-a8df-fe2b6129ed06","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"93fc6d5d-4086-48a8-9a24-0e9ccd299d77","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"490f7da9-6081-4fc8-b80b-288e2c90d354","type":"ColumnDataSource"},"glyph":{"id":"8cac94ca-2aee-4795-a0d6-5be24c6fb5f1","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"9fe8a1ea-601e-408a-97a5-69760c62c9c5","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"d630e73b-cdc7-4793-a520-9d6a30fa6b88","subtype":"Chart","type":"Plot"},"ticker":{"id":"f52591dd-33aa-4282-bafc-d003621ebbd0","type":"BasicTicker"}},"id":"324ccfa3-2574-4c76-b84d-42d3c8e5313f","type":"Grid"},{"attributes":{"plot":{"id":"e48cecf9-e1c7-4c92-908b-98f494624225","subtype":"Chart","type":"Plot"}},"id":"f7177c90-bcc0-4068-8ba6-659ad6c11564","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"55314379-2fb7-4915-bd55-b6f565f85f26","subtype":"Chart","type":"Plot"},"ticker":{"id":"fa0b3788-345c-4192-a7ce-9e5a0f0dac38","type":"BasicTicker"}},"id":"fcd32bce-a72f-4af4-a8fd-614c1abc7682","type":"Grid"},{"attributes":{},"id":"45b02499-7634-4708-b3e7-c7ec9eb23141","type":"BasicTicker"},{"attributes":{"callback":null,"end":0.7605151067368511,"start":0.7596512457466338},"id":"ab9b7b5a-de88-4e4a-9c91-ac7b19a07f9b","type":"Range1d"},{"attributes":{},"id":"400a486e-b3ff-4689-b11f-72c109774a37","type":"ToolEvents"},{"attributes":{"plot":{"id":"e48cecf9-e1c7-4c92-908b-98f494624225","subtype":"Chart","type":"Plot"}},"id":"8ad51a57-3f26-41e5-ad57-010d867c4a2e","type":"PanTool"},{"attributes":{"axis_label":"hungarian","formatter":{"id":"0be2a3fa-6a8c-4b4f-b2b9-469effcd5c69","type":"BasicTickFormatter"},"plot":{"id":"e48cecf9-e1c7-4c92-908b-98f494624225","subtype":"Chart","type":"Plot"},"ticker":{"id":"65e4db0f-8e5e-49a0-b340-b04c5c0ab527","type":"BasicTicker"}},"id":"e44111c6-8ced-46c7-b00d-6cc002343525","type":"LinearAxis"},{"attributes":{"callback":null,"end":40.5,"start":22.5},"id":"d2a222a6-418c-4d18-95de-6375c2023b5b","type":"Range1d"},{"attributes":{"location":"top_left","plot":{"id":"d630e73b-cdc7-4793-a520-9d6a30fa6b88","subtype":"Chart","type":"Plot"}},"id":" ...

# %%
scat_lt_2 = Scatter(data_lt, x = 'lost', y='mota')
scat_lt_3 = Scatter(data_lt, x = 'lost', y='motp')
scat_lt_4 = Scatter(data_lt, x = 'lost', y='mostly_tracked')
scat_lt_5 = Scatter(data_lt, x = 'lost', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat_lt_2, scat_lt_3), row(scat_lt_4, scat_lt_5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b5ebbf77-c078-4a16-8405-c4f8a04eb500"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b5ebbf77-c078-4a16-8405-c4f8a04eb500");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b5ebbf77-c078-4a16-8405-c4f8a04eb500");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b5ebbf77-c078-4a16-8405-c4f8a04eb500' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3b6ccf20-191c-4ac0-bc4f-d46fd8445233":{"roots":{"references":[{"attributes":{"callback":null,"end":10.3,"start":6.7},"id":"a1a11b20-cdfc-4e71-a5ba-1191d66f3bb3","type":"Range1d"},{"attributes":{"below":[{"id":"e3528806-b37a-4b44-a9ba-28c18d97b9a3","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"1f59b940-2d78-4fe1-b8b0-e97967bc3d1e","type":"LinearAxis"}],"renderers":[{"id":"4b273399-2f4a-4032-871d-73bf3489a2b6","type":"BoxAnnotation"},{"id":"7627057d-8ea4-4285-9e48-3e67885a33dc","type":"GlyphRenderer"},{"id":"56b67729-f625-4b2e-9ac5-6db7b55d158a","type":"Legend"},{"id":"e3528806-b37a-4b44-a9ba-28c18d97b9a3","type":"LinearAxis"},{"id":"1f59b940-2d78-4fe1-b8b0-e97967bc3d1e","type":"LinearAxis"},{"id":"f4ac74be-dc70-482f-b805-757a04a5391b","type":"Grid"},{"id":"3ae77555-879f-42ce-9dcb-29a830b5a2b4","type":"Grid"}],"title":{"id":"c49f1c58-9fae-4c3d-82bc-c0583e0b5309","type":"Title"},"tool_events":{"id":"e5dd1668-4d20-4ec9-ac1b-7c1291970026","type":"ToolEvents"},"toolbar":{"id":"416fac12-a072-4a73-9fd6-72654964e7f7","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"a1a11b20-cdfc-4e71-a5ba-1191d66f3bb3","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"b470045b-9798-45fc-bb67-885cf16f0e4d","type":"Range1d"}},"id":"e7720355-1bbb-4ac8-a18a-a58c567b01d6","subtype":"Chart","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"e7720355-1bbb-4ac8-a18a-a58c567b01d6","subtype":"Chart","type":"Plot"},"ticker":{"id":"ddffbe36-815b-4e5d-ba81-cfc66db0cd3f","type":"BasicTicker"}},"id":"3ae77555-879f-42ce-9dcb-29a830b5a2b4","type":"Grid"},{"attributes":{"plot":{"id":"e7720355-1bbb-4ac8-a18a-a58c567b01d6","subtype":"Chart","type":"Plot"}},"id":"471d43f9-f459-43c9-ab47-82b1845d8203","type":"SaveTool"},{"attributes":{"overlay":{"id":"4b273399-2f4a-4032-871d-73bf3489a2b6","type":"BoxAnnotation"},"plot":{"id":"e7720355-1bbb-4ac8-a18a-a58c567b01d6","subtype":"Chart","type":"Plot"}},"id":"8e2e77cd-2ffb-4962-8e72-85d5b11dbaef","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"bcd0ae3e-073f-4f78-aef2-2bf8c2819f60","subtype":"Chart","type":"Plot"}},"id":"138f6123-b53a-4971-9a93-6cbe567ed694","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"e7720355-1bbb-4ac8-a18a-a58c567b01d6","subtype":"Chart","type":"Plot"}},"id":"a226ff8a-f250-4847-b6aa-a4b0d88fd138","type":"ResetTool"},{"attributes":{"below":[{"id":"2d493381-8d2a-489e-90f6-5516a43998c8","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"372f6a7c-4e7b-4202-9867-10489466718f","type":"LinearAxis"}],"renderers":[{"id":"0b050cf5-5d5d-476f-aed8-6aac5bacb560","type":"BoxAnnotation"},{"id":"e26b9ba1-ed4b-4fda-aadc-95d292e863d6","type":"GlyphRenderer"},{"id":"86264e10-2c4f-4616-b425-7b6082b7dd00","type":"Legend"},{"id":"2d493381-8d2a-489e-90f6-5516a43998c8","type":"LinearAxis"},{"id":"372f6a7c-4e7b-4202-9867-10489466718f","type":"LinearAxis"},{"id":"4965f583-7dd3-41c5-9d59-a210335563ef","type":"Grid"},{"id":"56552553-b1d7-4d5b-a088-0bc270396f94","type":"Grid"}],"title":{"id":"d07bd94f-845e-4979-a90d-7d59906194ab","type":"Title"},"tool_events":{"id":"548fb715-a660-4e45-8377-c01036818688","type":"ToolEvents"},"toolbar":{"id":"795177ba-2027-40f3-a252-6d7597455ae8","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"0aeb5359-dd01-4091-9433-d854e36c0ab5","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"6720bb0d-30f5-49e2-be45-2faa8e6816bc","type":"Range1d"}},"id":"bcd0ae3e-073f-4f78-aef2-2bf8c2819f60","subtype":"Chart","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7e0fe065-9f0e-4dba-ab4c-e3fd1f984b9f","type":"PanTool"},{"id":"df95bd64-be83-410f-ba71-7908f0444f3c","type":"WheelZoomTool"},{"id":"8e2e77cd-2ffb-4962-8e72-85d5b11dbaef","type":"BoxZoomTool"},{"id":"471d43f9-f459-43c9-ab47-82b1845d8203","type":"SaveTool"},{"id":"a226ff8a-f250-4847-b6aa-a4b0d88fd138","type":"ResetTool"},{"id":"5ff7521d-3622-4ed7-a11d-7236854993b1","type":"HelpTool"}]},"id":"416fac12-a072-4a73-9fd6 ...

# %%
data['mota'].groupby(data['ht']).describe()
# Out:
#     count      mean       std       min       25%       50%       75%  \
# ht
# 24   16.0  0.760242  0.072590  0.649805  0.729531  0.773788  0.800795
# 29   16.0  0.760443  0.073760  0.647935  0.730359  0.774818  0.801189
# 34   16.0  0.760291  0.074754  0.645221  0.731053  0.775536  0.801564
# 39   16.0  0.759723  0.075403  0.642336  0.730270  0.775530  0.801391
#
#          max
# ht
# 24  0.846190
# 29  0.847084
# 34  0.847026
# 39  0.846465

# %%
data['mota'].groupby(data['lt']).describe()
# Out:
#     count      mean       std       min       25%       50%       75%  \
# lt
# 7    16.0  0.758698  0.073416  0.645215  0.729047  0.772645  0.800920
# 8    16.0  0.760219  0.073736  0.646332  0.732316  0.774313  0.801637
# 9    16.0  0.760953  0.074266  0.644817  0.732776  0.775225  0.801954
# 10   16.0  0.760830  0.075086  0.642336  0.733597  0.775462  0.802133
#
#          max
# lt
# 7   0.843427
# 8   0.845205
# 9   0.846962
# 10  0.847084

# %%
data['mota'].groupby(data['game']).describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# game
# ChvUtd   16.0  0.787144  0.000322  0.786323  0.786986  0.787250  0.787333
# ER0429   16.0  0.647685  0.002619  0.642336  0.645893  0.647621  0.649908
# PP0214   16.0  0.845105  0.001683  0.841481  0.843631  0.845443  0.846259
# PS0304   16.0  0.760765  0.002508  0.755462  0.759303  0.761353  0.762899
#
#              max
# game
# ChvUtd  0.787616
# ER0429  0.651738
# PP0214  0.847084
# PS0304  0.764097

# %%
data_lt_ht = data.copy()
data_lt_ht['lost'] = data_lt_ht['lt']
data_lt_ht['hungarian'] = data_lt_ht['ht']
data_lt_ht = data_lt_ht.loc[:,['mota','ht', 'lt', 'lost', 'hungarian']].groupby(['ht','lt']).mean()
data_lt_ht
# Out:
#            mota  lost  hungarian
# ht lt
# 24 7   0.758268     7         24
#    8   0.760282     8         24
#    9   0.761110     9         24
#    10  0.761308    10         24
# 29 7   0.758701     7         29
#    8   0.760186     8         29
#    9   0.761704     9         29
#    10  0.761182    10         29
# 34 7   0.759270     7         34
#    8   0.760349     8         34
#    9   0.760680     9         34
#    10  0.760863    10         34
# 39 7   0.758552     7         39
#    8   0.760059     8         39
#    9   0.760316     9         39
#    10  0.759965    10         39

# %%
scat_ht_lt_1 = Scatter(data_lt_ht, x='hungarian', y='mota', color='lost')
show(scat_ht_lt_1)
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/bokeh/core/json_encoder.py:73: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   if pd and isinstance(obj, pd.tslib.Timestamp):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="da309998-3d79-45e2-94a2-72ee2cd413aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("da309998-3d79-45e2-94a2-72ee2cd413aa");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("da309998-3d79-45e2-94a2-72ee2cd413aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'da309998-3d79-45e2-94a2-72ee2cd413aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"41459901-edb3-4329-9e06-2830d472344b":{"roots":{"references":[{"attributes":{"overlay":{"id":"07d758e1-5a15-422c-b3a6-63b8a1d71394","type":"BoxAnnotation"},"plot":{"id":"169df849-e362-4477-920c-8a94d8101ab9","subtype":"Chart","type":"Plot"}},"id":"0c68e113-74c7-475c-a353-c9c9b7ef279d","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"005debfb-350c-4c0b-9be9-42535c46d477","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"23da6bd2-3562-4531-947b-3b1dfce43c54","type":"Circle"},{"attributes":{"below":[{"id":"583942c6-bc29-49f8-bdb2-842fbe002217","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"965df126-45bc-4d8d-ab73-63210dda2b7a","type":"LinearAxis"}],"renderers":[{"id":"07d758e1-5a15-422c-b3a6-63b8a1d71394","type":"BoxAnnotation"},{"id":"41691f93-651e-4812-83eb-e26ac59fdf8b","type":"GlyphRenderer"},{"id":"de5599ca-4997-49b1-b264-cdfd8a3b495c","type":"GlyphRenderer"},{"id":"e1a18f88-d7af-4657-b539-523a68f75570","type":"GlyphRenderer"},{"id":"968836e8-3f97-4059-9fa4-6f13d67fe13a","type":"GlyphRenderer"},{"id":"35e27ebe-7be0-4e81-b8f6-055d58047769","type":"Legend"},{"id":"583942c6-bc29-49f8-bdb2-842fbe002217","type":"LinearAxis"},{"id":"965df126-45bc-4d8d-ab73-63210dda2b7a","type":"LinearAxis"},{"id":"0e315535-9896-406f-9f63-60f33e33f827","type":"Grid"},{"id":"362fa2f4-d674-4e6c-b15e-b8ee46762420","type":"Grid"}],"title":{"id":"6475068b-0e8d-4f02-ab02-aa5366251719","type":"Title"},"tool_events":{"id":"309411b0-be9e-473d-8693-2b846c8f52fe","type":"ToolEvents"},"toolbar":{"id":"a2446b96-d9df-4982-8d3a-d9bb02727e0b","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"8122e50f-4d6a-4d6a-9710-b8ecda99980a","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"d73a492f-7d7c-47b1-91b1-6518301e1a09","type":"Range1d"}},"id":"169df849-e362-4477-920c-8a94d8101ab9","subtype":"Chart","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"07d758e1-5a15-422c-b3a6-63b8a1d71394","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"729a97fc-73e8-456b-93ea-9f63789f27de","type":"ColumnDataSource"},"glyph":{"id":"23da6bd2-3562-4531-947b-3b1dfce43c54","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"e1a18f88-d7af-4657-b539-523a68f75570","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1342819e-4447-4ff5-be3b-9a3b646941b0","type":"PanTool"},{"id":"a7ce535f-4047-419b-8608-ff4466f3e286","type":"WheelZoomTool"},{"id":"0c68e113-74c7-475c-a353-c9c9b7ef279d","type":"BoxZoomTool"},{"id":"08ea4978-fedb-4e04-a755-6af85d70bcfc","type":"SaveTool"},{"id":"e198fa4b-c6d8-4dc2-8d02-0fd23e01a771","type":"ResetTool"},{"id":"62d7f61c-f2d4-4bf9-8fe0-4ad8be3243f5","type":"HelpTool"}]},"id":"a2446b96-d9df-4982-8d3a-d9bb02727e0b","type":"Toolbar"},{"attributes":{"axis_label":"mota","formatter":{"id":"d3a8795d-f29b-4a7e-bc24-4bead36bc0b5","type":"BasicTickFormatter"},"plot":{"id":"169df849-e362-4477-920c-8a94d8101ab9","subtype":"Chart","type":"Plot"},"ticker":{"id":"d67b36c6-0ceb-41c5-b685-4ca26e07fd5b","type":"BasicTicker"}},"id":"965df126-45bc-4d8d-ab73-63210dda2b7a","type":"LinearAxis"},{"attributes":{"label":{"value":"8"},"renderers":[{"id":"de5599ca-4997-49b1-b264-cdfd8a3b495c","type":"GlyphRenderer"}]},"id":"ddde9853-3f8a-4f4e-978a-2a800b1bdf74","type":"LegendItem"},{"attributes":{"label":{"value":"9"},"renderers":[{"id":" ...

# %%
scat_ht_6 = Scatter(data_ht, x = 'hungarian', y='mota');scat_ht_6.y_range.start,scat_ht_6.y_range.end = (0,1)
scat_ht_7 = Scatter(data_ht, x = 'hungarian', y='motp');scat_ht_7.y_range.start,scat_ht_7.y_range.end = (0,1)
scat_ht_8 = Scatter(data_ht, x = 'hungarian', y='mostly_tracked');scat_ht_8.y_range.start,scat_ht_8.y_range.end = (0,1)
scat_ht_9 = Scatter(data_ht, x = 'hungarian', y='mt_auc');scat_ht_9.y_range.start,scat_ht_9.y_range.end = (0,1)
show(column(row(scat_ht_6, scat_ht_7), row(scat_ht_8, scat_ht_9)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aca99ad6-a15f-4cee-9207-f2d4f12ab165"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("aca99ad6-a15f-4cee-9207-f2d4f12ab165");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aca99ad6-a15f-4cee-9207-f2d4f12ab165");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aca99ad6-a15f-4cee-9207-f2d4f12ab165' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a8529bd4-6b0f-4396-a022-d87f4f8d521b":{"roots":{"references":[{"attributes":{},"id":"1cf14007-d4cd-4483-9c1e-99af3b6c7a9c","type":"BasicTickFormatter"},{"attributes":{},"id":"abe37140-676a-4806-9ac6-e53151f2d9bb","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"ce82d474-7e54-48e5-b510-4e3ed7a6a01a","subtype":"Chart","type":"Plot"},"ticker":{"id":"8286100c-f5a9-4db2-ae0e-101975abcc3f","type":"BasicTicker"}},"id":"bff73914-8170-49e8-abdf-25384d214bc8","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":{"__ndarray__":"AAAAAAAAJEAAAAAAAAA0QAAAAAAAAD5AAAAAAAAAREAAAAAAAABJQAAAAAAAAE5AAAAAAACAUUAAAAAAAABUQAAAAAAAgFZAAAAAAAAAWUAAAAAAAEBfQAAAAAAAwGJAAAAAAADgZUAAAAAAAABpQAAAAAAAQG9AAAAAAADgdUAAAAAAAEB/QA==","dtype":"float64","shape":[17]},"y_values":{"__ndarray__":"58oVVagY6D+fh462+MDpP+jEJAf1Euo/bX1vH1I/6j/r0ZhoVGXqP8mYr9q1heo/1PIgHZyh6j8hQV/CI7rqPzXwgF21z+o/dpjt6Mni6j8xrpf6JQ3rP4RmSD0FLus/tcfQOY9J6z9gQaCb8V7rP54OQG7gfus/HgF3L9+l6z8CTUSE98LrPw==","dtype":"float64","shape":[17]}}},"id":"9433e5c0-2793-45f0-a7a5-05d1cb4bad4e","type":"ColumnDataSource"},{"attributes":{},"id":"4dafb5a6-dd02-412e-ae53-3c04660aaf6e","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cccebea9-8fb1-473d-b67b-d4bd5fa47501","type":"PanTool"},{"id":"6be6ddd1-4602-437b-a942-27b26ef4d949","type":"WheelZoomTool"},{"id":"955d74dc-73d8-4275-a231-c87fb580e264","type":"BoxZoomTool"},{"id":"5320a350-1fa5-4887-ae74-92090079d65a","type":"SaveTool"},{"id":"dbe4b573-f60f-4693-9ca1-6aeb8ff2164c","type":"ResetTool"},{"id":"299b4575-e502-4a67-a83d-ba7a93e21d05","type":"HelpTool"}]},"id":"a9536199-05d9-4516-9f4e-0b770524b068","type":"Toolbar"},{"attributes":{},"id":"4e158e93-3101-4239-9b19-3e96b568f0ae","type":"BasicTicker"},{"attributes":{},"id":"216cc8cc-1d9c-4b61-b780-a93d9035102e","type":"ToolEvents"},{"attributes":{"location":"top_left","plot":{"id":"454063e2-256e-48fb-9d7e-088c41d7262c","subtype":"Chart","type":"Plot"}},"id":"7e369383-aa2f-4d2d-aaf3-b6ba0285ce99","type":"Legend"},{"attributes":{"plot":{"id":"b56f98a3-0847-4de2-937f-cfa0e8df4bd2","subtype":"Chart","type":"Plot"}},"id":"6be6ddd1-4602-437b-a942-27b26ef4d949","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dc41ac07-8f5d-4845-9db6-5f877957a40e","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"c92b8b3f-768f-4a7a-a55d-102f3e57f757","type":"BoxAnnotation"},"plot":{"id":"454063e2-256e-48fb-9d7e-088c41d7262c","subtype":"Chart","type":"Plot"}},"id":"7d6ca30e-c125-4421-a0fd-0186dd699cdb","type":"BoxZoomTool"},{"attributes":{},"id":"f82cb6f4-7ca6-45d7-af44-c57ad398739d","type":"ToolEvents"},{"attributes":{"plot":{"id":"b56f98a3-0847-4de2-937f-cfa0e8df4bd2","subtype":"Chart","type":"Plot"}},"id":"cccebea9-8fb1-473d-b67b-d4bd5fa47501","type":"PanTool"},{"attributes":{},"id":"1dfa4adb-6724-4465-9271-9b6aea98762a","type":"ToolEvents"},{"attributes":{},"id":"c30ffa39-9575-4423-afbc-34f0a698ad29","type":"ToolEvents"},{"attributes":{"axis_label":"hungarian","formatter":{"id":"c8dfdd26-a2a2-476d-b489-65868eb17d81","type":"BasicTickFormatter"},"plot":{"id":"ce82d474-7e54-48e5-b510-4e3ed7a6a01a","subtype":"Chart","type":"Plot"},"ticker":{"id":"4dafb5a6-dd02-412e-ae53-3c04660aaf6e","type":"BasicTicker"}},"id":"0b2c59c7-de84-4a29-b35a-fd54d96246fb","type":"LinearAxis"},{"attributes":{"plot":{"id":"48bedabf-abd7-47dd-95ff-1919575d52ab","subtype":"Chart","type":"Plot"}},"id":"8a3e6ecb-cc7d-4b41-a70f-5c4ff86bf894","type":"ResetTool"},{"attributes":{"data_source":{" ...

# %%
scat_lt_6 = Scatter(data_lt, x = 'lost', y='mota');scat_lt_6.y_range.start,scat_lt_6.y_range.end = (0,1)
scat_lt_7 = Scatter(data_lt, x = 'lost', y='motp');scat_lt_7.y_range.start,scat_lt_7.y_range.end = (0,1)
scat_lt_8 = Scatter(data_lt, x = 'lost', y='mostly_tracked');scat_lt_8.y_range.start,scat_lt_8.y_range.end = (0,1)
scat_lt_9 = Scatter(data_lt, x = 'lost', y='mt_auc');scat_lt_9.y_range.start,scat_lt_9.y_range.end = (0,1)
show(column(row(scat_lt_6, scat_lt_7), row(scat_lt_8, scat_lt_9)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="09f8c595-e1dd-4958-9e0f-406a174fcd55"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("09f8c595-e1dd-4958-9e0f-406a174fcd55");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("09f8c595-e1dd-4958-9e0f-406a174fcd55");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '09f8c595-e1dd-4958-9e0f-406a174fcd55' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b4b27a68-b971-4d8d-8836-a3e1c6723d35":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ab0d30f0-20a9-4eb9-a0bb-4a4aee6e55bc","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"}},"id":"8dbec301-e747-4941-9b14-9ea314715dc4","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"}},"id":"f1f4428e-23a8-4435-b419-1bdaef647b16","type":"HelpTool"},{"attributes":{"location":"top_left","plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"}},"id":"e21a6811-4d58-423b-846e-35605ea41c56","type":"Legend"},{"attributes":{},"id":"1626c20e-e80b-47d4-a71d-0eaee2a54495","type":"BasicTicker"},{"attributes":{"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"}},"id":"c266efe3-f523-416d-a091-78db36dc7908","type":"PanTool"},{"attributes":{"axis_label":"lost","formatter":{"id":"0de9ead1-c319-4741-b6cb-c5c1fb55d98c","type":"BasicTickFormatter"},"plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"},"ticker":{"id":"f15db48f-e5e3-4d92-987b-8c1a1d3ac054","type":"BasicTicker"}},"id":"dfecfd0f-10db-4fbb-acf6-f196180f1a46","type":"LinearAxis"},{"attributes":{},"id":"0de9ead1-c319-4741-b6cb-c5c1fb55d98c","type":"BasicTickFormatter"},{"attributes":{},"id":"f15db48f-e5e3-4d92-987b-8c1a1d3ac054","type":"BasicTicker"},{"attributes":{"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"}},"id":"70c1b89b-e7cc-42cc-8b45-92e6f58592b1","type":"HelpTool"},{"attributes":{"data_source":{"id":"78285ca3-c5c0-4094-b593-f116fd2d3cb8","type":"ColumnDataSource"},"glyph":{"id":"37396e15-6092-4c14-af82-1d0e587db3d2","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"cca08c7e-ed40-4698-a24b-7be031e7dd8a","type":"GlyphRenderer"},{"attributes":{},"id":"77b8ea0c-8728-4d30-9c2d-2706d0085364","type":"BasicTicker"},{"attributes":{"axis_label":"mt_auc","formatter":{"id":"06da90f1-e884-4a09-8888-cf8561ad6023","type":"BasicTickFormatter"},"plot":{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"},"ticker":{"id":"77b8ea0c-8728-4d30-9c2d-2706d0085364","type":"BasicTicker"}},"id":"07cd424d-4b3d-43ec-8f23-2a7e71563e0b","type":"LinearAxis"},{"attributes":{"axis_label":"lost","formatter":{"id":"bc4e95cc-571e-40a1-8aa9-6c6151b3e95e","type":"BasicTickFormatter"},"plot":{"id":"ecf19637-5741-4635-9c04-c5f1d476710a","subtype":"Chart","type":"Plot"},"ticker":{"id":"1626c20e-e80b-47d4-a71d-0eaee2a54495","type":"BasicTicker"}},"id":"d024be3e-413f-4ab6-8d48-88d24e0364ad","type":"LinearAxis"},{"attributes":{"children":[{"id":"11482419-79ce-4bef-9e77-da96c0f0e4ef","type":"Row"},{"id":"c5c9bc5b-c3d0-471f-b115-81408d06eb2d","type":"Row"}]},"id":"6295a5e5-4764-44c9-8fa5-92662feba106","type":"Column"},{"attributes":{"children":[{"id":"eb81cae9-1073-46e8-baf2-02256f6ac130","subtype":"Chart","type":"Plot"},{"id":"f1bf9304-7561-4d06-b2ce-dacf524ff028","subtype":"Chart","type":"Plot"}]},"id":"c5c9bc5b-c3d0-471f-b115-81408d06eb2d","type":"Row"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null],"x_values":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAABhAAAAAAAAAHEAAAAAAAAAgQA==","dtype":"float64","shape":[8]},"y_values":{"__ndarray__":"8OTY/4QD6T83Bx/iHMbpP1gs7g1cWOo/ae5QQWDB6j/JkMCxiRXrPx/qijjLWes/nH5gaiSQ6z+ZZEidjLvrPw==","dtype":"float64","shape":[8]}}},"id":"e4486230-5169-4848-9e68-5f230b73b7b7","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"f1bf9304-7561-4d0 ...

# %%
scat_ht_10 = Scatter(data, x='ht', y='mota', color='game');scat_ht_10.y_range.start,scat_ht_10.y_range.end = (0,1)
show(scat_ht_10)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="75112888-b9e2-4817-a815-035e133e1aa9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("75112888-b9e2-4817-a815-035e133e1aa9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75112888-b9e2-4817-a815-035e133e1aa9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '75112888-b9e2-4817-a815-035e133e1aa9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a49b8214-1c8f-4f2a-96ad-741f060efb95":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"},{"game":"PP0214"}],"game":["PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214","PP0214"],"x_values":[500,500,500,350,350,500,350,250,250,500,250,200,350,200,175,250,175,350,250,200,500,200,350,150,175,175,125,70,150,125,17 ...

# %%
scat_lt_10 = Scatter(data, x='lt', y='mota', color='game');scat_lt_10.y_range.start,scat_lt_10.y_range.end = (0,1)
show(scat_lt_10)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e16fdd17-23fc-4d9c-95f5-5925253d2bbc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e16fdd17-23fc-4d9c-95f5-5925253d2bbc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e16fdd17-23fc-4d9c-95f5-5925253d2bbc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e16fdd17-23fc-4d9c-95f5-5925253d2bbc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f19e4c2f-dbad-476e-b4c2-1f7b16530a21":{"roots":{"references":[{"attributes":{"label":{"value":"PP0214"},"renderers":[{"id":"4b92634f-087c-4451-ac0e-bdcfbc25ac73","type":"GlyphRenderer"}]},"id":"fe4a5c1c-917b-40a7-8907-9bf60eb51efd","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c990ca31-bbb3-40af-aef0-d85227e9a1ff","type":"Circle"},{"attributes":{"data_source":{"id":"6fd4c1c0-056a-4175-bb1d-2b92311e6364","type":"ColumnDataSource"},"glyph":{"id":"49031655-7c44-4028-878a-3cb5e65ce607","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"3bb9a10b-aa80-4f7f-b175-8681083ae631","type":"GlyphRenderer"},{"attributes":{},"id":"6ee6f2f3-0f59-4ce7-809d-21edf3b36b4e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":8.7,"start":0.29999999999999993},"id":"1bec8485-71ac-492f-abf7-85eaab359b19","type":"Range1d"},{"attributes":{"axis_label":"lt","formatter":{"id":"5aca91ba-03d0-48a5-b073-d4e5f2a53ba1","type":"BasicTickFormatter"},"plot":{"id":"9d97ea9e-8100-4c6d-9e03-89eb0932a855","subtype":"Chart","type":"Plot"},"ticker":{"id":"bb768bc6-2ccf-4cd4-b480-f3a2069cfa2d","type":"BasicTicker"}},"id":"92b2b022-c38e-4f18-896d-037d6c57459a","type":"LinearAxis"},{"attributes":{"plot":{"id":"9d97ea9e-8100-4c6d-9e03-89eb0932a855","subtype":"Chart","type":"Plot"}},"id":"fb466228-b28c-4885-a8e1-17936b6079a6","type":"SaveTool"},{"attributes":{"label":{"value":"ChvUtd"},"renderers":[{"id":"58350d29-64b6-4dc8-b6c9-53c75c086ea5","type":"GlyphRenderer"}]},"id":"6bb64ada-1abf-4e07-afd9-bb9293c3b0f9","type":"LegendItem"},{"attributes":{},"id":"c2ef1b0a-ce66-47f3-9dd4-d6e183b6f54a","type":"ToolEvents"},{"attributes":{"below":[{"id":"92b2b022-c38e-4f18-896d-037d6c57459a","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"af549a0f-480d-4825-ba47-9e74369c551a","type":"LinearAxis"}],"renderers":[{"id":"a2cbce62-63eb-4eef-acba-bd5ed18d3a81","type":"BoxAnnotation"},{"id":"4b92634f-087c-4451-ac0e-bdcfbc25ac73","type":"GlyphRenderer"},{"id":"58350d29-64b6-4dc8-b6c9-53c75c086ea5","type":"GlyphRenderer"},{"id":"87e71c7b-c60c-4ea8-b55a-138cecc3698f","type":"GlyphRenderer"},{"id":"3bb9a10b-aa80-4f7f-b175-8681083ae631","type":"GlyphRenderer"},{"id":"1a48a948-ede5-4fee-9f24-c24aba46c301","type":"Legend"},{"id":"92b2b022-c38e-4f18-896d-037d6c57459a","type":"LinearAxis"},{"id":"af549a0f-480d-4825-ba47-9e74369c551a","type":"LinearAxis"},{"id":"e8f9a358-bae0-4eac-a266-327ed326b70a","type":"Grid"},{"id":"1293b0c1-abaf-433e-9b79-57d5087276bc","type":"Grid"}],"title":{"id":"68a28bc6-84d7-44e1-a3b0-2ec5967a6c0f","type":"Title"},"tool_events":{"id":"c2ef1b0a-ce66-47f3-9dd4-d6e183b6f54a","type":"ToolEvents"},"toolbar":{"id":"14a9598e-fccd-4cc4-92dd-62ef794997dd","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"1bec8485-71ac-492f-abf7-85eaab359b19","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"1ccdda8d-a070-41d6-a437-117a1c584613","type":"Range1d"}},"id":"9d97ea9e-8100-4c6d-9e03-89eb0932a855","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429 ...

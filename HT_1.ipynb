# %%
import holmes.experiment as Ex
import tempfile
import pprint
import json
import os
from terrarium.flatten import flatten_dict, expand_dict
import tempfile

# %%
temp_dir_obj = tempfile.TemporaryDirectory()
temp_dir = temp_dir_obj.name
package_location = Ex.staging.prep_holmes_package(
    staging_path=temp_dir, 
    commit_hash='ca6ccd63f270d603ffa9bdf5a7ced184d6339796'
)

detects_dict={}
for video_data in Ex.val_data:
    detects_dict[video_data['video_id']] = video_data['video_path'].replace('processed','detections')

def_conf_path = Ex.staging.extract_default_config(package_location, temp_dir)

with open(def_conf_path, 'r') as fp:
    def_conf_dict = json.load(fp)

new_def_conf_dicts={}
list_dicts=[]
for video_data in Ex.val_data:
    new_def_conf_dict = def_conf_dict.copy()
    detects_path = video_data['video_path'].replace('processed','detections').replace('.mp4', '.json')
    new_def_conf_dict['detector_config'] = {"source_path": detects_path,"_class_name": "PassThroughDetectorConfig","batch_size": 1}
    new_def_conf_dict['video_config'] = video_data
    new_def_conf_dict['video_config']['_class_name'] = 'RawVideoConfig'
    list_dicts.append(new_def_conf_dict)

# %%
measurement_ids = ['M01-PS0304-001', 'M02-PP0214-000', 'M00-ChvUtd-000', 'M03-ER0429-001']
hungarian_threshold = [10,28,46,64,82,100]

# %%
list_configs=[]
for ht in hungarian_thresholds:
    for config in list_dicts:
        current_config_dict = config.copy()
        parameter_map = {"tracker_config.associator_config._class_name": 'SpatialAssociatorConfig', "tracker_config.associator_config.threshold": ht}
        flat_dict = flatten_dict(current_config_dict)
        flat_dict.update(parameter_map)
        updated_config_dict = expand_dict(flat_dict)

        file_name = os.path.join(temp_dir, "M{:02d}-{}-{:02d}.json".format(len(list_configs), 
                                            current_config_dict['video_config']['video_id'], ht))
        list_configs.append(file_name)
        with open(file_name, 'w') as f:
            json.dump(updated_config_dict, f, indent=2)
print(len(list_configs), list_configs[0])

# %%
experiment = Ex.AWSExperiment(
    experiment_id="PTA-95-HT-1-1", job_queue=Ex.AWSComputeQueue.cpu_queue
)

for i, config_path in enumerate(list_configs):
    meas_id = os.path.basename(config_path).replace(".json", "")
    experiment.add_measurement(
        Ex.AWSMeasurement(
            experiment_id = "PTA-95-HT-1-1",
            measurement_id = meas_id,
            job_queue = Ex.AWSComputeQueue.cpu_queue,
            package_path = package_location,
            config_path = config_path
        )
    )

# %%
import boto3
experiment._batch_client = boto3.client('batch', region_name='us-east-1')

# %%
experiment.stage_experiment()

# %%
experiment.launch_experiment()

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/hung3.csv')

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="545212bf-789e-42ed-8bb0-04dca0f85e5c">Loading BokehJS ...</span>
#     </div>

# %%
data['ht'] = 1
for index, row in data.iterrows():
    data['ht'][index] = row['job_id'][-3:]
data['ht'][data['ht']<0]=data['ht'][data['ht']<0]*-1

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][20:26]

# %%
scat1 = Scatter(data, x='ht', y='mota', color='game')
show(scat1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="229a3f1c-fb4a-4ae5-8296-35ff801fe863"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("229a3f1c-fb4a-4ae5-8296-35ff801fe863");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("229a3f1c-fb4a-4ae5-8296-35ff801fe863");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '229a3f1c-fb4a-4ae5-8296-35ff801fe863' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e22a35a2-6fa1-40f7-a57d-9116bc7d655f":{"roots":{"references":[{"attributes":{"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"}},"id":"07da870c-07f1-4350-a120-9f49e01f524a","type":"HelpTool"},{"attributes":{"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"}},"id":"75621d01-4648-43b9-937c-2e37a1e07565","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"}},"id":"4fc407d2-df16-406c-b2d0-fb93381cfee9","type":"ResetTool"},{"attributes":{"label":{"value":"0304-0"},"renderers":[{"id":"a63091dd-86c8-4c6a-9fea-9765c3ed3f77","type":"GlyphRenderer"}]},"id":"37998a71-1202-4294-bf2e-021da0dce91e","type":"LegendItem"},{"attributes":{"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"},"ticker":{"id":"46d51882-77a6-4f87-bb63-1d533e692b38","type":"BasicTicker"}},"id":"9bb0a50b-c224-4f35-b743-2d2d1a834526","type":"Grid"},{"attributes":{},"id":"46d51882-77a6-4f87-bb63-1d533e692b38","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"de49c928-fc7a-4a20-867d-42172a8bb6c2","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"01a95e9d-0c8a-4d5d-bced-16357c5bd765","type":"Circle"},{"attributes":{},"id":"0771ad36-1242-41fd-851f-8041703fe228","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"3ca10c03-e54c-436c-ad33-62ee66752ea1","type":"Circle"},{"attributes":{"data_source":{"id":"38cc396f-51db-4bd4-b25a-ed14beacbdad","type":"ColumnDataSource"},"glyph":{"id":"3ca10c03-e54c-436c-ad33-62ee66752ea1","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"2864fd0d-9d69-4ef2-a0df-8dc5311c8404","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e982200a-8659-4125-a330-8600015c5b08","type":"ColumnDataSource"},"glyph":{"id":"01a95e9d-0c8a-4d5d-bced-16357c5bd765","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"0a9b470a-d333-4367-942d-ade4810dbefb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"}},"id":"567f03e3-e955-463f-97c6-aa186757ab58","type":"SaveTool"},{"attributes":{"axis_label":"ht","formatter":{"id":"36b5d4d8-ed4a-42d8-ad83-9fa49486ad0c","type":"BasicTickFormatter"},"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"},"ticker":{"id":"46d51882-77a6-4f87-bb63-1d533e692b38","type":"BasicTicker"}},"id":"61d815f5-56fd-4554-ac22-b5ba8ab07767","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"},"ticker":{"id":"cbb1d81b-5a34-44ac-a211-08b4b7f9aa85","type":"BasicTicker"}},"id":"5c76d45a-e6ba-4643-8bfe-13d24bb6b1ed","type":"Grid"},{"attributes":{"plot":{"id":"e1631c09-cb89-431f-8085-67f1a65d80b3","subtype":"Chart","type":"Plot"}},"id":"e2433a34-dc71-4263-b950-29e259203053","type":"PanTool"},{"attributes":{},"id":"cbb1d81b-5a34-44ac-a211-08b4b7f9aa85","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"0429-0"},{"game":"0429-0"},{"game":"0429-0"},{"game":"0429-0"},{"game":"0429-0"},{"game":"0429-0"}],"game":["0429-0","0429-0","0429-0","0429-0","0429-0","0429-0"],"x_values":[10,28,46,100,82,64],"y_values":{"__ndarray__":"fuDEH3ch4T/VdBfvW6XhPzEfRBYa0eE/Y ...

# %%
data_ht = data.copy()
data_ht['hungarian_threshold'] = data_ht['ht']
data_ht = data_ht.groupby(['ht']).mean()
data_ht
# Out:
#          mota      motp      motr  mostly_tracked    mt_auc  \
# ht
# 10   0.672471  0.649297  0.733826        0.432157  0.727345
# 28   0.710704  0.642245  0.782900        0.550912  0.776123
# 46   0.714994  0.641175  0.789975        0.565035  0.782787
# 64   0.718542  0.640535  0.795641        0.585925  0.788023
# 82   0.720653  0.640163  0.799665        0.597462  0.791817
# 100  0.722046  0.639926  0.802513        0.607699  0.794376
#
#      hungarian_threshold
# ht
# 10                    10
# 28                    28
# 46                    46
# 64                    64
# 82                    82
# 100                  100

# %%
scat2 = Scatter(data_ht, x = 'hungarian_threshold', y='mota')
scat3 = Scatter(data_ht, x = 'hungarian_threshold', y='motp')
scat4 = Scatter(data_ht, x = 'hungarian_threshold', y='mostly_tracked')
scat5 = Scatter(data_ht, x = 'hungarian_threshold', y='mt_auc')
from bokeh.layouts import column, row
show(column(row(scat2, scat3), row(scat4, scat5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="73e0fc30-a289-421f-843e-0a392f36378f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("73e0fc30-a289-421f-843e-0a392f36378f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("73e0fc30-a289-421f-843e-0a392f36378f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '73e0fc30-a289-421f-843e-0a392f36378f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ed413a7a-5b79-4c0f-bad5-f528f1c46a94":{"roots":{"references":[{"attributes":{},"id":"3d0d4832-6b4e-47ca-b033-7cb055572cf9","type":"ToolEvents"},{"attributes":{},"id":"929548e9-97ca-4771-9128-fea3d5138945","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":null},"id":"29770c09-fd5d-414f-827b-09458537d8ad","type":"Title"},{"attributes":{},"id":"400b8237-3331-4628-aa01-69700245d4b2","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":null},"id":"c56a8bc1-2509-446e-9739-8c5a3e1cf9d7","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"152cfcc8-9261-454f-bc60-3cf40de99795","type":"PanTool"},{"id":"1dc5577e-dd19-41c9-8a97-1d0fc54d51aa","type":"WheelZoomTool"},{"id":"ea7771dd-af7f-4629-a82d-5e50c148d51d","type":"BoxZoomTool"},{"id":"7fbd6446-ea62-4b4d-83bc-d04a2afc52c9","type":"SaveTool"},{"id":"8468bf42-6751-40a4-bd5a-1457dfb91b6f","type":"ResetTool"},{"id":"e84acb89-8db0-4915-9c3a-10291598e8e2","type":"HelpTool"}]},"id":"04be12de-a8d0-44fc-86dd-1f2536bee415","type":"Toolbar"},{"attributes":{"children":[{"id":"7c6a77bc-366f-42a1-88a2-b9f1aee7c18f","subtype":"Chart","type":"Plot"},{"id":"c61c7e6e-cc92-4fa8-9f28-2ed0ff694295","subtype":"Chart","type":"Plot"}]},"id":"1af007b2-3ce7-41ef-8062-96a38860a217","type":"Row"},{"attributes":{},"id":"ac8941ce-8cdf-412a-a977-bbd22acc6e10","type":"ToolEvents"},{"attributes":{"callback":null,"end":0.727003947722363,"start":0.6675131869230809},"id":"67e74b07-1552-4f2a-8dcf-5c45caa48dba","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2543e2b7-eeba-4276-add2-205897892b8c","type":"BoxAnnotation"},{"attributes":{},"id":"a7fa9187-0708-4a47-8249-e9bbfda7a3a0","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c2dc17b9-0964-414b-93b7-c91505e4fca1","subtype":"Chart","type":"Plot"}},"id":"152cfcc8-9261-454f-bc60-3cf40de99795","type":"PanTool"},{"attributes":{"children":[{"id":"c2dc17b9-0964-414b-93b7-c91505e4fca1","subtype":"Chart","type":"Plot"},{"id":"187178a8-c030-4a3d-abcb-c62c509f8317","subtype":"Chart","type":"Plot"}]},"id":"b246c336-7f7a-4b49-8d0c-64449458fec4","type":"Row"},{"attributes":{},"id":"24c4e6c4-c6a9-4c63-a4b0-5cc1a566e468","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c2dc17b9-0964-414b-93b7-c91505e4fca1","subtype":"Chart","type":"Plot"}},"id":"1dc5577e-dd19-41c9-8a97-1d0fc54d51aa","type":"WheelZoomTool"},{"attributes":{},"id":"6cbb6b89-3974-4c9e-8714-ceec5ada98e4","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"2543e2b7-eeba-4276-add2-205897892b8c","type":"BoxAnnotation"},"plot":{"id":"c2dc17b9-0964-414b-93b7-c91505e4fca1","subtype":"Chart","type":"Plot"}},"id":"ea7771dd-af7f-4629-a82d-5e50c148d51d","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"c2dc17b9-0964-414b-93b7-c91505e4fca1","subtype":"Chart","type":"Plot"}},"id":"7fbd6446-ea62-4b4d-83bc-d04a2afc52c9","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null],"x_values":[10,28,46,64,82,100],"y_values":{"__ndarray__":"4Hnx5XWo2z8BzxViEaHhP5aJNrDDFOI/6gMDE+W/4j9ONjflaB7jP2Nw0QdFcuM/","dtype":"float64","shape":[6]}}},"id":"58074984-3801-4f62-9b50-07a053b3fe0b","type":"ColumnDataSource"},{"attributes":{},"id":"c792050f-1378-49e9-8763-bcc37ce2978b","type":"BasicTickFormatter"},{"attributes":{"axis_label":"mota","formatter":{"id":"929548e9-97ca-4771-9128-fea3d5138945","type":"BasicTickFormatter"},"plot":{"id":"7c6a77bc-366f-42a1-88a2-b9f1aee7c18f","subtype":"Chart","type":"Plot"},"ticker":{"id":"f8ce20e9-e878-47e8-b901-b091718f5725","type":"BasicTicker"}},"id":"3f8951be-8da3-43d4-a14d-516e11b7ae41","type":"LinearAxis"} ...

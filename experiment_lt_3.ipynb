# %%
import pandas as pd
import numpy as np
import bokeh
import bokeh.io
import bokeh.charts
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a2474ff8-3b2f-493e-b274-703f2b8c9646">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv('/Users/jason.katz/Downloads/search_results3.csv')

# %%
data['lt'] = 1
for index, row in data.iterrows():
    data['lt'][index] = row['job_id'][-2:]
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['game'] = 'id'
for index, row in data.iterrows():
    data['game'][index] = row['job_id'][16:22]
# Out:
# /Users/jason.katz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data
# Out:
#                            job_id      mota      motp      motr  \
# 0   PTA-89-LT-3-M10-PP0214-000-03  0.854059  0.737125  0.923697
# 1   PTA-89-LT-3-M06-PP0214-000-02  0.853803  0.738694  0.912826
# 2   PTA-89-LT-3-M14-PP0214-000-04  0.851985  0.736281  0.930011
# 3   PTA-89-LT-3-M18-PP0214-000-05  0.850651  0.735508  0.935204
# 4   PTA-89-LT-3-M02-PP0214-000-01  0.849321  0.740777  0.895742
# 5   PTA-89-LT-3-M22-PP0214-000-06  0.848217  0.734876  0.939124
# 6   PTA-89-LT-3-M26-PP0214-000-07  0.845709  0.734334  0.941508
# 7   PTA-89-LT-3-M30-PP0214-000-08  0.843445  0.733847  0.943616
# 8   PTA-89-LT-3-M34-PP0214-000-09  0.841031  0.733521  0.945212
# 9   PTA-89-LT-3-M38-PP0214-000-10  0.838492  0.733050  0.946370
# 10  PTA-89-LT-3-M08-ChvUtd-000-03  0.788571  0.497311  0.883557
# 11  PTA-89-LT-3-M04-ChvUtd-000-02  0.787769  0.497707  0.876707
# 12  PTA-89-LT-3-M12-ChvUtd-000-04  0.787178  0.497065  0.886685
# 13  PTA-89-LT-3-M16-ChvUtd-000-05  0.786032  0.496805  0.889604
# 14  PTA-89-LT-3-M00-ChvUtd-000-01  0.785258  0.498395  0.867273
# 15  PTA-89-LT-3-M20-ChvUtd-000-06  0.784831  0.496699  0.892029
# 16  PTA-89-LT-3-M24-ChvUtd-000-07  0.783800  0.496611  0.894179
# 17  PTA-89-LT-3-M28-ChvUtd-000-08  0.782841  0.496368  0.895695
# 18  PTA-89-LT-3-M32-ChvUtd-000-09  0.781784  0.496402  0.896816
# 19  PTA-89-LT-3-M36-ChvUtd-000-10  0.780247  0.496333  0.897924
# 20  PTA-89-LT-3-M05-PS0304-001-02  0.764009  0.693461  0.889793
# 21  PTA-89-LT-3-M09-PS0304-001-03  0.763130  0.692329  0.902405
# 22  PTA-89-LT-3-M01-PS0304-001-01  0.759433  0.695574  0.867553
# 23  PTA-89-LT-3-M13-PS0304-001-04  0.759156  0.691453  0.909974
# 24  PTA-89-LT-3-M17-PS0304-001-05  0.758623  0.690994  0.915346
# 25  PTA-89-LT-3-M21-PS0304-001-06  0.754985  0.690518  0.919377
# 26  PTA-89-LT-3-M25-PS0304-001-07  0.751403  0.690301  0.922852
# 27  PTA-89-LT-3-M29-PS0304-001-08  0.747656  0.690000  0.925486
# 28  PTA-89-LT-3-M33-PS0304-001-09  0.744863  0.689700  0.927601
# 29  PTA-89-LT-3-M37-PS0304-001-10  0.742471  0.689346  0.929768
# 30  PTA-89-LT-3-M39-ER0429-001-10  0.591173  0.618417  0.769612
# 31  PTA-89-LT-3-M35-ER0429-001-09  0.589066  0.619390  0.762397
# 32  PTA-89-LT-3-M27-ER0429-001-07  0.586927  0.621087  0.746830
# 33  PTA-89-LT-3-M31-ER0429-001-08  0.585946  0.620286  0.752360
# 34  PTA-89-LT-3-M23-ER0429-001-06  0.585491  0.621694  0.740099
# 35  PTA-89-LT-3-M19-ER0429-001-05  0.583276  0.622794  0.727793
# 36  PTA-89-LT-3-M15-ER0429-001-04  0.578131  0.623255  0.714088
# 37  PTA-89-LT-3-M11-ER0429-001-03  0.570993  0.624674  0.695469
# 38  PTA-89-LT-3-M07-ER0429-001-02  0.560530  0.625679  0.674508
# 39  PTA-89-LT-3-M03-ER0429-001-01  0.546161  0.627268  0.645050
#
#     mostly_tracked    mt_auc  lt    game
# 0         0.877895  0.915283   3  PP0214
# 1         0.861754  0.904864   2  PP0214
# 2         0.887018  0.921391   4  PP0214
# 3         0.895439  0.926514   5  PP0214
# 4         0.830877  0.888448   1  PP0214
# 5         0.901053  0.930367   6  PP0214
# 6         0.903860  0.932743   7  PP0214
# 7         0.909474  0.934856   8  PP0214
# 8         0.913684  0.936539   9  PP0214
# 9         0.914386  0.937708  10  PP0214
# 10        0.830279  0.876409   3  ChvUtd
# 11        0.816733  0.869886   2  ChvUtd
# 12        0.834263  0.879371   4  ChvUtd
# 13        0.843028  0.882174   5  ChvUtd
# 14        0.792032  0.860817   1  ChvUtd
# 15        0.851793  0.884510   6  ChvUtd
# 16        0.854183  0.886609   7  ChvUtd
# 17        0.854980  0.888039   8  ChvUtd
# 18        0.858964  0.889158   9  ChvUtd
# 19        0.859761  0.890210  10  ChvUtd
# 20        0.815714  0.879204   2  PS0304
# 21        0.836429  0.891613   3  PS0304
# 22        0.767857  0.857687   1  PS0304
# 23        0.853571  0.899056   4  PS0304
# 24        0.863571  0.904494   5  PS0304
# 25        0.873571  0.908596   6  PS0304
# 26        0.885000  0.912126   7  PS0304
# 27        0.888571  0.914792   8  PS0304
# 28        0.894286  0.917038   9  PS0304
# 29        0.897143  0.919292  10  PS0304
# 30        0.541382  0.752745  10  ER0429
# 31        0.529233  0.745154   9  ER0429
# 32        0.490509  0.729838   7  ER0429
# 33        0.509491  0.735487   8  ER0429
# 34        0.490509  0.723069   6  ER0429
# 35        0.457099  0.710924   5  ER0429
# 36        0.425209  0.697191   4  ER0429
# 37        0.381169  0.678546   3  ER0429
# 38        0.343204  0.657422   2  ER0429
# 39        0.280182  0.628031   1  ER0429

# %%
scat1 = bokeh.charts.Scatter(data, x='lt', y='mota', color='game')
bokeh.io.show(scat1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1b51b5a9-38dd-4547-a2e1-e636f0c890c1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1b51b5a9-38dd-4547-a2e1-e636f0c890c1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1b51b5a9-38dd-4547-a2e1-e636f0c890c1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1b51b5a9-38dd-4547-a2e1-e636f0c890c1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"99478f19-bd69-4510-91cd-f59035573b44":{"roots":{"references":[{"attributes":{"items":[{"id":"0e05f3a7-7eaa-4589-b01f-ffc4034df107","type":"LegendItem"},{"id":"51dd9125-7127-4632-be35-30b9bed5d3c2","type":"LegendItem"},{"id":"c86377dc-0edf-4462-9cfa-0a05c72ba593","type":"LegendItem"},{"id":"60b52319-51c0-4a46-9b62-e25d154dcb15","type":"LegendItem"}],"location":"top_left","plot":{"id":"fc21c70d-5276-485b-b15f-bf939fefa94f","subtype":"Chart","type":"Plot"}},"id":"d57a641a-bb9c-4ebd-971d-514cc22ebd16","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"a35f6e12-eb67-4585-9ca7-04a89b0e6fe4","type":"Circle"},{"attributes":{"axis_label":"lt","formatter":{"id":"240335db-58c1-40e0-a012-07a809d95eab","type":"BasicTickFormatter"},"plot":{"id":"fc21c70d-5276-485b-b15f-bf939fefa94f","subtype":"Chart","type":"Plot"},"ticker":{"id":"fd22e0b5-c79c-47bf-86c8-b130a63a27ad","type":"BasicTicker"}},"id":"4718e024-6d80-4ff5-bb5d-b25d7b2c96cd","type":"LinearAxis"},{"attributes":{},"id":"0bbe5479-79be-44b8-990e-dc015b3e03df","type":"ToolEvents"},{"attributes":{"data_source":{"id":"442acc9e-7b62-4058-bdd7-86044dbcc818","type":"ColumnDataSource"},"glyph":{"id":"7482815a-1b1d-46b1-a76a-3357858fd642","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"34763cd2-5bbf-478a-9658-5ddf362f035c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"},{"game":"ER0429"}],"game":["ER0429","ER0429","ER0429","ER0429","ER0429","ER0429","ER0429","ER0429","ER0429","ER0429"],"x_values":[10,9,7,8,6,5,4,3,2,1],"y_values":{"__ndarray__":"gahqreLq4j95NqtXodniP8oBBF4ayOI/KMceTRHA4j9QhfTDV7ziP/pxiDkyquI/2qpPRQyA4j+sv37UkkXiP6oeq7jb7+E/4sDm2CV64T8=","dtype":"float64","shape":[10]}}},"id":"442acc9e-7b62-4058-bdd7-86044dbcc818","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"39be6c78-7164-450c-9bf0-2ed8359a62e7","type":"ColumnDataSource"},"glyph":{"id":"9dd8779b-0b7f-4530-b27f-0f6c887bb8e7","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"ab796556-b32f-4942-92fe-6adb789e20c5","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"fc21c70d-5276-485b-b15f-bf939fefa94f","subtype":"Chart","type":"Plot"}},"id":"6a915819-9b2c-417b-b39a-af24224f59f2","type":"PanTool"},{"attributes":{"plot":{"id":"fc21c70d-5276-485b-b15f-bf939fefa94f","subtype":"Chart","type":"Plot"}},"id":"1db72eb2-362f-4866-a6dd-10c4fd877705","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"7482815a-1b1d-46b1-a76a-3357858fd642","type":"Circle"},{"attributes":{},"id":"240335db-58c1-40e0-a012-07a809d95eab","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"596bbb14-ae17-482e-9bf5-b9bdde86390c","type":"Circle"},{"attributes":{},"id":"9fd214e4-f1d5-415b-b0be-a38abec957d6","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"fc21c70d-5276-485b-b15f-bf939fefa94f","subtype":"Chart","type":"Plot"}},"id":"3455c4f4-5166-466e-a890-52e45dacf47e","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"fc21c70d-5276-485b-b15f-bf939fefa94f","subtype":"Chart","type":"Plot"},"ticker":{"id":"fd22e0b5-c79c-47bf-86c8-b130a63a27ad","type":"BasicTicker"}},"id":"1b7973fe-7c0e-4df7-9fb1-0a27896baaea","type":"Grid"},{"attributes":{},"id":"975cbe01-02d2-4f71-92f5-6eb564860798","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_val ...

# %%
data_lt = data.copy()
data_lt['loss'] = data_lt['lt']
data_lt = data_lt.groupby(['lt']).mean()
data_lt
# Out:
#         mota      motp      motr  mostly_tracked    mt_auc  loss
# lt
# 1   0.735043  0.640503  0.818905        0.667737  0.808746     1
# 2   0.741528  0.638885  0.838458        0.709351  0.827844     2
# 3   0.744188  0.637860  0.851282        0.731443  0.840463     3
# 4   0.744112  0.637014  0.860190        0.750015  0.849252     4
# 5   0.744646  0.636525  0.866987        0.764784  0.856027     5
# 6   0.743381  0.635947  0.872657        0.779231  0.861635     6
# 7   0.741960  0.635584  0.876342        0.783388  0.865329     7
# 8   0.739972  0.635125  0.879289        0.790629  0.868293     8
# 9   0.739186  0.634753  0.883007        0.799042  0.871972     9
# 10  0.738096  0.634286  0.885919        0.803168  0.874989    10

# %%
scat2 = bokeh.charts.Scatter(data_lt, x = 'loss', y='mota')
scat3 = bokeh.charts.Scatter(data_lt, x = 'loss', y='motp')
scat4 = bokeh.charts.Scatter(data_lt, x = 'loss', y='mostly_tracked')
scat5 = bokeh.charts.Scatter(data_lt, x = 'loss', y='mt_auc')
bokeh.io.show(bokeh.layouts.column(bokeh.layouts.row(scat2, scat3), bokeh.layouts.row(scat4, scat5)))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8372976b-d4de-448e-b5ba-ce6ec60099fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8372976b-d4de-448e-b5ba-ce6ec60099fb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8372976b-d4de-448e-b5ba-ce6ec60099fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8372976b-d4de-448e-b5ba-ce6ec60099fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a3993c7f-aef7-4c93-aef2-6c3e6c17902d":{"roots":{"references":[{"attributes":{},"id":"4a524abf-9ecd-4a66-98de-b040f8e37fdc","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0083c582-9eed-40b0-b8ba-d39e7609759f","type":"BoxAnnotation"},{"attributes":{},"id":"8cab6cab-65e5-4a7e-a02e-dcdf68d40297","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cce6ece0-3105-4f9b-b0a9-dd5d1f5b63fd","type":"PanTool"},{"id":"8b8e2e19-d844-40cf-b988-5d23ba8a9b8a","type":"WheelZoomTool"},{"id":"adc828d4-d149-4f0b-b8a2-c0082faf8e4c","type":"BoxZoomTool"},{"id":"97dcc813-d87d-4902-bf2d-050d1dc9e8d5","type":"SaveTool"},{"id":"d044a1ce-2123-419c-b4a5-6f519fe43a5e","type":"ResetTool"},{"id":"91344bac-beaa-4f45-9adb-d03ab34e7c8b","type":"HelpTool"}]},"id":"78345804-f872-4629-89ef-4f6a17ffbbeb","type":"Toolbar"},{"attributes":{"plot":{"id":"35cf673b-0693-4482-ba4c-b5d8d97237de","subtype":"Chart","type":"Plot"}},"id":"d80afda6-289f-46e7-b768-98e1af35135a","type":"PanTool"},{"attributes":{"callback":null,"end":10.9,"start":0.09999999999999998},"id":"f4b1382c-2ea6-49c0-bd31-a79f91fea96f","type":"Range1d"},{"attributes":{"plot":{"id":"35cf673b-0693-4482-ba4c-b5d8d97237de","subtype":"Chart","type":"Plot"}},"id":"11c3ab61-a817-4344-9044-5cba8bdd2002","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"40c5e8e6-e6db-4551-843b-af065c015d30","type":"Circle"},{"attributes":{"callback":null,"end":0.6411251891069669,"start":0.6336645666450372},"id":"27efa446-e321-4a03-9fd7-82df5e9bacc0","type":"Range1d"},{"attributes":{"below":[{"id":"9542ced4-26a7-420f-9197-b8491a92d689","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"10192d24-f724-4596-b664-d08a9ae15716","type":"LinearAxis"}],"renderers":[{"id":"0083c582-9eed-40b0-b8ba-d39e7609759f","type":"BoxAnnotation"},{"id":"6ae5577b-c95b-4711-a268-67acced0f87c","type":"GlyphRenderer"},{"id":"a1f39378-bdeb-4d34-8505-80c340fe83d1","type":"Legend"},{"id":"9542ced4-26a7-420f-9197-b8491a92d689","type":"LinearAxis"},{"id":"10192d24-f724-4596-b664-d08a9ae15716","type":"LinearAxis"},{"id":"3660559e-ce05-4280-84dc-450100009bc1","type":"Grid"},{"id":"6cb57c4d-dd27-4906-8864-d372f9bf93dc","type":"Grid"}],"title":{"id":"ca8bc7c7-e6f3-42e4-b9d4-b1a2a06ff35e","type":"Title"},"tool_events":{"id":"4a524abf-9ecd-4a66-98de-b040f8e37fdc","type":"ToolEvents"},"toolbar":{"id":"e10654ad-dff0-4156-8379-f000d9edd891","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"6ab566dc-9e12-4a9d-a848-e6a242f9243b","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"f5ee813d-fcb3-426b-aef4-091ac6507287","type":"Range1d"}},"id":"1d567a3c-b65e-4577-8c59-4296f74532b2","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"end":0.7456059344884816,"start":0.734082946754945},"id":"51337dfa-d912-4d1f-8423-8a43828b770f","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d80afda6-289f-46e7-b768-98e1af35135a","type":"PanTool"},{"id":"5ec2e40c-517a-4e9a-91ea-e6346192bfc2","type":"WheelZoomTool"},{"id":"0cd0258c-4ae3-41b2-b63f-952e495f1db6","type":"BoxZoomTool"},{"id":"8c7ebf01-4957-44f7-a785-851828423607","type":"SaveTool"},{"id":"a72a4ca1-67f4-483c-a270-2d335a06dc18","type":"ResetTool"},{"id":"11c3ab61-a817-4344-9044-5cba8bdd2002","type":"HelpTool"}]},"id":"60595ee3-36a5-4213-beb4-a51fc596e1c8","type":"Toolbar"},{"attributes":{"plot":{"id":"1d567a3c-b65e-4577-8c59-4296f74532b2","subtype":"Chart","type":"Plot"}},"id":"dd05970d-74 ...

# %%
data_lt = data['mota'].groupby(data['lt']).describe()
data_lt
# Out:
#     count      mean       std       min       25%       50%       75%  \
# lt
# 1     4.0  0.735043  0.131469  0.546161  0.706115  0.772346  0.801273
# 2     4.0  0.741528  0.126504  0.560530  0.713139  0.775889  0.804277
# 3     4.0  0.744188  0.121651  0.570993  0.715096  0.775851  0.804943
# 4     4.0  0.744112  0.117285  0.578131  0.713900  0.773167  0.803379
# 5     4.0  0.744646  0.114289  0.583276  0.714786  0.772328  0.802187
# 6     4.0  0.743381  0.112209  0.585491  0.712612  0.769908  0.800677
# 7     4.0  0.741960  0.110512  0.586927  0.710284  0.767601  0.799277
# 8     4.0  0.739972  0.110042  0.585946  0.707228  0.765248  0.797992
# 9     4.0  0.739186  0.107634  0.589066  0.705914  0.763324  0.796596
# 10    4.0  0.738096  0.105612  0.591173  0.704646  0.761359  0.794808
#
#          max
# lt
# 1   0.849321
# 2   0.853803
# 3   0.854059
# 4   0.851985
# 5   0.850651
# 6   0.848217
# 7   0.845709
# 8   0.843445
# 9   0.841031
# 10  0.838492

# %%
data[data['lt']==4]
# Out:
#                            job_id      mota      motp      motr  \
# 2   PTA-89-LT-3-M14-PP0214-000-04  0.851985  0.736281  0.930011
# 12  PTA-89-LT-3-M12-ChvUtd-000-04  0.787178  0.497065  0.886685
# 23  PTA-89-LT-3-M13-PS0304-001-04  0.759156  0.691453  0.909974
# 36  PTA-89-LT-3-M15-ER0429-001-04  0.578131  0.623255  0.714088
#
#     mostly_tracked    mt_auc  lt    game
# 2         0.887018  0.921391   4  PP0214
# 12        0.834263  0.879371   4  ChvUtd
# 23        0.853571  0.899056   4  PS0304
# 36        0.425209  0.697191   4  ER0429
